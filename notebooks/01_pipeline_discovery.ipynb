# %% [markdown]
# # Excel Quality Pipeline – Discovery Notebook
#
# ## Objective
# Build a reproducible data pipeline that produces a single cleaned
# quality dataset from multiple Excel inputs.
#
# This notebook is for exploration and validation only.
# Final logic will be migrated into the `src/` module.

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
file_path = "../data/raw/PATIENT OPD VISITS- from MCC & Email.xlsx"
df = pd.read_excel(file_path)
df.shape
# Out:
# (4204, 18)

# %%
header = df.columns.tolist()

# %%
print(header)
# Out:
# ['MRN', 'PatEngName', 'pat_birthdate', 'regtime', 'VISIT_DATETIME', 'ARRIVETIME', 'STARTTIME', 'VISIT_TYPE', 'PORTAL STATUS', 'VISIT STATUS', 'BOOKING_TYPE', 'clinic_key', 'CLINIC_NAME', 'MRP', 'JOB TITLE', 'SPECIALTY', 'Added_by', 'addtime']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4204 entries, 0 to 4203
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MRN             4204 non-null   int64
#  1   PatEngName      4094 non-null   object
#  2   pat_birthdate   4047 non-null   datetime64[ns]
#  3   regtime         4204 non-null   datetime64[ns]
#  4   VISIT_DATETIME  4047 non-null   datetime64[ns]
#  5   ARRIVETIME      3314 non-null   datetime64[ns]
#  6   STARTTIME       3208 non-null   datetime64[ns]
#  7   VISIT_TYPE      4204 non-null   object
#  8   PORTAL STATUS   4047 non-null   object
#  9   VISIT STATUS    4047 non-null   object
#  10  BOOKING_TYPE    4047 non-null   object
#  11  clinic_key      4047 non-null   float64
#  12  CLINIC_NAME     4204 non-null   object
#  13  MRP             4204 non-null   object
#  14  JOB TITLE       4047 non-null   object
#  15  SPECIALTY       4047 non-null   object
#  16  Added_by        4047 non-null   object
#  17  addtime         4047 non-null   datetime64[ns]
# dtypes: datetime64[ns](6), float64(1), int64(1), object(10)
# memory usage: 591.3+ KB

# %%
# Drop uneeded col
cols_to_drop = [
    "regtime",
    "ARRIVETIME",
    "STARTTIME",
    "PORTAL STATUS",
    "clinic_key",
    "JOB TITLE",
    "SPECIALTY",
    "Added_by",
    "addtime",
]

df = df.drop(columns=cols_to_drop)

# %%
df.columns
# Out:
# Index(['MRN', 'PatEngName', 'pat_birthdate', 'VISIT_DATETIME', 'VISIT_TYPE',
#        'VISIT STATUS', 'BOOKING_TYPE', 'CLINIC_NAME', 'MRP'],
#       dtype='object')

# %%
# Normalize column names
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)
df.columns
# Out:
# Index(['mrn', 'patengname', 'pat_birthdate', 'visit_datetime', 'visit_type',
#        'visit_status', 'booking_type', 'clinic_name', 'mrp'],
#       dtype='object')

# %%
df['visit_datetime'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# change col visit_datetime to datetime DD/MM/YYYY

df["visit_datetime"] = pd.to_datetime(
    df["visit_datetime"],
    errors="coerce"
).dt.date

# %%
df["visit_datetime"].dtype
type(df.loc[0, "visit_datetime"])
# Out:
# datetime.date

# %%
# Adding the new col

new_cols = [
    "liver_r_d",
    "liver_status",
    "kidney_recipient",
    "kidney_donor",
]

for col in new_cols:
    df[col] = None

df.columns
# Out:
# Index(['mrn', 'patengname', 'pat_birthdate', 'visit_datetime', 'visit_type',
#        'visit_status', 'booking_type', 'clinic_name', 'mrp', 'liver_r_d',
#        'liver_status', 'kidney_recipient', 'kidney_donor'],
#       dtype='object')

# %%
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  218455            NORAH BAHIAS ALI ZARAB    1987-04-16     2025-12-23
# 1  118631          ZAHRA MAHDI ALI ALAWAZIM    2003-02-24     2025-12-10
# 2  219640  SULTANAH HAMAD ABDULLAH ALHASSAN    1959-01-10     2025-12-08
# 3  220961   SEHAM MOHAMMED KHAMEES ALHASSAN    1969-06-03     2025-12-10
# 4  220533     ABDULAZIZ ADNAN SALEH ALHADAD    1978-09-30     2025-12-21
#
#   visit_type visit_status    booking_type clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 1        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 2        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 3        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 4        NEW      STARTED  NORMAL BOOKING  Anesthesia
#
#                                      mrp liver_r_d liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 1  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 2  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 4  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
#
#   kidney_recipient kidney_donor
# 0             None         None
# 1             None         None
# 2             None         None
# 3             None         None
# 4             None         None

# %%
df['visit_status'].value_counts()
# Out:
# visit_status
# STARTED    3208
# NO SHOW     733
# ARRIVED     106
# Name: count, dtype: int64

# %%
# Remove NO SHOW visit_status

df = df[df["visit_status"] != "NO SHOW"]

# %%
df['visit_status'].value_counts()
# Out:
# visit_status
# STARTED    3208
# ARRIVED     106
# Name: count, dtype: int64

# %%
# Fill liver columns using Liver Registry (ONLY)
# For each MRN in df:
# Look it up in Liver Registry
# If found:
###### Rec_Don → liver_r_d
###### Current Status1 → liver_status
# If not found:
##### leave as NaN

liver_df = pd.read_excel("../data/raw/Liver Registry - 1 JAN.xlsx")
liver_df.columns = (liver_df.columns.str.strip().str.lower().str.replace(" ", "_"))

# %%
liver_df.columns.tolist()
# Out:
# ['r_mrn',
#  'id_number',
#  'patient_name',
#  'mobile1_0',
#  'payment_0',
#  'rec_don',
#  'nationality',
#  'city_of_residence',
#  'specify_other',
#  'age_group',
#  'age',
#  'blood_group',
#  'gender',
#  'date_open_file_0',
#  'current_status1',
#  'patient_type_1',
#  'initial_tx_assessment_date',
#  'workup_start_date',
#  'workup_completed_date',
#  'date_added_to_waiting_list',
#  'surgery_date',
#  'tx_type',
#  'transplant_place',
#  'comment_0',
#  'closefile_r',
#  'closefiledate_r',
#  'closefilereason_r',
#  'assigned_consultant_0',
#  'assigned_surgeon_r',
#  'primary_disease']

# %%
df = df.merge(
    liver_df[["r_mrn", "rec_don", "current_status1"]],
    left_on="mrn",
    right_on="r_mrn",
    how="left"
)

# %%
df["liver_r_d"] = df["rec_don"]
df["liver_status"] = df["current_status1"]
df.tail()
# Out:
#          mrn  patengname pat_birthdate visit_datetime visit_type visit_status  \
# 3466  203844   Abdullah            NaT            NaT  Follow up          NaN
# 3467  221651   MOHAMMED            NaT            NaT        New          NaN
# 3468  221730  Abdulqawi            NaT            NaT        New          NaN
# 3469   40991     SHATHA            NaT            NaT        New          NaN
# 3470  107061   ABDULLAH            NaT            NaT        New          NaN
#
#      booking_type clinic_name            mrp  liver_r_d liver_status  \
# 3466          NaN  Psychology  Alia Al Enazi  Recipient      Post Tx
# 3467          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3468          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3469          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3470          NaN  Psychology  Alia Al Enazi        NaN          NaN
#
#      kidney_recipient kidney_donor   r_mrn    rec_don current_status1
# 3466             None         None  203844  Recipient         Post Tx
# 3467             None         None     NaN        NaN             NaN
# 3468             None         None     NaN        NaN             NaN
# 3469             None         None     NaN        NaN             NaN
# 3470             None         None     NaN        NaN             NaN

# %%
df = df.drop(columns=["r_mrn", "rec_don", "current_status1"])

# %%
df[df["liver_r_d"].notna()]
# Out:
#          mrn                              patengname pat_birthdate  \
# 12    104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 20    220797                 BASHAYER FAWAZ  ALSAEGR    1992-04-17
# 21    220503  ALHASSAN ABDULRAHIM ABDULLAH ALZAHRANI    1999-08-20
# 22    220468                    SAAD SALEM M ALMAHRI    1986-03-17
# 23    220993      IBRAHIM ABDULKARIM IBRAHIM ALHABIB    1993-09-13
# ...      ...                                     ...           ...
# 3454  221422                                MESHARI            NaT
# 3455  221756                                  FAHAD            NaT
# 3456  218992                                 HISSAH            NaT
# 3461  221468                                   WADI            NaT
# 3466  203844                               Abdullah            NaT
#
#      visit_datetime visit_type visit_status    booking_type  \
# 12       2025-12-10        NEW      STARTED  NORMAL BOOKING
# 20       2025-12-10    Walk-In      STARTED         WALK-IN
# 21       2025-12-10    Walk-In      STARTED         WALK-IN
# 22       2025-12-10    Walk-In      STARTED         WALK-IN
# 23       2025-12-10    Walk-In      STARTED         WALK-IN
# ...             ...        ...          ...             ...
# 3454            NaT        New          NaN             NaN
# 3455            NaT        New          NaN             NaN
# 3456            NaT        New          NaN             NaN
# 3461            NaT        New          NaN             NaN
# 3466            NaT  Follow up          NaN             NaN
#
#              clinic_name                                    mrp  liver_r_d  \
# 12            Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID  Recipient
# 20    TRANSPLANT SURGERY           Mohammed Saad Ali AL-Qahtani      Donor
# 21    TRANSPLANT SURGERY           Mohammed Saad Ali AL-Qahtani      Donor
# 22    TRANSPLANT SURGERY           Mohammed Saad Ali AL-Qahtani      Donor
# 23    TRANSPLANT SURGERY           Mohammed Saad Ali AL-Qahtani      Donor
# ...                  ...                                    ...        ...
# 3454          Psychology                          Alia Al Enazi      Donor
# 3455          Psychology                          Alia Al Enazi      Donor
# 3456          Psychology                          Alia Al Enazi  Recipient
# 3461          Psychology                          Alia Al Enazi      Donor
# 3466          Psychology                          Alia Al Enazi  Recipient
#
#                      liver_status kidney_recipient kidney_donor
# 12             Hepatology patient             None         None
# 20    Pre Tx ready for transplant             None         None
# 21                        Post Tx             None         None
# 22                        Post Tx             None         None
# 23    Pre Tx ready for transplant             None         None
# ...                           ...              ...          ...
# 3454            Pre Tx on workups             None         None
# 3455            Pre Tx on workups             None         None
# 3456            Pre Tx on workups             None         None
# 3461            Pre Tx on workups             None         None
# 3466                      Post Tx             None         None
#
# [672 rows x 13 columns]

# %%
# Fill kidney_recipient using Kidney Recipient registry (ONLY)
# For each mrn in the main df:
# Look it up in Kidney Recipient - 1 JAN.xlsx

# If found:
###### copy Current Status1 → kidney_recipient
# If not found:
###### leave as NaN

kidney_rec_df = pd.read_excel("../data/raw/Kidney Recipient - 1 JAN.xlsx")
kidney_rec_df.columns = (kidney_rec_df.columns.str.strip().str.lower().str.replace(" ", "_"))

# %%
df = df.merge(
    kidney_rec_df[["r_mrn", "current_status1"]],
    left_on="mrn",
    right_on="r_mrn",
    how="left"
)
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  218455            NORAH BAHIAS ALI ZARAB    1987-04-16     2025-12-23
# 1  118631          ZAHRA MAHDI ALI ALAWAZIM    2003-02-24     2025-12-10
# 2  219640  SULTANAH HAMAD ABDULLAH ALHASSAN    1959-01-10     2025-12-08
# 3  220961   SEHAM MOHAMMED KHAMEES ALHASSAN    1969-06-03     2025-12-10
# 4  220533     ABDULAZIZ ADNAN SALEH ALHADAD    1978-09-30     2025-12-21
#
#   visit_type visit_status    booking_type clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 1        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 2        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 3        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 4        NEW      STARTED  NORMAL BOOKING  Anesthesia
#
#                                      mrp liver_r_d liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 1  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 2  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 4  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
#
#   kidney_recipient kidney_donor  r_mrn current_status1
# 0             None         None    NaN             NaN
# 1             None         None    NaN             NaN
# 2             None         None    NaN             NaN
# 3             None         None    NaN             NaN
# 4             None         None    NaN             NaN

# %%
df["kidney_recipient"] = df["current_status1"]
df = df.drop(columns=["r_mrn", "current_status1"])

# %%
df.tail()
# Out:
#          mrn  patengname pat_birthdate visit_datetime visit_type visit_status  \
# 3466  203844   Abdullah            NaT            NaT  Follow up          NaN
# 3467  221651   MOHAMMED            NaT            NaT        New          NaN
# 3468  221730  Abdulqawi            NaT            NaT        New          NaN
# 3469   40991     SHATHA            NaT            NaT        New          NaN
# 3470  107061   ABDULLAH            NaT            NaT        New          NaN
#
#      booking_type clinic_name            mrp  liver_r_d liver_status  \
# 3466          NaN  Psychology  Alia Al Enazi  Recipient      Post Tx
# 3467          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3468          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3469          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3470          NaN  Psychology  Alia Al Enazi        NaN          NaN
#
#         kidney_recipient kidney_donor
# 3466  Nephrology patient         None
# 3467                 NaN         None
# 3468                 NaN         None
# 3469                 NaN         None
# 3470          Post LD Tx         None

# %%
# Fill kidney_donor
# For each mrn in the main df:
# Match it to d_mrn in Kidney Donor - 1 JAN.xlsx
# Copy current_status1_d → kidney_donor
# If no match → leave NaN

kidney_donor_df = pd.read_excel("../data/raw/Kidney Donor - 1 JAN.xlsx")

kidney_donor_df.columns = (
    kidney_donor_df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
)

df = df.merge(
    kidney_donor_df[["d_mrn", "current_status1_d"]],
    left_on="mrn",
    right_on="d_mrn",
    how="left"
)

df["kidney_donor"] = df["current_status1_d"]

df = df.drop(columns=["d_mrn", "current_status1_d"])

# %%
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  218455            NORAH BAHIAS ALI ZARAB    1987-04-16     2025-12-23
# 1  118631          ZAHRA MAHDI ALI ALAWAZIM    2003-02-24     2025-12-10
# 2  219640  SULTANAH HAMAD ABDULLAH ALHASSAN    1959-01-10     2025-12-08
# 3  220961   SEHAM MOHAMMED KHAMEES ALHASSAN    1969-06-03     2025-12-10
# 4  220533     ABDULAZIZ ADNAN SALEH ALHADAD    1978-09-30     2025-12-21
#
#   visit_type visit_status    booking_type clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 1        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 2        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 3        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 4        NEW      STARTED  NORMAL BOOKING  Anesthesia
#
#                                      mrp liver_r_d liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 1  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 2  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 4  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
#
#   kidney_recipient kidney_donor
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Anesthesia                                     840
# Clinical Nutrition                             556
# Adult Post Renal Transplant                    500
# TRANSPLANT SURGERY                             458
# Adult Post Kidney Transplant Virtual Clinic    264
# Adult Pre Renal Transplant                     133
# ADULT POST LIVER TRANSPLANT                    131
# Social Work                                    110
# Pediatric Post Renal Transplant                102
# Adult Pre Liver Transplant                      97
# Pediatric Liver Transplant                      66
# Transplant Dressing (procedure)                 54
# Psychology                                      47
# Adult Post Liver Transplant Virtual             42
# Adult Pre Renal Transplant Virtual Clinic       37
# Pre anesthesia liver transplant                 15
# Pediatric Pre Renal Transplant                  11
# Adult Pre Liver Transplant Virtual               5
# Transplant Cystoscopy Clinic                     3
# Name: count, dtype: int64

# %%
# Remove visits based on clinic + transplant status (ONLY)

# Remove row if ALL of the following are true:

# 1-clinic_name is Anesthesia OR Clinical Nutrition
# 2- liver_r_d is NaN
# 3-kidney_recipient is NaN
# 4-kidney_donor is NaN

mask = (
    df["clinic_name"].isin(["Anesthesia", "Clinical Nutrition"])
    & df["liver_r_d"].isna()
    & df["kidney_recipient"].isna()
    & df["kidney_donor"].isna()
)

df = df[~mask]

# %%
df[
    df["clinic_name"].isin(["Anesthesia", "Clinical Nutrition"])
][["liver_r_d", "kidney_recipient", "kidney_donor"]].isna().all(axis=1).sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#        mrn                              patengname pat_birthdate  \
# 7   174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9    77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12  104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13  101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17    6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
#
#    visit_datetime visit_type visit_status    booking_type  \
# 7      2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9      2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12     2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17     2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
#
#                     clinic_name                                     mrp  \
# 7   Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
#
#     liver_r_d        liver_status kidney_recipient kidney_donor
# 7         NaN                 NaN       Post LD Tx          NaN
# 9         NaN                 NaN       Post DD Tx          NaN
# 12  Recipient  Hepatology patient       Post DD Tx          NaN
# 13        NaN                 NaN       Post LD Tx          NaN
# 17        NaN                 NaN       Post LD Tx          NaN

# %%
df[df[["liver_r_d", "kidney_recipient", "kidney_donor"]].isna().all(axis=1)]
# Out:
#          mrn                          patengname pat_birthdate visit_datetime  \
# 530    13459        SHAIKHAH MOHAMMED A ALSAMHAN    1940-08-04     2025-12-15
# 1166  221813   MOHAMMAD MOQBIL ABDULLAH ALQARAWI    1959-01-10     2025-12-28
# 1169  218567      REEM ABDULHAKIM HAMAD ALKHALDI    2010-07-14     2025-12-02
# 2335    8909  BANEEN ABDULLAH MOHAMMED ALSAIHATI    1986-05-17     2025-12-29
# 2744  200160       AHMED MOHAMED ALY AHMED ZIDAN    1981-07-25     2025-12-31
# 2756    6097            REHAB AHMED GABER ABDALL    1978-06-10     2025-12-28
# 3018  220426          SALMAN OMAR JAFAR ALOTAIBI    1986-09-14     2025-12-09
# 3041  200362                      NISY   MATHEWS    1998-08-15     2025-12-16
# 3170  210421                      Devika   Reghu    1996-05-04     2025-12-29
#
#        visit_type visit_status    booking_type                 clinic_name  \
# 530           NEW      STARTED  NORMAL BOOKING  Adult Pre Liver Transplant
# 1166          NEW      STARTED  NORMAL BOOKING  Adult Pre Liver Transplant
# 1169      Walk-In      STARTED         WALK-IN  Pediatric Liver Transplant
# 2335    FOLLOW UP      STARTED  NORMAL BOOKING          TRANSPLANT SURGERY
# 2744  CHART CHECK      STARTED         WALK-IN          TRANSPLANT SURGERY
# 2756  CHART CHECK      STARTED         WALK-IN          TRANSPLANT SURGERY
# 3018      Walk-In      STARTED         WALK-IN          TRANSPLANT SURGERY
# 3041      Walk-In      STARTED         WALK-IN  Adult Pre Renal Transplant
# 3170      Walk-In      STARTED         WALK-IN          TRANSPLANT SURGERY
#
#                                       mrp liver_r_d liver_status  \
# 530   Eyad Mohammad Osman Elhassan Gadour       NaN          NaN
# 1166           HADI MOHAMMED SHOEI KURIRY       NaN          NaN
# 1169      Razan Monther Abdulmajied Bader       NaN          NaN
# 2335            MAHMOUD ALI MAHMOUD OBEID       NaN          NaN
# 2744        AHMED MOHAMED ALY AHMED ZIDAN       NaN          NaN
# 2756        AHMED MOHAMED ALY AHMED ZIDAN       NaN          NaN
# 3018         Mohammed Saad Ali AL-Qahtani       NaN          NaN
# 3041          KHALID AHMEDH BELEED AKKARI       NaN          NaN
# 3170            MAHMOUD ALI MAHMOUD OBEID       NaN          NaN
#
#      kidney_recipient kidney_donor
# 530               NaN          NaN
# 1166              NaN          NaN
# 1169              NaN          NaN
# 2335              NaN          NaN
# 2744              NaN          NaN
# 2756              NaN          NaN
# 3018              NaN          NaN
# 3041              NaN          NaN
# 3170              NaN          NaN

# %%
# Add need_review flag
df["need_review"] = "no"
review_mask = (
    df[["liver_r_d", "kidney_recipient", "kidney_donor"]]
    .isna()
    .all(axis=1)
)

df.loc[review_mask, "need_review"] = "yes"

# %%
df['liver_r_d'].value_counts()
# Out:
# liver_r_d
# Recipient    547
# Donor        125
# Name: count, dtype: int64

# %%
# Create and fill r_d (LOCKED LOGIC)

# We look at three columns:
#liver_r_d, kidney_recipient, kidney_donor
# A) If only one of the three is non-NaN:
# Only liver_r_d filled → r_d = "Liver " + liver_r_d
# Only kidney_recipient filled → r_d = kidney_recipient
# Only kidney_donor filled → r_d = kidney_donor
# B) If liver_r_d is non-NaN AND (either kidney_recipient OR kidney_donor is non-NaN):
# Use clinic_name keyword:
# If clinic_name contains renal or kidney → r_d becomes the non-NaN kidney value (recipient preferred, else donor)
# If clinic_name contains liver → r_d = "Liver " + liver_r_d

# Vectorized version
mask_liver_only = df['liver_r_d'].notna() & df['kidney_recipient'].isna() & df['kidney_donor'].isna()
mask_k_recip_only = df['kidney_recipient'].notna() & df['liver_r_d'].isna() & df['kidney_donor'].isna()
mask_k_donor_only = df['kidney_donor'].notna() & df['liver_r_d'].isna() & df['kidney_recipient'].isna()

df['r_d'] = np.select(
    [
        mask_liver_only,
        mask_k_recip_only,
        mask_k_donor_only,
    ],
    [
        "Liver " + df['liver_r_d'].astype(str),
        df['kidney_recipient'],
        df['kidney_donor']
    ],
    default=np.nan
)

# Now handle mixed cases (where liver + at least one kidney is present)
mixed_mask = (
    df['liver_r_d'].notna() &
    (df['kidney_recipient'].notna() | df['kidney_donor'].notna()) &
    (df['r_d'].isna())  # still null after previous step
)

clinic_lower = df['clinic_name'].fillna('').str.lower()

renal_clinic = clinic_lower.str.contains('renal|kidney')
liver_clinic = clinic_lower.str.contains('liver')

df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'r_d'] = \
    df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'kidney_recipient'].fillna(
        df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'kidney_donor']
    )

df.loc[mixed_mask & liver_clinic & ~renal_clinic, 'r_d'] = \
    "Liver " + df.loc[mixed_mask & liver_clinic & ~renal_clinic, 'liver_r_d'].astype(str)

# %%
df.head()
# Out:
#        mrn                              patengname pat_birthdate  \
# 7   174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9    77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12  104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13  101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17    6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
#
#    visit_datetime visit_type visit_status    booking_type  \
# 7      2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9      2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12     2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17     2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
#
#                     clinic_name                                     mrp  \
# 7   Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
#
#     liver_r_d        liver_status kidney_recipient kidney_donor need_review  \
# 7         NaN                 NaN       Post LD Tx          NaN          no
# 9         NaN                 NaN       Post DD Tx          NaN          no
# 12  Recipient  Hepatology patient       Post DD Tx          NaN          no
# 13        NaN                 NaN       Post LD Tx          NaN          no
# 17        NaN                 NaN       Post LD Tx          NaN          no
#
#            r_d
# 7   Post LD Tx
# 9   Post DD Tx
# 12         NaN
# 13  Post LD Tx
# 17  Post LD Tx

# %%
df['liver_status'].value_counts()
# Out:
# liver_status
# Post Tx                        366
# Hepatology patient             111
# Pre Tx on workups               82
# New patient                     47
# Pre Tx ready for transplant     24
# OPD Hepatology patient          16
# Pre Tx on DDWL                  16
# Pre Tx Ready for transplant      6
# Hepatitis C patient              2
# Pre Tx on hold                   2
# Name: count, dtype: int64

# %%
# ambiguous_mask = (
#     df['liver_r_d'].notna() &
#     (df['kidney_recipient'].notna() | df['kidney_donor'].notna()) &
#     df['r_d'].isna()
# )

# len(df.loc[ambiguous_mask])

# come to this later at the end to see how many should be assigned as need review
df.head(30)
# Out:
#         mrn                              patengname pat_birthdate  \
# 7    174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9     77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12   104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13   101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17     6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
# 18    66898         AMNA AHMED ABDULGAFOR AL SHEIKH    1984-01-04
# 19   208799                   FARZANAH SAEED A  ALI    1963-07-01
# 20   220797                 BASHAYER FAWAZ  ALSAEGR    1992-04-17
# 21   220503  ALHASSAN ABDULRAHIM ABDULLAH ALZAHRANI    1999-08-20
# 22   220468                    SAAD SALEM M ALMAHRI    1986-03-17
# 23   220993      IBRAHIM ABDULKARIM IBRAHIM ALHABIB    1993-09-13
# 27   176279               RADHI NASER HASAN ALHODAR    1946-05-31
# 56    69581            AHMED MOHAMMED QASEM ALHARBI    1991-09-12
# 102  201292            ALI IBRAHIM MOBARAK ABU ABSI    1968-09-23
# 121   91287         NURAH ABDULMONEM AHMED ALFADHLI    2009-04-05
# 122   77466        ALBATUL HASSAN MUSALLAM ALBATHER    2011-11-13
# 125  220299          LANA NASSER MOHAMMED ALMUTAIRI    2025-06-20
# 126  220296                    AYAH ALI AHMED ASIRI    2023-06-26
# 127  217873            ELYAS ZUHDI ABDALLAH ELAYYAN    2024-11-04
# 129  194221             MISK MOHAMMED RADHI ALANAZI    2022-08-02
# 130  142741              AHMED JABER JUHRAN ALMALKI    2017-05-19
# 131  206092          IBRAHIM MOHAMMED IBRAHIM HAMDI    2022-11-22
# 134  201371           AMIRAH AHMED SAEED ALSHAHRANI    2024-04-24
# 135  201315    ABDULRAHMAN HUSSAIN ALI AL BOKHUDHER    2023-03-20
# 136  196993          ABDULLAH ALI MUDAYNI ALOTHAYQI    2023-01-11
# 139  190214           KAYAN MOHAMMED ALI ALDARWEESH    2022-09-27
# 141  188843             HOOR MOHAMMED TAHER ALBASRI    2023-04-06
# 142  187523           TARAF ABDULLAH HUSSAIN ALSABI    2016-06-06
# 143   54041             REFAH HAMAD SALEH ALDOSSARI    1975-07-28
# 148   97290        ANAS MUKHLED DHAIFALLAH ALSULAMI    2009-08-02
#
#     visit_datetime visit_type visit_status    booking_type  \
# 7       2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9       2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12      2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13      2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17      2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
# 18      2025-12-10  FOLLOW UP      ARRIVED  NORMAL BOOKING
# 19      2025-12-15  FOLLOW UP      STARTED  NORMAL BOOKING
# 20      2025-12-10    Walk-In      STARTED         WALK-IN
# 21      2025-12-10    Walk-In      STARTED         WALK-IN
# 22      2025-12-10    Walk-In      STARTED         WALK-IN
# 23      2025-12-10    Walk-In      STARTED         WALK-IN
# 27      2025-12-01         VV      STARTED  NORMAL BOOKING
# 56      2025-12-07        NEW      STARTED  NORMAL BOOKING
# 102     2025-12-02         VV      STARTED  NORMAL BOOKING
# 121     2025-12-24        NEW      STARTED  NORMAL BOOKING
# 122     2025-12-31         VV      STARTED  NORMAL BOOKING
# 125     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 126     2025-12-03         VV      STARTED  NORMAL BOOKING
# 127     2025-12-17        NEW      STARTED  NORMAL BOOKING
# 129     2025-12-31        NEW      STARTED  NORMAL BOOKING
# 130     2025-12-18        NEW      STARTED  NORMAL BOOKING
# 131     2025-12-24         VV      STARTED  NORMAL BOOKING
# 134     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 135     2025-12-07        NEW      STARTED  NORMAL BOOKING
# 136     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 139     2025-12-03         VV      STARTED  NORMAL BOOKING
# 141     2025-12-24        NEW      STARTED  NORMAL BOOKING
# 142     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 143     2025-12-29        NEW      STARTED  NORMAL BOOKING
# 148     2025-12-28         VV      STARTED  NORMAL BOOKING
#
#                      clinic_name                                     mrp  \
# 7    Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                     Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 18            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 19            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 20            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 21            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 22            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 23            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 27            Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 56            Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 102           Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 121           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 122           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 125           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 126           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 127           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 129           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 130           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 131           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 134           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 135           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 136           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 139           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 141           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 142           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 143           Clinical Nutrition             Fatimah Abdullah  AlIbrahim
# 148           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
#
#      liver_r_d                 liver_status  \
# 7          NaN                          NaN
# 9          NaN                          NaN
# 12   Recipient           Hepatology patient
# 13         NaN                          NaN
# 17         NaN                          NaN
# 18         NaN                          NaN
# 19         NaN                          NaN
# 20       Donor  Pre Tx ready for transplant
# 21       Donor                      Post Tx
# 22       Donor                      Post Tx
# 23       Donor  Pre Tx ready for transplant
# 27         NaN                          NaN
# 56         NaN                          NaN
# 102        NaN                          NaN
# 121        NaN                          NaN
# 122        NaN                          NaN
# 125  Recipient                  New patient
# 126        NaN                          NaN
# 127  Recipient                      Post Tx
# 129  Recipient                      Post Tx
# 130        NaN                          NaN
# 131        NaN                          NaN
# 134  Recipient                      Post Tx
# 135        NaN                          NaN
# 136  Recipient                      Post Tx
# 139  Recipient                      Post Tx
# 141  Recipient           Hepatology patient
# 142        NaN                          NaN
# 143  Recipient           Hepatology patient
# 148        NaN                          NaN
#
#                          kidney_recipient kidney_donor need_review  \
# 7                              Post LD Tx          NaN          no
# 9                              Post DD Tx          NaN          no
# 12                             Post DD Tx          NaN          no
# 13                             Post LD Tx          NaN          no
# 17                             Post LD Tx          NaN          no
# 18                             Post LD Tx          NaN          no
# 19                             Post LD Tx          NaN          no
# 20                                    NaN          NaN          no
# 21                                    NaN          NaN          no
# 22                                    NaN          NaN          no
# 23                                    NaN          NaN          no
# 27                     Nephrology patient          NaN          no
# 56                             Post LD Tx          NaN          no
# 102                    Nephrology patient          NaN          no
# 121                            Post DD Tx          NaN          no
# 122  Pre Tx Discussed with pending issues          NaN          no
# 125                                   NaN          NaN          no
# 126                     Pre Tx on workups          NaN          no
# 127                                   NaN          NaN          no
# 129                    Nephrology patient          NaN          no
# 130                            Post LD Tx          NaN          no
# 131                     Pre Tx on workups          NaN          no
# 134                                   NaN          NaN          no
# 135                            Post LD Tx          NaN          no
# 136                                   NaN          NaN          no
# 139                                   NaN          NaN          no
# 141                                   NaN          NaN          no
# 142                            Post LD Tx          NaN          no
# 143                                   NaN          NaN          no
# 148                            Post LD Tx          NaN          no
#
#                                       r_d
# 7                              Post LD Tx
# 9                              Post DD Tx
# 12                                    NaN
# 13                             Post LD Tx
# 17                             Post LD Tx
# 18                             Post LD Tx
# 19                             Post LD Tx
# 20                            Liver Donor
# 21                            Liver Donor
# 22                            Liver Donor
# 23                            Liver Donor
# 27                     Nephrology patient
# 56                             Post LD Tx
# 102                    Nephrology patient
# 121                            Post DD Tx
# 122  Pre Tx Discussed with pending issues
# 125                       Liver Recipient
# 126                     Pre Tx on workups
# 127                       Liver Recipient
# 129                                   NaN
# 130                            Post LD Tx
# 131                     Pre Tx on workups
# 134                       Liver Recipient
# 135                            Post LD Tx
# 136                       Liver Recipient
# 139                       Liver Recipient
# 141                       Liver Recipient
# 142                            Post LD Tx
# 143                       Liver Recipient
# 148                            Post LD Tx

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        911
# Liver Recipient                                   450
# Pre Tx on workups                                 266
# Post living donor nephrectomy                     158
# Liver Donor                                       122
# Post DD Tx                                         98
# Waiting for first appointment                      50
# Listed on DDWL                                     40
# Pre Tx Ready for committee                         33
# Pre Tx Discussed & ready for donor nephrectomy     30
# Nephrology patient                                 21
# Initial visit done, No LD, suspended for DDWL      20
# Pre Tx Discussed & Ready for LD Tx                 18
# Listed on DDWL & Ready for LD Tx                   13
# Pre Tx Discussed with pending issues                9
# Pre Tx on hold                                      9
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df["patient_type"] = None
df["transplant_date"] = None
df["days"] = None

# %%
df.head(1)
# Out:
#       mrn              patengname pat_birthdate visit_datetime visit_type  \
# 7  174153  AYSH ABDO HAMAD HADIDI    1955-02-23     2025-12-23  FOLLOW UP
#
#   visit_status    booking_type                  clinic_name  \
# 7      STARTED  NORMAL BOOKING  Adult Post Renal Transplant
#
#                                       mrp liver_r_d liver_status  \
# 7  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI       NaN          NaN
#
#   kidney_recipient kidney_donor need_review         r_d patient_type  \
# 7       Post LD Tx          NaN          no  Post LD Tx         None
#
#   transplant_date  days
# 7            None  None

# %%
df['patient_type'] = df['liver_status'].combine_first(
    df['kidney_recipient']
).combine_first(
    df['kidney_donor']
)

# %%
# if patient_type is NA i think need_revuew = yes

# %%
# Create lookup dictionaries: MRN → Surgery Date
# Using the actual column names from your files

liver_dict = (
    liver_df[['r_mrn', 'surgery_date']]
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['surgery_date']
    .to_dict()
)

recip_dict = (
    kidney_rec_df[['r_mrn', 'surgery_date']]           # ← using kidney_rec_df (your naming)
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['surgery_date']
    .to_dict()
)

donor_dict = (
    kidney_donor_df[['d_mrn', 'surgery_date_d']]
    .dropna(subset=['d_mrn'])
    .set_index('d_mrn')['surgery_date_d']
    .to_dict()
)

# Populate transplant_date with this priority order:
# 1. Liver
# 2. Kidney Recipient
# 3. Kidney Donor
df['transplant_date'] = (
    df['mrn'].map(liver_dict)                  # Liver first
    .combine_first(df['mrn'].map(recip_dict))       # then Recipient
    .combine_first(df['mrn'].map(donor_dict))       # then Donor
)

# Optional: Flag rows that still have no transplant date
# (uncomment when you're ready to implement review flagging)
# df.loc[df['transplant_date'].isna(), 'need_review'] = 'yes'

print("transplant_date column updated.")
print(f"Number of rows with transplant_date filled: {df['transplant_date'].notna().sum()}")
# Out:
# transplant_date column updated.
# Number of rows with transplant_date filled: 1577

# %%
# fill patient_type: if visit_date - transplant_date is minus, zero or the transplant_date is NaN -> pre
# if the visit_date - transplant_date. patient_type -> post

# Ensure both columns are datetime (safe, coercive)
visit_dt = pd.to_datetime(df["visit_datetime"], errors="coerce")
tx_dt = pd.to_datetime(df["transplant_date"], errors="coerce")

# Calculate day difference
df["days"] = (visit_dt - tx_dt).dt.days

# Overwrite patient_type based on rules
df.loc[tx_dt.isna(), "patient_type"] = "pre"
df.loc[tx_dt.notna() & (df["days"] <= 0), "patient_type"] = "pre"
df.loc[tx_dt.notna() & (df["days"] > 0), "patient_type"] = "post"

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        911
# Liver Recipient                                   450
# Pre Tx on workups                                 266
# Post living donor nephrectomy                     158
# Liver Donor                                       122
# Post DD Tx                                         98
# Waiting for first appointment                      50
# Listed on DDWL                                     40
# Pre Tx Ready for committee                         33
# Pre Tx Discussed & ready for donor nephrectomy     30
# Nephrology patient                                 21
# Initial visit done, No LD, suspended for DDWL      20
# Pre Tx Discussed & Ready for LD Tx                 18
# Listed on DDWL & Ready for LD Tx                   13
# Pre Tx Discussed with pending issues                9
# Pre Tx on hold                                      9
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df[df['r_d'] == 'Nephrology patient']
# Out:
#          mrn                             patengname pat_birthdate  \
# 27    176279              RADHI NASER HASAN ALHODAR    1946-05-31
# 102   201292           ALI IBRAHIM MOBARAK ABU ABSI    1968-09-23
# 312   156996                RANA ABDULLAH A ALHAMAM    1975-09-17
# 333   196863        MONEERAH NASSER SAAD ALSHAMMARI    1956-02-12
# 361   166481             ZAINAB ALI HUSSAIN AL NASR    1953-03-16
# 634   207593          SUWAID MESFER SWAID ALDOSSARI    1949-04-29
# 637    55000              ZYAD YOSAF SALEH ALDUHAHI    2005-06-18
# 649    13447              NARJES ABDULALI M ALSINAN    1956-02-12
# 698   115829          ZAHRA MOHAMMED AHMED ALWABARI    2016-05-09
# 714   168247           SEDRA FARAJ MOHAMMED ALANAZI    2021-01-26
# 1858  188122       ASAAD  ABDULAZIZ KHALF AL SHATAB    1965-10-21
# 1860   86311          KLIFAH RASHED HAMDAN ALRAHEEB    1949-04-29
# 1868   86311          KLIFAH RASHED HAMDAN ALRAHEEB    1949-04-29
# 1885  176618  RAHMAH ABDULRAZAQ ABDULHADI AL HAMMAD    1984-09-10
# 2116   57005             SAAD SALAH    SAAD   ALMAL    1995-06-30
# 2119   46523              MAY HUSSAIN SAAD ALMUSLIM    1975-07-20
# 2419  172516               Ahmad Ali Hadi AlQahtani    1954-03-06
# 2490  212836              NAWAL SAUD ALI ALSHAMMARI    1968-09-23
# 2823   55299             SAMIRA MOHAMMED ALI DEARIA    1956-08-14
# 2855  177052          NOUFAH OBAID ABDULLAH ALANAZI    1954-06-18
# 3160  172516               Ahmad Ali Hadi AlQahtani    1954-03-06
#
#      visit_datetime   visit_type visit_status    booking_type  \
# 27       2025-12-01           VV      STARTED  NORMAL BOOKING
# 102      2025-12-02           VV      STARTED  NORMAL BOOKING
# 312      2025-12-04          NEW      STARTED  NORMAL BOOKING
# 333      2025-12-30          NEW      STARTED  NORMAL BOOKING
# 361      2025-12-02           VV      STARTED  NORMAL BOOKING
# 634      2025-12-08          NEW      STARTED  NORMAL BOOKING
# 637      2025-12-10          NEW      STARTED  NORMAL BOOKING
# 649      2025-12-03          NEW      STARTED  NORMAL BOOKING
# 698      2025-12-01          NEW      STARTED  NORMAL BOOKING
# 714      2025-12-15          NEW      STARTED  NORMAL BOOKING
# 1858     2025-12-01           VV      STARTED  NORMAL BOOKING
# 1860     2025-12-16          NEW      STARTED  NORMAL BOOKING
# 1868     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 1885     2025-12-01          NEW      STARTED  NORMAL BOOKING
# 2116     2025-12-11          NEW      STARTED  NORMAL BOOKING
# 2119     2025-12-28          NEW      STARTED  NORMAL BOOKING
# 2419     2025-12-14    FOLLOW UP      STARTED  NORMAL BOOKING
# 2490     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 2823     2025-12-01  CHART CHECK      STARTED         WALK-IN
# 2855     2025-12-02      Walk-In      STARTED         WALK-IN
# 3160     2025-12-24    FOLLOW UP      STARTED  NORMAL BOOKING
#
#                                     clinic_name  \
# 27                           Clinical Nutrition
# 102                          Clinical Nutrition
# 312                          Clinical Nutrition
# 333                          Clinical Nutrition
# 361                          Clinical Nutrition
# 634                          Clinical Nutrition
# 637                          Clinical Nutrition
# 649                          Clinical Nutrition
# 698                                  Anesthesia
# 714                          Clinical Nutrition
# 1858                         Clinical Nutrition
# 1860                         Clinical Nutrition
# 1868                         Clinical Nutrition
# 1885                         Clinical Nutrition
# 2116                                 Anesthesia
# 2119                                 Anesthesia
# 2419                         TRANSPLANT SURGERY
# 2490                                 Anesthesia
# 2823  Adult Pre Renal Transplant Virtual Clinic
# 2855                                 Anesthesia
# 3160                         TRANSPLANT SURGERY
#
#                                         mrp liver_r_d liver_status  \
# 27           Ebtisam Hassan Husain Al-Ghawi       NaN          NaN
# 102          Ebtisam Hassan Husain Al-Ghawi       NaN          NaN
# 312                     Nihad Ali  Al_Ahmed       NaN          NaN
# 333                     Nihad Ali  Al_Ahmed       NaN          NaN
# 361                     Nihad Ali  Al_Ahmed       NaN          NaN
# 634            Fatima Abdullah Ali Al-Sinan       NaN          NaN
# 637            Fatima Abdullah Ali Al-Sinan       NaN          NaN
# 649            Fatima Abdullah Ali Al-Sinan       NaN          NaN
# 698   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 714               Fatimah Mansoor  Al Faraj       NaN          NaN
# 1858           RAWAN OLAYAN OBAIAD ALOLAYAN       NaN          NaN
# 1860           RAWAN OLAYAN OBAIAD ALOLAYAN       NaN          NaN
# 1868           RAWAN OLAYAN OBAIAD ALOLAYAN       NaN          NaN
# 1885           RAWAN OLAYAN OBAIAD ALOLAYAN       NaN          NaN
# 2116  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 2119  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 2419              MAHMOUD ALI MAHMOUD OBEID       NaN          NaN
# 2490  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 2823            NAGEEB ASHOOR SALEM MUSAIAD       NaN          NaN
# 2855  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 3160              MAHMOUD ALI MAHMOUD OBEID       NaN          NaN
#
#         kidney_recipient kidney_donor need_review                 r_d  \
# 27    Nephrology patient          NaN          no  Nephrology patient
# 102   Nephrology patient          NaN          no  Nephrology patient
# 312   Nephrology patient          NaN          no  Nephrology patient
# 333   Nephrology patient          NaN          no  Nephrology patient
# 361   Nephrology patient          NaN          no  Nephrology patient
# 634   Nephrology patient          NaN          no  Nephrology patient
# 637   Nephrology patient          NaN          no  Nephrology patient
# 649   Nephrology patient          NaN          no  Nephrology patient
# 698   Nephrology patient          NaN          no  Nephrology patient
# 714   Nephrology patient          NaN          no  Nephrology patient
# 1858  Nephrology patient          NaN          no  Nephrology patient
# 1860  Nephrology patient          NaN          no  Nephrology patient
# 1868  Nephrology patient          NaN          no  Nephrology patient
# 1885  Nephrology patient          NaN          no  Nephrology patient
# 2116  Nephrology patient          NaN          no  Nephrology patient
# 2119  Nephrology patient          NaN          no  Nephrology patient
# 2419  Nephrology patient          NaN          no  Nephrology patient
# 2490  Nephrology patient          NaN          no  Nephrology patient
# 2823  Nephrology patient          NaN          no  Nephrology patient
# 2855  Nephrology patient          NaN          no  Nephrology patient
# 3160  Nephrology patient          NaN          no  Nephrology patient
#
#      patient_type transplant_date    days
# 27            pre             NaT     NaN
# 102           pre             NaT     NaN
# 312           pre             NaT     NaN
# 333           pre             NaT     NaN
# 361           pre             NaT     NaN
# 634           pre             NaT     NaN
# 637           pre             NaT     NaN
# 649           pre             NaT     NaN
# 698           pre             NaT     NaN
# 714           pre             NaT     NaN
# 1858          pre             NaT     NaN
# 1860          pre             NaT     NaN
# 1868          pre             NaT     NaN
# 1885          pre             NaT     NaN
# 2116         post      2012-04-29  4974.0
# 2119          pre             NaT     NaN
# 2419          pre             NaT     NaN
# 2490          pre             NaT     NaN
# 2823          pre             NaT     NaN
# 2855          pre             NaT     NaN
# 3160          pre             NaT     NaN

# %%
df['liver_status'].value_counts()
# Out:
# liver_status
# Post Tx                        366
# Hepatology patient             111
# Pre Tx on workups               82
# New patient                     47
# Pre Tx ready for transplant     24
# OPD Hepatology patient          16
# Pre Tx on DDWL                  16
# Pre Tx Ready for transplant      6
# Hepatitis C patient              2
# Pre Tx on hold                   2
# Name: count, dtype: int64

# %%
df['patient_type'].value_counts()
# Out:
# patient_type
# post                 1391
# pre                   881
# Post Tx                17
# Post LD Tx             11
# Post DD Tx              2
# Pre Tx on workups       1
# Name: count, dtype: int64

# %%
df.head(50)
# Out:
#         mrn                              patengname pat_birthdate  \
# 7    174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9     77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12   104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13   101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17     6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
# 18    66898         AMNA AHMED ABDULGAFOR AL SHEIKH    1984-01-04
# 19   208799                   FARZANAH SAEED A  ALI    1963-07-01
# 20   220797                 BASHAYER FAWAZ  ALSAEGR    1992-04-17
# 21   220503  ALHASSAN ABDULRAHIM ABDULLAH ALZAHRANI    1999-08-20
# 22   220468                    SAAD SALEM M ALMAHRI    1986-03-17
# 23   220993      IBRAHIM ABDULKARIM IBRAHIM ALHABIB    1993-09-13
# 27   176279               RADHI NASER HASAN ALHODAR    1946-05-31
# 56    69581            AHMED MOHAMMED QASEM ALHARBI    1991-09-12
# 102  201292            ALI IBRAHIM MOBARAK ABU ABSI    1968-09-23
# 121   91287         NURAH ABDULMONEM AHMED ALFADHLI    2009-04-05
# 122   77466        ALBATUL HASSAN MUSALLAM ALBATHER    2011-11-13
# 125  220299          LANA NASSER MOHAMMED ALMUTAIRI    2025-06-20
# 126  220296                    AYAH ALI AHMED ASIRI    2023-06-26
# 127  217873            ELYAS ZUHDI ABDALLAH ELAYYAN    2024-11-04
# 129  194221             MISK MOHAMMED RADHI ALANAZI    2022-08-02
# 130  142741              AHMED JABER JUHRAN ALMALKI    2017-05-19
# 131  206092          IBRAHIM MOHAMMED IBRAHIM HAMDI    2022-11-22
# 134  201371           AMIRAH AHMED SAEED ALSHAHRANI    2024-04-24
# 135  201315    ABDULRAHMAN HUSSAIN ALI AL BOKHUDHER    2023-03-20
# 136  196993          ABDULLAH ALI MUDAYNI ALOTHAYQI    2023-01-11
# 139  190214           KAYAN MOHAMMED ALI ALDARWEESH    2022-09-27
# 141  188843             HOOR MOHAMMED TAHER ALBASRI    2023-04-06
# 142  187523           TARAF ABDULLAH HUSSAIN ALSABI    2016-06-06
# 143   54041             REFAH HAMAD SALEH ALDOSSARI    1975-07-28
# 148   97290        ANAS MUKHLED DHAIFALLAH ALSULAMI    2009-08-02
# 149   77466        ALBATUL HASSAN MUSALLAM ALBATHER    2011-11-13
# 150   77466        ALBATUL HASSAN MUSALLAM ALBATHER    2011-11-13
# 151  220299          LANA NASSER MOHAMMED ALMUTAIRI    2025-06-20
# 153  103345        ZAINAB HUSSAIN MOHAMMED MUSAQLEB    2009-10-02
# 160  191182    ABDULRAHMAN BANADR MOHAMMED AL ENEZI    2019-12-06
# 161  182051                 RASIL ABDU SIDDIQ OTAYN    2012-11-17
# 162  181881      RAWAN ABDULLAH ABDULMOHSEN ALHARBI    2022-08-23
# 166  152685            NADIR Sarrah MUAITH AL QARNI    2009-03-24
# 167  152211        ABDULLAH HAMED ABDULLAH ALJEDANI    2017-06-27
# 169  192234          HUSAIN MOHAMMED JABER ALASSIRY    2015-12-11
# 170  129193           NASSER MOHMMD NASSER ALHELEEW    2016-03-13
# 171  140366        HAIDAR YOUSEF MOHAMMED ALHULAYMI    2019-07-20
# 173  174704          IBRAHIM TALAL IBRAHIM ALFEHAID    2021-08-26
# 181  196684       FATIMAH HAIDAR NASSER AL SUWAYDAH    2023-11-07
# 183  152741               ELAF HASSAN HABIB  ALSAIF    2020-05-09
# 185  173480         ALI HUSSAIN ABDULKARIM AL AHMED    2021-10-24
# 187  201798         ABDULAZIZ AHMED  IBRAHIM HAJAZI    2024-02-08
# 188  146859             FAWAZ MASFER SAEED AL QASEM    2018-07-31
# 190  162497            BASSAM FAHAD KHATEM ALHARTHI    2014-12-10
# 191   99983         ZAINAB NASSIR ABDULLAH AL MAREI    2015-10-06
#
#     visit_datetime visit_type visit_status    booking_type  \
# 7       2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9       2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12      2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13      2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17      2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
# 18      2025-12-10  FOLLOW UP      ARRIVED  NORMAL BOOKING
# 19      2025-12-15  FOLLOW UP      STARTED  NORMAL BOOKING
# 20      2025-12-10    Walk-In      STARTED         WALK-IN
# 21      2025-12-10    Walk-In      STARTED         WALK-IN
# 22      2025-12-10    Walk-In      STARTED         WALK-IN
# 23      2025-12-10    Walk-In      STARTED         WALK-IN
# 27      2025-12-01         VV      STARTED  NORMAL BOOKING
# 56      2025-12-07        NEW      STARTED  NORMAL BOOKING
# 102     2025-12-02         VV      STARTED  NORMAL BOOKING
# 121     2025-12-24        NEW      STARTED  NORMAL BOOKING
# 122     2025-12-31         VV      STARTED  NORMAL BOOKING
# 125     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 126     2025-12-03         VV      STARTED  NORMAL BOOKING
# 127     2025-12-17        NEW      STARTED  NORMAL BOOKING
# 129     2025-12-31        NEW      STARTED  NORMAL BOOKING
# 130     2025-12-18        NEW      STARTED  NORMAL BOOKING
# 131     2025-12-24         VV      STARTED  NORMAL BOOKING
# 134     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 135     2025-12-07        NEW      STARTED  NORMAL BOOKING
# 136     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 139     2025-12-03         VV      STARTED  NORMAL BOOKING
# 141     2025-12-24        NEW      STARTED  NORMAL BOOKING
# 142     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 143     2025-12-29        NEW      STARTED  NORMAL BOOKING
# 148     2025-12-28         VV      STARTED  NORMAL BOOKING
# 149     2025-12-03        NEW      STARTED  NORMAL BOOKING
# 150     2025-12-15        NEW      STARTED  NORMAL BOOKING
# 151     2025-12-02         VV      STARTED  NORMAL BOOKING
# 153     2025-12-07        NEW      STARTED  NORMAL BOOKING
# 160     2025-12-03        NEW      STARTED  NORMAL BOOKING
# 161     2025-12-17        NEW      STARTED  NORMAL BOOKING
# 162     2025-12-31         VV      STARTED  NORMAL BOOKING
# 166     2025-12-24         VV      STARTED  NORMAL BOOKING
# 167     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 169     2025-12-21        NEW      STARTED  NORMAL BOOKING
# 170     2025-12-31         VV      STARTED  NORMAL BOOKING
# 171     2025-12-31         VV      STARTED  NORMAL BOOKING
# 173     2025-12-31         VV      STARTED  NORMAL BOOKING
# 181     2025-12-21        NEW      STARTED  NORMAL BOOKING
# 183     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 185     2025-12-07        NEW      STARTED  NORMAL BOOKING
# 187     2025-12-24         VV      STARTED  NORMAL BOOKING
# 188     2025-12-07        NEW      STARTED  NORMAL BOOKING
# 190     2025-12-24        NEW      STARTED  NORMAL BOOKING
# 191     2025-12-21        NEW      STARTED  NORMAL BOOKING
#
#                      clinic_name                                     mrp  \
# 7    Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                     Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 18            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 19            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 20            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 21            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 22            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 23            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 27            Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 56            Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 102           Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 121           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 122           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 125           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 126           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 127           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 129           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 130           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 131           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 134           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 135           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 136           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 139           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 141           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 142           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 143           Clinical Nutrition             Fatimah Abdullah  AlIbrahim
# 148           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 149           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 150           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 151           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 153           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 160           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 161           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 162           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 166           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 167           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 169           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 170           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 171           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 173           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 181           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 183           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 185           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 187           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 188           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 190           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 191           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
#
#      liver_r_d                 liver_status  \
# 7          NaN                          NaN
# 9          NaN                          NaN
# 12   Recipient           Hepatology patient
# 13         NaN                          NaN
# 17         NaN                          NaN
# 18         NaN                          NaN
# 19         NaN                          NaN
# 20       Donor  Pre Tx ready for transplant
# 21       Donor                      Post Tx
# 22       Donor                      Post Tx
# 23       Donor  Pre Tx ready for transplant
# 27         NaN                          NaN
# 56         NaN                          NaN
# 102        NaN                          NaN
# 121        NaN                          NaN
# 122        NaN                          NaN
# 125  Recipient                  New patient
# 126        NaN                          NaN
# 127  Recipient                      Post Tx
# 129  Recipient                      Post Tx
# 130        NaN                          NaN
# 131        NaN                          NaN
# 134  Recipient                      Post Tx
# 135        NaN                          NaN
# 136  Recipient                      Post Tx
# 139  Recipient                      Post Tx
# 141  Recipient           Hepatology patient
# 142        NaN                          NaN
# 143  Recipient           Hepatology patient
# 148        NaN                          NaN
# 149        NaN                          NaN
# 150        NaN                          NaN
# 151  Recipient                  New patient
# 153        NaN                          NaN
# 160        NaN                          NaN
# 161        NaN                          NaN
# 162  Recipient                      Post Tx
# 166        NaN                          NaN
# 167  Recipient                      Post Tx
# 169  Recipient                      Post Tx
# 170  Recipient           Hepatology patient
# 171  Recipient                      Post Tx
# 173  Recipient                      Post Tx
# 181  Recipient                      Post Tx
# 183  Recipient                      Post Tx
# 185  Recipient                  New patient
# 187  Recipient                      Post Tx
# 188        NaN                          NaN
# 190  Recipient                      Post Tx
# 191  Recipient                      Post Tx
#
#                          kidney_recipient kidney_donor need_review  \
# 7                              Post LD Tx          NaN          no
# 9                              Post DD Tx          NaN          no
# 12                             Post DD Tx          NaN          no
# 13                             Post LD Tx          NaN          no
# 17                             Post LD Tx          NaN          no
# 18                             Post LD Tx          NaN          no
# 19                             Post LD Tx          NaN          no
# 20                                    NaN          NaN          no
# 21                                    NaN          NaN          no
# 22                                    NaN          NaN          no
# 23                                    NaN          NaN          no
# 27                     Nephrology patient          NaN          no
# 56                             Post LD Tx          NaN          no
# 102                    Nephrology patient          NaN          no
# 121                            Post DD Tx          NaN          no
# 122  Pre Tx Discussed with pending issues          NaN          no
# 125                                   NaN          NaN          no
# 126                     Pre Tx on workups          NaN          no
# 127                                   NaN          NaN          no
# 129                    Nephrology patient          NaN          no
# 130                            Post LD Tx          NaN          no
# 131                     Pre Tx on workups          NaN          no
# 134                                   NaN          NaN          no
# 135                            Post LD Tx          NaN          no
# 136                                   NaN          NaN          no
# 139                                   NaN          NaN          no
# 141                                   NaN          NaN          no
# 142                            Post LD Tx          NaN          no
# 143                                   NaN          NaN          no
# 148                            Post LD Tx          NaN          no
# 149  Pre Tx Discussed with pending issues          NaN          no
# 150  Pre Tx Discussed with pending issues          NaN          no
# 151                                   NaN          NaN          no
# 153                            Post LD Tx          NaN          no
# 160                            Post LD Tx          NaN          no
# 161                            Post LD Tx          NaN          no
# 162                                   NaN          NaN          no
# 166                        Listed on DDWL          NaN          no
# 167                                   NaN          NaN          no
# 169                                   NaN          NaN          no
# 170                                   NaN          NaN          no
# 171                                   NaN          NaN          no
# 173                                   NaN          NaN          no
# 181                    Nephrology patient          NaN          no
# 183                                   NaN          NaN          no
# 185                                   NaN          NaN          no
# 187                                   NaN          NaN          no
# 188                        Listed on DDWL          NaN          no
# 190                    Nephrology patient          NaN          no
# 191                                   NaN          NaN          no
#
#                                       r_d patient_type transplant_date    days
# 7                              Post LD Tx         post      2025-11-26    27.0
# 9                              Post DD Tx         post      2016-04-24  3524.0
# 12                                    NaN         post      2020-11-07  1859.0
# 13                             Post LD Tx         post      2022-01-08  1436.0
# 17                             Post LD Tx         post      2007-06-06  6773.0
# 18                             Post LD Tx         post      2012-08-27  4853.0
# 19                             Post LD Tx         post      2025-11-24    21.0
# 20                            Liver Donor          pre             NaT     NaN
# 21                            Liver Donor          pre      2025-12-16    -6.0
# 22                            Liver Donor          pre      2025-12-15    -5.0
# 23                            Liver Donor          pre             NaT     NaN
# 27                     Nephrology patient          pre             NaT     NaN
# 56                             Post LD Tx         post      2012-12-16  4739.0
# 102                    Nephrology patient          pre             NaT     NaN
# 121                            Post DD Tx         post      2015-07-02  3828.0
# 122  Pre Tx Discussed with pending issues          pre             NaT     NaN
# 125                       Liver Recipient          pre             NaT     NaN
# 126                     Pre Tx on workups          pre             NaT     NaN
# 127                       Liver Recipient         post      2025-10-09    69.0
# 129                                   NaN         post      2024-02-01   699.0
# 130                            Post LD Tx         post      2025-09-01   108.0
# 131                     Pre Tx on workups          pre             NaT     NaN
# 134                       Liver Recipient         post      2025-01-22   340.0
# 135                            Post LD Tx         post      2025-03-10   272.0
# 136                       Liver Recipient         post      2025-07-07   174.0
# 139                       Liver Recipient         post      2024-08-30   460.0
# 141                       Liver Recipient          pre             NaT     NaN
# 142                            Post LD Tx         post      2024-09-11   459.0
# 143                       Liver Recipient          pre             NaT     NaN
# 148                            Post LD Tx         post      2024-12-18   375.0
# 149  Pre Tx Discussed with pending issues          pre             NaT     NaN
# 150  Pre Tx Discussed with pending issues          pre             NaT     NaN
# 151                       Liver Recipient          pre             NaT     NaN
# 153                            Post LD Tx         post      2017-10-10  2980.0
# 160                            Post LD Tx         post      2023-10-31   764.0
# 161                            Post LD Tx         post      2023-08-23   847.0
# 162                       Liver Recipient         post      2023-06-14   931.0
# 166                        Listed on DDWL          pre             NaT     NaN
# 167                       Liver Recipient         post      2020-09-05  1940.0
# 169                       Liver Recipient         post      2023-12-17   735.0
# 170                       Liver Recipient          pre             NaT     NaN
# 171                       Liver Recipient         post      2024-03-04   667.0
# 173                       Liver Recipient         post      2022-12-28  1099.0
# 181                                   NaN         post      2025-09-03   109.0
# 183                       Liver Recipient         post      2021-03-18  1732.0
# 185                       Liver Recipient          pre             NaT     NaN
# 187                       Liver Recipient         post      2025-08-21   125.0
# 188                        Listed on DDWL          pre             NaT     NaN
# 190                                   NaN         post      2023-04-06   993.0
# 191                       Liver Recipient         post      2016-12-22  3286.0

# %%
# Final patient_type classification logic
#
# This step overwrites patient_type (which initially contains only "pre" / "post")
# and assigns a final clinical category using transplant context and liver status.
#
# Priority order (top to bottom – first match wins):
#
# 1) Hepatology override:
#    If liver_status contains any of:
#       - "hepatology"
#       - "hepatitis"
#       - "new patients"
#    → patient_type = "Hepatology"
#
# 2) Liver transplant context:
#    If r_d contains "liver":
#       - patient_type == "post" → "Post-Liver Tx"
#       - patient_type == "pre"  → "Pre-Liver Tx"
#
# 3) Nephrology (non-transplant):
#    If r_d contains "nephrology":
#       → patient_type = "Nephrology"
#
# 4) Kidney transplant context:
#    If r_d is present AND does NOT contain "liver" or "nephrology":
#       - patient_type == "post" → "Post-Kidney Tx"
#       - patient_type == "pre"  → "Pre-Kidney Tx"
#
# 5) Final fallback:
#    Any remaining rows → "Pre-Kidney Tx"
#
# Notes:
# - Matching is case-insensitive
# - Rules are mutually exclusive and applied in strict priority order
# - This mirrors the quality department’s manual classification logic



import numpy as np


# Prepare case-insensitive conditions
r_d_lower = df['r_d'].fillna('').str.lower()
liver_status_lower = df['liver_status'].fillna('').str.lower()

# ── Priority conditions (applied top → bottom) ───────────────────────────────

# Priority 1: Hepatology override (absolute)
is_hepatology = liver_status_lower.str.contains('hepatology|hepatitis|new patients', na=False)

# Priority 2: Liver transplant context
is_liver_context = r_d_lower.str.contains('liver', na=False)
is_post = df['patient_type'] == 'post'
is_pre  = df['patient_type'] == 'pre'

# Priority 3: Nephrology (non-transplant)
is_nephrology = r_d_lower.str.contains('nephrology', na=False)

# Priority 4: Kidney transplant context
# (has r_d value, but not liver & not nephrology)
is_kidney_context = (
    df['r_d'].notna() &
    ~is_liver_context &
    ~is_nephrology
)

# ── Apply rules in strict priority order using np.select ─────────────────────

conditions = [
    is_hepatology,                                      # 1. Hepatology override
    is_liver_context & is_post,                         # 2. Post-Liver Tx
    is_liver_context & is_pre,                          # 2. Pre-Liver Tx
    is_nephrology,                                      # 3. Nephrology
    is_kidney_context & is_post,                        # 4. Post-Kidney Tx
    is_kidney_context & is_pre,                         # 4. Pre-Kidney Tx
]

choices = [
    "Hepatology",
    "Post-Liver Tx",
    "Pre-Liver Tx",
    "Nephrology",
    "Post-Kidney Tx",
    "Pre-Kidney Tx",
]

df['patient_type'] = np.select(conditions, choices, default="Pre-Kidney Tx")

# %%
df['patient_type'].value_counts()
# Out:
# patient_type
# Post-Kidney Tx    1030
# Pre-Kidney Tx      630
# Post-Liver Tx      286
# Pre-Liver Tx       207
# Hepatology         129
# Nephrology          21
# Name: count, dtype: int64

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Adult Post Renal Transplant                    500
# TRANSPLANT SURGERY                             458
# Adult Post Kidney Transplant Virtual Clinic    264
# Adult Pre Renal Transplant                     133
# ADULT POST LIVER TRANSPLANT                    131
# Anesthesia                                     130
# Social Work                                    110
# Pediatric Post Renal Transplant                102
# Clinical Nutrition                              98
# Adult Pre Liver Transplant                      97
# Pediatric Liver Transplant                      66
# Transplant Dressing (procedure)                 54
# Psychology                                      47
# Adult Post Liver Transplant Virtual             42
# Adult Pre Renal Transplant Virtual Clinic       37
# Pre anesthesia liver transplant                 15
# Pediatric Pre Renal Transplant                  11
# Adult Pre Liver Transplant Virtual               5
# Transplant Cystoscopy Clinic                     3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                              patengname pat_birthdate  \
# 7   174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9    77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12  104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13  101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17    6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
#
#    visit_datetime visit_type visit_status    booking_type  \
# 7      2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9      2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12     2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17     2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
#
#                     clinic_name                                     mrp  \
# 7   Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
#
#     liver_r_d        liver_status kidney_recipient kidney_donor need_review  \
# 7         NaN                 NaN       Post LD Tx          NaN          no
# 9         NaN                 NaN       Post DD Tx          NaN          no
# 12  Recipient  Hepatology patient       Post DD Tx          NaN          no
# 13        NaN                 NaN       Post LD Tx          NaN          no
# 17        NaN                 NaN       Post LD Tx          NaN          no
#
#            r_d    patient_type transplant_date    days
# 7   Post LD Tx  Post-Kidney Tx      2025-11-26    27.0
# 9   Post DD Tx  Post-Kidney Tx      2016-04-24  3524.0
# 12         NaN      Hepatology      2020-11-07  1859.0
# 13  Post LD Tx  Post-Kidney Tx      2022-01-08  1436.0
# 17  Post LD Tx  Post-Kidney Tx      2007-06-06  6773.0

# %%
# Create lookup dictionaries: MRN → Age Group

liver_age_dict = (
    liver_df[['r_mrn', 'age_group']]
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['age_group']
    .to_dict()
)

recip_age_dict = (
    kidney_rec_df[['r_mrn', 'age_group']]
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['age_group']
    .to_dict()
)

donor_age_dict = (
    kidney_donor_df[['d_mrn', 'age_group_d']]
    .dropna(subset=['d_mrn'])
    .set_index('d_mrn')['age_group_d']
    .to_dict()
)

# Populate age_group with priority: Liver → Recipient → Donor
df['age_group'] = (
    df['mrn'].map(liver_age_dict)                # 1. Liver first
    .combine_first(df['mrn'].map(recip_age_dict))     # 2. Kidney Recipient
    .combine_first(df['mrn'].map(donor_age_dict))     # 3. Kidney Donor
)

# %%
df['age_group'].value_counts()
# Out:
# age_group
# Adult        2027
# Pediatric     267
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                              patengname pat_birthdate  \
# 7   174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9    77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12  104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13  101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17    6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
#
#    visit_datetime visit_type visit_status    booking_type  \
# 7      2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9      2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12     2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17     2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
#
#                     clinic_name                                     mrp  \
# 7   Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
#
#     liver_r_d        liver_status kidney_recipient kidney_donor need_review  \
# 7         NaN                 NaN       Post LD Tx          NaN          no
# 9         NaN                 NaN       Post DD Tx          NaN          no
# 12  Recipient  Hepatology patient       Post DD Tx          NaN          no
# 13        NaN                 NaN       Post LD Tx          NaN          no
# 17        NaN                 NaN       Post LD Tx          NaN          no
#
#            r_d    patient_type transplant_date    days age_group
# 7   Post LD Tx  Post-Kidney Tx      2025-11-26    27.0     Adult
# 9   Post DD Tx  Post-Kidney Tx      2016-04-24  3524.0     Adult
# 12         NaN      Hepatology      2020-11-07  1859.0     Adult
# 13  Post LD Tx  Post-Kidney Tx      2022-01-08  1436.0     Adult
# 17  Post LD Tx  Post-Kidney Tx      2007-06-06  6773.0     Adult

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Adult Post Renal Transplant                    500
# TRANSPLANT SURGERY                             458
# Adult Post Kidney Transplant Virtual Clinic    264
# Adult Pre Renal Transplant                     133
# ADULT POST LIVER TRANSPLANT                    131
# Anesthesia                                     130
# Social Work                                    110
# Pediatric Post Renal Transplant                102
# Clinical Nutrition                              98
# Adult Pre Liver Transplant                      97
# Pediatric Liver Transplant                      66
# Transplant Dressing (procedure)                 54
# Psychology                                      47
# Adult Post Liver Transplant Virtual             42
# Adult Pre Renal Transplant Virtual Clinic       37
# Pre anesthesia liver transplant                 15
# Pediatric Pre Renal Transplant                  11
# Adult Pre Liver Transplant Virtual               5
# Transplant Cystoscopy Clinic                     3
# Name: count, dtype: int64

# %%
df['patient_type'].value_counts()
# Out:
# patient_type
# Post-Kidney Tx    1030
# Pre-Kidney Tx      630
# Post-Liver Tx      286
# Pre-Liver Tx       207
# Hepatology         129
# Nephrology          21
# Name: count, dtype: int64

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        911
# Liver Recipient                                   450
# Pre Tx on workups                                 266
# Post living donor nephrectomy                     158
# Liver Donor                                       122
# Post DD Tx                                         98
# Waiting for first appointment                      50
# Listed on DDWL                                     40
# Pre Tx Ready for committee                         33
# Pre Tx Discussed & ready for donor nephrectomy     30
# Nephrology patient                                 21
# Initial visit done, No LD, suspended for DDWL      20
# Pre Tx Discussed & Ready for LD Tx                 18
# Listed on DDWL & Ready for LD Tx                   13
# Pre Tx Discussed with pending issues                9
# Pre Tx on hold                                      9
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                              patengname pat_birthdate  \
# 7   174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9    77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12  104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13  101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17    6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
#
#    visit_datetime visit_type visit_status    booking_type  \
# 7      2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9      2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12     2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17     2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
#
#                     clinic_name                                     mrp  \
# 7   Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
#
#     liver_r_d        liver_status kidney_recipient kidney_donor need_review  \
# 7         NaN                 NaN       Post LD Tx          NaN          no
# 9         NaN                 NaN       Post DD Tx          NaN          no
# 12  Recipient  Hepatology patient       Post DD Tx          NaN          no
# 13        NaN                 NaN       Post LD Tx          NaN          no
# 17        NaN                 NaN       Post LD Tx          NaN          no
#
#            r_d    patient_type transplant_date    days age_group
# 7   Post LD Tx  Post-Kidney Tx      2025-11-26    27.0     Adult
# 9   Post DD Tx  Post-Kidney Tx      2016-04-24  3524.0     Adult
# 12         NaN      Hepatology      2020-11-07  1859.0     Adult
# 13  Post LD Tx  Post-Kidney Tx      2022-01-08  1436.0     Adult
# 17  Post LD Tx  Post-Kidney Tx      2007-06-06  6773.0     Adult

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        911
# Liver Recipient                                   450
# Pre Tx on workups                                 266
# Post living donor nephrectomy                     158
# Liver Donor                                       122
# Post DD Tx                                         98
# Waiting for first appointment                      50
# Listed on DDWL                                     40
# Pre Tx Ready for committee                         33
# Pre Tx Discussed & ready for donor nephrectomy     30
# Nephrology patient                                 21
# Initial visit done, No LD, suspended for DDWL      20
# Pre Tx Discussed & Ready for LD Tx                 18
# Listed on DDWL & Ready for LD Tx                   13
# Pre Tx Discussed with pending issues                9
# Pre Tx on hold                                      9
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                              patengname pat_birthdate  \
# 7   174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9    77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12  104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13  101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17    6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
#
#    visit_datetime visit_type visit_status    booking_type  \
# 7      2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9      2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12     2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17     2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
#
#                     clinic_name                                     mrp  \
# 7   Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
#
#     liver_r_d        liver_status kidney_recipient kidney_donor need_review  \
# 7         NaN                 NaN       Post LD Tx          NaN          no
# 9         NaN                 NaN       Post DD Tx          NaN          no
# 12  Recipient  Hepatology patient       Post DD Tx          NaN          no
# 13        NaN                 NaN       Post LD Tx          NaN          no
# 17        NaN                 NaN       Post LD Tx          NaN          no
#
#            r_d    patient_type transplant_date    days age_group
# 7   Post LD Tx  Post-Kidney Tx      2025-11-26    27.0     Adult
# 9   Post DD Tx  Post-Kidney Tx      2016-04-24  3524.0     Adult
# 12         NaN      Hepatology      2020-11-07  1859.0     Adult
# 13  Post LD Tx  Post-Kidney Tx      2022-01-08  1436.0     Adult
# 17  Post LD Tx  Post-Kidney Tx      2007-06-06  6773.0     Adult

# %%
df[df['patient_type'] == 'Hepatology'][30:50]
# Out:
#          mrn                              patengname pat_birthdate  \
# 1181  189072               JABER YAHIA SALEM ALMALKI    1969-04-16
# 1224  221032        Basmah  Abdulrazaq   Abdulrahman    1993-01-01
# 1230  195166             HASSAN MAHMOOD OMAR HAWSAWI    1962-10-05
# 1237  176215  Fatimah   Saeed   Abdullah   Al Baggal    1992-02-16
# 1239  220244         KHULUD ABDULLAH DHAFER ALOTAIBI    1985-03-22
# 1331  218286           ABDULKAREEM ZAYED ALI ALWASHI    2000-01-01
# 1370  122652              RAWAN AHMED NASSAR ALATAWI    2007-04-03
# 1383  120889              AMMAR DHAFER SAAD ALALYANI    2015-11-26
# 1393   52498             RAWAF AHMED YOUSEF  ALJALAL    2010-03-25
# 1395   53033       ANWAR MOHAMMED ABDULLAH ALSWAILMI    2007-11-21
# 1401    1470        KHALED SAEED BIN AWADH ALQAHTANI    1986-04-26
# 1403  174705     Fuad Soliman Abdulrahman Al Soliman    1974-09-14
# 1411  210542           ALMAHA KHALED AYEDH ALQAHTANI    2006-06-18
# 1417  208624              QUDS SAMIR MOHAMMAD ALHLAL    2000-09-22
# 1422  151279      MAMDOUH ABDLLUAH IBRAHIM AL MAJHAD    1974-11-18
# 1423  213165         HAMIDAH HUSSAIN BIN ALI ALHAJJI    1974-07-20
# 1424  217727                 AIED MOHAMMAD M ALHAZMI    1978-01-21
# 1426  220244         KHULUD ABDULLAH DHAFER ALOTAIBI    1985-03-22
# 1428  212720             SAIF SAAD MOHAMMED ALSAWYAF    1984-06-13
# 1566  103350             NORAH MAHDI MOHAMMED ALYAMI    1964-11-05
#
#      visit_datetime   visit_type visit_status    booking_type  \
# 1181     2025-12-15    FOLLOW UP      STARTED  NORMAL BOOKING
# 1224     2025-12-09          NEW      STARTED  NORMAL BOOKING
# 1230     2025-12-02    FOLLOW UP      STARTED  NORMAL BOOKING
# 1237     2025-12-22          NEW      STARTED  NORMAL BOOKING
# 1239     2025-12-15    FOLLOW UP      STARTED  NORMAL BOOKING
# 1331     2025-12-24      Walk-In      STARTED         WALK-IN
# 1370     2025-12-08  CHART CHECK      STARTED         WALK-IN
# 1383     2025-12-11  CHART CHECK      STARTED         WALK-IN
# 1393     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 1395     2025-12-07  CHART CHECK      STARTED         WALK-IN
# 1401     2025-12-30    FOLLOW UP      STARTED  NORMAL BOOKING
# 1403     2025-12-21    FOLLOW UP      STARTED  NORMAL BOOKING
# 1411     2025-12-09    FOLLOW UP      STARTED  NORMAL BOOKING
# 1417     2025-12-23  V Follow UP      STARTED  NORMAL BOOKING
# 1422     2025-12-07    FOLLOW UP      STARTED  NORMAL BOOKING
# 1423     2025-12-08    FOLLOW UP      STARTED  NORMAL BOOKING
# 1424     2025-12-01    FOLLOW UP      STARTED  NORMAL BOOKING
# 1426     2025-12-22  V Follow UP      STARTED  NORMAL BOOKING
# 1428     2025-12-01    FOLLOW UP      STARTED  NORMAL BOOKING
# 1566     2025-12-30      Walk-In      STARTED         WALK-IN
#
#                              clinic_name  \
# 1181          Adult Pre Liver Transplant
# 1224          Adult Pre Liver Transplant
# 1230          Adult Pre Liver Transplant
# 1237          Adult Pre Liver Transplant
# 1239          Adult Pre Liver Transplant
# 1331         Adult Post Renal Transplant
# 1370     Pediatric Post Renal Transplant
# 1383     Pediatric Post Renal Transplant
# 1393     Pediatric Post Renal Transplant
# 1395     Pediatric Post Renal Transplant
# 1401          Adult Pre Liver Transplant
# 1403          Adult Pre Liver Transplant
# 1411          Adult Pre Liver Transplant
# 1417  Adult Pre Liver Transplant Virtual
# 1422          Adult Pre Liver Transplant
# 1423          Adult Pre Liver Transplant
# 1424          Adult Pre Liver Transplant
# 1426  Adult Pre Liver Transplant Virtual
# 1428          Adult Pre Liver Transplant
# 1566         Adult Post Renal Transplant
#
#                                          mrp  liver_r_d        liver_status  \
# 1181     Eyad Mohammad Osman Elhassan Gadour  Recipient  Hepatology patient
# 1224                 NOORA HASSAN B AL FARAJ  Recipient  Hepatology patient
# 1230                 NOORA HASSAN B AL FARAJ  Recipient  Hepatology patient
# 1237     Eyad Mohammad Osman Elhassan Gadour  Recipient  Hepatology patient
# 1239     Eyad Mohammad Osman Elhassan Gadour  Recipient  Hepatology patient
# 1331        MAHER MOHAMMED RAFAT ALDEMERDASH  Recipient  Hepatology patient
# 1370          ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 1383       Mohammed Abdulmoatani  Almaghrabi  Recipient  Hepatology patient
# 1393          ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 1395          ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 1401                 NOORA HASSAN B AL FARAJ  Recipient  Hepatology patient
# 1403              HADI MOHAMMED SHOEI KURIRY  Recipient  Hepatology patient
# 1411                 NOORA HASSAN B AL FARAJ  Recipient  Hepatology patient
# 1417                 NOORA HASSAN B AL FARAJ  Recipient  Hepatology patient
# 1422              HADI MOHAMMED SHOEI KURIRY  Recipient  Hepatology patient
# 1423     Eyad Mohammad Osman Elhassan Gadour  Recipient  Hepatology patient
# 1424     Eyad Mohammad Osman Elhassan Gadour  Recipient  Hepatology patient
# 1426     Eyad Mohammad Osman Elhassan Gadour  Recipient  Hepatology patient
# 1428     Eyad Mohammad Osman Elhassan Gadour  Recipient  Hepatology patient
# 1566  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI  Recipient  Hepatology patient
#
#      kidney_recipient kidney_donor need_review              r_d patient_type  \
# 1181       Post LD Tx          NaN          no  Liver Recipient   Hepatology
# 1224              NaN          NaN          no  Liver Recipient   Hepatology
# 1230              NaN          NaN          no  Liver Recipient   Hepatology
# 1237              NaN          NaN          no  Liver Recipient   Hepatology
# 1239              NaN          NaN          no  Liver Recipient   Hepatology
# 1331       Post LD Tx          NaN          no       Post LD Tx   Hepatology
# 1370       Post LD Tx          NaN          no       Post LD Tx   Hepatology
# 1383       Post LD Tx          NaN          no       Post LD Tx   Hepatology
# 1393       Post LD Tx          NaN          no       Post LD Tx   Hepatology
# 1395       Post DD Tx          NaN          no       Post DD Tx   Hepatology
# 1401              NaN          NaN          no  Liver Recipient   Hepatology
# 1403              NaN          NaN          no  Liver Recipient   Hepatology
# 1411              NaN          NaN          no  Liver Recipient   Hepatology
# 1417              NaN          NaN          no  Liver Recipient   Hepatology
# 1422              NaN          NaN          no  Liver Recipient   Hepatology
# 1423              NaN          NaN          no  Liver Recipient   Hepatology
# 1424              NaN          NaN          no  Liver Recipient   Hepatology
# 1426              NaN          NaN          no  Liver Recipient   Hepatology
# 1428              NaN          NaN          no  Liver Recipient   Hepatology
# 1566       Post LD Tx          NaN          no       Post LD Tx   Hepatology
#
#      transplant_date    days  age_group
# 1181      2025-11-06    39.0      Adult
# 1224             NaT     NaN      Adult
# 1230             NaT     NaN      Adult
# 1237             NaT     NaN      Adult
# 1239             NaT     NaN      Adult
# 1331      2025-11-17    37.0      Adult
# 1370      2025-11-25    13.0  Pediatric
# 1383      2019-04-29  2418.0  Pediatric
# 1393      2024-12-24   370.0  Pediatric
# 1395      2011-12-05  5116.0  Pediatric
# 1401             NaT     NaN      Adult
# 1403             NaT     NaN      Adult
# 1411             NaT     NaN      Adult
# 1417             NaT     NaN      Adult
# 1422             NaT     NaN      Adult
# 1423             NaT     NaN      Adult
# 1424             NaT     NaN      Adult
# 1426             NaT     NaN      Adult
# 1428             NaT     NaN      Adult
# 1566      2025-12-21     9.0      Adult

# %%
# Final logic for correcting / filling r_d column
# Rules applied in this strict top-to-bottom priority order:

# 1. If patient_type == "Hepatology"
#    → r_d = "Liver Recipient"

# 2. If patient_type == "Nephrology"
#    → r_d = "Kidney Recipient"

# 3. If patient_type in ["Post-Liver Tx", "Pre-Liver Tx"]
#    → keep the current r_d value as-is 
#      (it should already be either "Liver Recipient" or "Liver Donor")

# 4. If patient_type in ["Post-Kidney Tx", "Pre-Kidney Tx"]
#    → Decision order:
#      - If kidney_recipient is NOT NULL → r_d = "Kidney Recipient"
#      - Else if kidney_donor is NOT NULL   → r_d = "Kidney Donor"
#      - Else (both kidney_recipient AND kidney_donor are NULL)
#        → keep current r_d value unchanged
#        → AND set need_review = "yes" (change from default "no")

# All other cases: keep current r_d (though in practice should be covered above)

# Notes:
# - Liver cases trust existing r_d (already cleaned correctly)
# - Kidney cases prefer recipient status when available
# - Only flag for manual review when there's true ambiguity 
#   (no clear kidney role in source registry columns)


# 1. Hepatology & Nephrology overrides
hepatology_mask = df['patient_type'] == "Hepatology"
nephrology_mask = df['patient_type'] == "Nephrology"

df.loc[hepatology_mask, 'r_d'] = "Liver Recipient"
df.loc[nephrology_mask, 'r_d'] = "Kidney Recipient"

# 2. Liver cases - keep current r_d (no change needed)

# 3. Kidney transplant cases (Post & Pre)
kidney_tx_mask = df['patient_type'].isin(["Post-Kidney Tx", "Pre-Kidney Tx"])

# Sub-conditions for kidney cases
has_recipient = df['kidney_recipient'].notna()
has_donor     = df['kidney_donor'].notna()

# Apply preference: Recipient > Donor > keep current
df.loc[kidney_tx_mask & has_recipient, 'r_d'] = "Kidney Recipient"
df.loc[kidney_tx_mask & ~has_recipient & has_donor, 'r_d'] = "Kidney Donor"

# 4. Ambiguous kidney cases → flag for review
ambiguous_kidney = (
    kidney_tx_mask & 
    ~has_recipient & 
    ~has_donor
)

df.loc[ambiguous_kidney, 'need_review'] = "yes"

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Adult Post Renal Transplant                    500
# TRANSPLANT SURGERY                             458
# Adult Post Kidney Transplant Virtual Clinic    264
# Adult Pre Renal Transplant                     133
# ADULT POST LIVER TRANSPLANT                    131
# Anesthesia                                     130
# Social Work                                    110
# Pediatric Post Renal Transplant                102
# Clinical Nutrition                              98
# Adult Pre Liver Transplant                      97
# Pediatric Liver Transplant                      66
# Transplant Dressing (procedure)                 54
# Psychology                                      47
# Adult Post Liver Transplant Virtual             42
# Adult Pre Renal Transplant Virtual Clinic       37
# Pre anesthesia liver transplant                 15
# Pediatric Pre Renal Transplant                  11
# Adult Pre Liver Transplant Virtual               5
# Transplant Cystoscopy Clinic                     3
# Name: count, dtype: int64

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Kidney Recipient    1265
# Liver Recipient      516
# Kidney Donor         391
# Liver Donor          122
# Name: count, dtype: int64

# %%
# Logic for creating the new 'clinic' column
# Rules are applied in order - first matching condition wins (top-to-bottom priority)

# All string matching is:
# - case-insensitive
# - partial contains (anywhere in the clinic_name string)

# 1. If clinic_name contains "renal" or "kidney"
#    → clinic = "Kidney Tx"

# 2. Else if clinic_name contains any of:
#    - "pediatric liver transplant"
#    - "adult pre liver transplant"
#    - "adult post liver transplant"
#    → clinic = "liver Tx"

# 3. Else if clinic_name contains "anesthesia"
#    → Check r_d (case-insensitive contains):
#      - if r_d contains "kidney" → clinic = "Anesthesia-Kidney"
#      - if r_d contains "liver"  → clinic = "Anesthesia-Liver"
#      - if neither → clinic remains NaN

# 4. Else if clinic_name contains "transplant urology" or "transplant cystoscopy clinic"
#    → clinic = "Urology"

# 5. Else if clinic_name contains "clinical nutrition"
#    → clinic = "Nutrition"

# 6. Else if clinic_name contains "transplant dressing (procedure)"
#    → clinic = "Surgery-Dressing"

# 7. Else if clinic_name contains "transplant surgery"
#    → Check r_d (case-insensitive contains):
#      - if r_d contains "kidney" → clinic = "Surgery-Kidney"
#      - else → clinic = "Surgery-Liver"

# 8. Else if clinic_name contains "psychology"
#    → clinic = "Psychology"

# 9. Else if clinic_name contains "social work"
#    → clinic = "Social Work"

# 10. Fallback (no match above)
#     → clinic remains NaN



# Make sure clinic_name is string and handle NaN
df['clinic_name'] = df['clinic_name'].astype(str).fillna('')

# Prepare lowercase versions for matching
clinic_lower = df['clinic_name'].str.lower()
rd_lower     = df['r_d'].fillna('').str.lower()

# Initialize the new column
df['clinic'] = pd.NA

# 1. Kidney Tx (renal or kidney)
mask_kidney = clinic_lower.str.contains('renal|kidney', na=False)
df.loc[mask_kidney, 'clinic'] = 'Kidney Tx'

# 2. Liver Tx (specific phrases)
mask_liver_specific = clinic_lower.str.contains(
    'pediatric liver transplant|adult pre liver transplant|adult post liver transplant',
    na=False
)
df.loc[mask_liver_specific & df['clinic'].isna(), 'clinic'] = 'liver Tx'

# 3. Anesthesia cases
mask_anesthesia = clinic_lower.str.contains('anesthesia', na=False)
df.loc[mask_anesthesia & df['clinic'].isna(), 'clinic'] = pd.NA  # default

df.loc[
    mask_anesthesia & df['clinic'].isna() & rd_lower.str.contains('kidney'),
    'clinic'
] = 'Anesthesia-Kidney'

df.loc[
    mask_anesthesia & df['clinic'].isna() & rd_lower.str.contains('liver'),
    'clinic'
] = 'Anesthesia-Liver'

# 4. Urology
mask_urology = clinic_lower.str.contains('transplant urology|transplant cystoscopy clinic', na=False)
df.loc[mask_urology & df['clinic'].isna(), 'clinic'] = 'Urology'

# 5. Nutrition
mask_nutrition = clinic_lower.str.contains('clinical nutrition', na=False)
df.loc[mask_nutrition & df['clinic'].isna(), 'clinic'] = 'Nutrition'

# 6. Surgery Dressing
mask_dressing = clinic_lower.str.contains('transplant dressing (procedure)', na=False)
df.loc[mask_dressing & df['clinic'].isna(), 'clinic'] = 'Surgery-Dressing'

# 7. Transplant Surgery
mask_surgery = clinic_lower.str.contains('transplant surgery', na=False)
df.loc[mask_surgery & df['clinic'].isna(), 'clinic'] = 'Surgery-Liver'  # default for surgery

df.loc[
    mask_surgery & df['clinic'].isna() & rd_lower.str.contains('kidney'),
    'clinic'
] = 'Surgery-Kidney'

# 8. Psychology
mask_psych = clinic_lower.str.contains('psychology', na=False)
df.loc[mask_psych & df['clinic'].isna(), 'clinic'] = 'Psychology'

# 9. Social Work
mask_social = clinic_lower.str.contains('social work', na=False)
df.loc[mask_social & df['clinic'].isna(), 'clinic'] = 'Social Work'
# Out:
# /var/folders/67/spj008b90s1d1nmg1kfhfrzw0000gn/T/ipykernel_83722/3488552905.py:92: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask_dressing = clinic_lower.str.contains('transplant dressing (procedure)', na=False)
