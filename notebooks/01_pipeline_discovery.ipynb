# %% [markdown]
# # Excel Quality Pipeline – Discovery Notebook
#
# ## Objective
# Build a reproducible data pipeline that produces a single cleaned
# quality dataset from multiple Excel inputs.
#
# This notebook is for exploration and validation only.
# Final logic will be migrated into the `src/` module.

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
file_path = "../data/raw/PATIENT OPD VISITS- from MCC & Email.xlsx"
df = pd.read_excel(file_path)
df.shape
# Out:
# (4204, 18)

# %%
header = df.columns.tolist()

# %%
print(header)
# Out:
# ['MRN', 'PatEngName', 'pat_birthdate', 'regtime', 'VISIT_DATETIME', 'ARRIVETIME', 'STARTTIME', 'VISIT_TYPE', 'PORTAL STATUS', 'VISIT STATUS', 'BOOKING_TYPE', 'clinic_key', 'CLINIC_NAME', 'MRP', 'JOB TITLE', 'SPECIALTY', 'Added_by', 'addtime']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4204 entries, 0 to 4203
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MRN             4204 non-null   int64
#  1   PatEngName      4094 non-null   object
#  2   pat_birthdate   4047 non-null   datetime64[ns]
#  3   regtime         4204 non-null   datetime64[ns]
#  4   VISIT_DATETIME  4047 non-null   datetime64[ns]
#  5   ARRIVETIME      3314 non-null   datetime64[ns]
#  6   STARTTIME       3208 non-null   datetime64[ns]
#  7   VISIT_TYPE      4204 non-null   object
#  8   PORTAL STATUS   4047 non-null   object
#  9   VISIT STATUS    4047 non-null   object
#  10  BOOKING_TYPE    4047 non-null   object
#  11  clinic_key      4047 non-null   float64
#  12  CLINIC_NAME     4204 non-null   object
#  13  MRP             4204 non-null   object
#  14  JOB TITLE       4047 non-null   object
#  15  SPECIALTY       4047 non-null   object
#  16  Added_by        4047 non-null   object
#  17  addtime         4047 non-null   datetime64[ns]
# dtypes: datetime64[ns](6), float64(1), int64(1), object(10)
# memory usage: 591.3+ KB

# %%
# Drop uneeded col
cols_to_drop = [
    "regtime",
    "ARRIVETIME",
    "STARTTIME",
    "PORTAL STATUS",
    "clinic_key",
    "JOB TITLE",
    "SPECIALTY",
    "Added_by",
    "addtime",
]

df = df.drop(columns=cols_to_drop)

# %%
df.columns
# Out:
# Index(['MRN', 'PatEngName', 'pat_birthdate', 'VISIT_DATETIME', 'VISIT_TYPE',
#        'VISIT STATUS', 'BOOKING_TYPE', 'CLINIC_NAME', 'MRP'],
#       dtype='object')

# %%
# Normalize column names
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)
df.columns
# Out:
# Index(['mrn', 'patengname', 'pat_birthdate', 'visit_datetime', 'visit_type',
#        'visit_status', 'booking_type', 'clinic_name', 'mrp'],
#       dtype='object')

# %%
df['visit_datetime'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# change col visit_datetime to datetime DD/MM/YYYY

df["visit_datetime"] = pd.to_datetime(
    df["visit_datetime"],
    errors="coerce"
).dt.date

# %%
df["visit_datetime"].dtype
type(df.loc[0, "visit_datetime"])
# Out:
# datetime.date

# %%
# Adding the new col

new_cols = [
    "liver_r_d",
    "liver_status",
    "kidney_recipient",
    "kidney_donor",
]

for col in new_cols:
    df[col] = None

df.columns
# Out:
# Index(['mrn', 'patengname', 'pat_birthdate', 'visit_datetime', 'visit_type',
#        'visit_status', 'booking_type', 'clinic_name', 'mrp', 'liver_r_d',
#        'liver_status', 'kidney_recipient', 'kidney_donor'],
#       dtype='object')

# %%
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  218455            NORAH BAHIAS ALI ZARAB    1987-04-16     2025-12-23
# 1  118631          ZAHRA MAHDI ALI ALAWAZIM    2003-02-24     2025-12-10
# 2  219640  SULTANAH HAMAD ABDULLAH ALHASSAN    1959-01-10     2025-12-08
# 3  220961   SEHAM MOHAMMED KHAMEES ALHASSAN    1969-06-03     2025-12-10
# 4  220533     ABDULAZIZ ADNAN SALEH ALHADAD    1978-09-30     2025-12-21
#
#   visit_type visit_status    booking_type clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 1        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 2        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 3        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 4        NEW      STARTED  NORMAL BOOKING  Anesthesia
#
#                                      mrp liver_r_d liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 1  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 2  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 4  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
#
#   kidney_recipient kidney_donor
# 0             None         None
# 1             None         None
# 2             None         None
# 3             None         None
# 4             None         None

# %%
df['visit_status'].value_counts()
# Out:
# visit_status
# STARTED    3208
# NO SHOW     733
# ARRIVED     106
# Name: count, dtype: int64

# %%
# Remove NO SHOW visit_status

df = df[df["visit_status"] != "NO SHOW"]

# %%
df['visit_status'].value_counts()
# Out:
# visit_status
# STARTED    3208
# ARRIVED     106
# Name: count, dtype: int64

# %%
# Fill liver columns using Liver Registry (ONLY)
# For each MRN in df:
# Look it up in Liver Registry
# If found:
###### Rec_Don → liver_r_d
###### Current Status1 → liver_status
# If not found:
##### leave as NaN

liver_df = pd.read_excel("../data/raw/Liver Registry - 1 JAN.xlsx")
liver_df.columns = (liver_df.columns.str.strip().str.lower().str.replace(" ", "_"))

# %%
liver_df.columns.tolist()
# Out:
# ['r_mrn',
#  'id_number',
#  'patient_name',
#  'mobile1_0',
#  'payment_0',
#  'rec_don',
#  'nationality',
#  'city_of_residence',
#  'specify_other',
#  'age_group',
#  'age',
#  'blood_group',
#  'gender',
#  'date_open_file_0',
#  'current_status1',
#  'patient_type_1',
#  'initial_tx_assessment_date',
#  'workup_start_date',
#  'workup_completed_date',
#  'date_added_to_waiting_list',
#  'surgery_date',
#  'tx_type',
#  'transplant_place',
#  'comment_0',
#  'closefile_r',
#  'closefiledate_r',
#  'closefilereason_r',
#  'assigned_consultant_0',
#  'assigned_surgeon_r',
#  'primary_disease']

# %%
df = df.merge(
    liver_df[["r_mrn", "rec_don", "current_status1"]],
    left_on="mrn",
    right_on="r_mrn",
    how="left"
)

# %%
df["liver_r_d"] = df["rec_don"]
df["liver_status"] = df["current_status1"]
df.tail()
# Out:
#          mrn  patengname pat_birthdate visit_datetime visit_type visit_status  \
# 3466  203844   Abdullah            NaT            NaT  Follow up          NaN
# 3467  221651   MOHAMMED            NaT            NaT        New          NaN
# 3468  221730  Abdulqawi            NaT            NaT        New          NaN
# 3469   40991     SHATHA            NaT            NaT        New          NaN
# 3470  107061   ABDULLAH            NaT            NaT        New          NaN
#
#      booking_type clinic_name            mrp  liver_r_d liver_status  \
# 3466          NaN  Psychology  Alia Al Enazi  Recipient      Post Tx
# 3467          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3468          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3469          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3470          NaN  Psychology  Alia Al Enazi        NaN          NaN
#
#      kidney_recipient kidney_donor   r_mrn    rec_don current_status1
# 3466             None         None  203844  Recipient         Post Tx
# 3467             None         None     NaN        NaN             NaN
# 3468             None         None     NaN        NaN             NaN
# 3469             None         None     NaN        NaN             NaN
# 3470             None         None     NaN        NaN             NaN

# %%
df = df.drop(columns=["r_mrn", "rec_don", "current_status1"])

# %%
df[df["liver_r_d"].notna()]
# Out:
#          mrn                              patengname pat_birthdate  \
# 12    104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 20    220797                 BASHAYER FAWAZ  ALSAEGR    1992-04-17
# 21    220503  ALHASSAN ABDULRAHIM ABDULLAH ALZAHRANI    1999-08-20
# 22    220468                    SAAD SALEM M ALMAHRI    1986-03-17
# 23    220993      IBRAHIM ABDULKARIM IBRAHIM ALHABIB    1993-09-13
# ...      ...                                     ...           ...
# 3454  221422                                MESHARI            NaT
# 3455  221756                                  FAHAD            NaT
# 3456  218992                                 HISSAH            NaT
# 3461  221468                                   WADI            NaT
# 3466  203844                               Abdullah            NaT
#
#      visit_datetime visit_type visit_status    booking_type  \
# 12       2025-12-10        NEW      STARTED  NORMAL BOOKING
# 20       2025-12-10    Walk-In      STARTED         WALK-IN
# 21       2025-12-10    Walk-In      STARTED         WALK-IN
# 22       2025-12-10    Walk-In      STARTED         WALK-IN
# 23       2025-12-10    Walk-In      STARTED         WALK-IN
# ...             ...        ...          ...             ...
# 3454            NaT        New          NaN             NaN
# 3455            NaT        New          NaN             NaN
# 3456            NaT        New          NaN             NaN
# 3461            NaT        New          NaN             NaN
# 3466            NaT  Follow up          NaN             NaN
#
#              clinic_name                                    mrp  liver_r_d  \
# 12            Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID  Recipient
# 20    TRANSPLANT SURGERY           Mohammed Saad Ali AL-Qahtani      Donor
# 21    TRANSPLANT SURGERY           Mohammed Saad Ali AL-Qahtani      Donor
# 22    TRANSPLANT SURGERY           Mohammed Saad Ali AL-Qahtani      Donor
# 23    TRANSPLANT SURGERY           Mohammed Saad Ali AL-Qahtani      Donor
# ...                  ...                                    ...        ...
# 3454          Psychology                          Alia Al Enazi      Donor
# 3455          Psychology                          Alia Al Enazi      Donor
# 3456          Psychology                          Alia Al Enazi  Recipient
# 3461          Psychology                          Alia Al Enazi      Donor
# 3466          Psychology                          Alia Al Enazi  Recipient
#
#                      liver_status kidney_recipient kidney_donor
# 12             Hepatology patient             None         None
# 20    Pre Tx ready for transplant             None         None
# 21                        Post Tx             None         None
# 22                        Post Tx             None         None
# 23    Pre Tx ready for transplant             None         None
# ...                           ...              ...          ...
# 3454            Pre Tx on workups             None         None
# 3455            Pre Tx on workups             None         None
# 3456            Pre Tx on workups             None         None
# 3461            Pre Tx on workups             None         None
# 3466                      Post Tx             None         None
#
# [672 rows x 13 columns]

# %%
# Fill kidney_recipient using Kidney Recipient registry (ONLY)
# For each mrn in the main df:
# Look it up in Kidney Recipient - 1 JAN.xlsx

# If found:
###### copy Current Status1 → kidney_recipient
# If not found:
###### leave as NaN

kidney_rec_df = pd.read_excel("../data/raw/Kidney Recipient - 1 JAN.xlsx")
kidney_rec_df.columns = (kidney_rec_df.columns.str.strip().str.lower().str.replace(" ", "_"))

# %%
df = df.merge(
    kidney_rec_df[["r_mrn", "current_status1"]],
    left_on="mrn",
    right_on="r_mrn",
    how="left"
)
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  218455            NORAH BAHIAS ALI ZARAB    1987-04-16     2025-12-23
# 1  118631          ZAHRA MAHDI ALI ALAWAZIM    2003-02-24     2025-12-10
# 2  219640  SULTANAH HAMAD ABDULLAH ALHASSAN    1959-01-10     2025-12-08
# 3  220961   SEHAM MOHAMMED KHAMEES ALHASSAN    1969-06-03     2025-12-10
# 4  220533     ABDULAZIZ ADNAN SALEH ALHADAD    1978-09-30     2025-12-21
#
#   visit_type visit_status    booking_type clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 1        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 2        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 3        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 4        NEW      STARTED  NORMAL BOOKING  Anesthesia
#
#                                      mrp liver_r_d liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 1  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 2  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 4  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
#
#   kidney_recipient kidney_donor  r_mrn current_status1
# 0             None         None    NaN             NaN
# 1             None         None    NaN             NaN
# 2             None         None    NaN             NaN
# 3             None         None    NaN             NaN
# 4             None         None    NaN             NaN

# %%
df["kidney_recipient"] = df["current_status1"]
df = df.drop(columns=["r_mrn", "current_status1"])

# %%
df.tail()
# Out:
#          mrn  patengname pat_birthdate visit_datetime visit_type visit_status  \
# 3466  203844   Abdullah            NaT            NaT  Follow up          NaN
# 3467  221651   MOHAMMED            NaT            NaT        New          NaN
# 3468  221730  Abdulqawi            NaT            NaT        New          NaN
# 3469   40991     SHATHA            NaT            NaT        New          NaN
# 3470  107061   ABDULLAH            NaT            NaT        New          NaN
#
#      booking_type clinic_name            mrp  liver_r_d liver_status  \
# 3466          NaN  Psychology  Alia Al Enazi  Recipient      Post Tx
# 3467          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3468          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3469          NaN  Psychology  Alia Al Enazi        NaN          NaN
# 3470          NaN  Psychology  Alia Al Enazi        NaN          NaN
#
#         kidney_recipient kidney_donor
# 3466  Nephrology patient         None
# 3467                 NaN         None
# 3468                 NaN         None
# 3469                 NaN         None
# 3470          Post LD Tx         None

# %%
# Fill kidney_donor
# For each mrn in the main df:
# Match it to d_mrn in Kidney Donor - 1 JAN.xlsx
# Copy current_status1_d → kidney_donor
# If no match → leave NaN

kidney_donor_df = pd.read_excel("../data/raw/Kidney Donor - 1 JAN.xlsx")

kidney_donor_df.columns = (
    kidney_donor_df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
)

df = df.merge(
    kidney_donor_df[["d_mrn", "current_status1_d"]],
    left_on="mrn",
    right_on="d_mrn",
    how="left"
)

df["kidney_donor"] = df["current_status1_d"]

df = df.drop(columns=["d_mrn", "current_status1_d"])

# %%
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  218455            NORAH BAHIAS ALI ZARAB    1987-04-16     2025-12-23
# 1  118631          ZAHRA MAHDI ALI ALAWAZIM    2003-02-24     2025-12-10
# 2  219640  SULTANAH HAMAD ABDULLAH ALHASSAN    1959-01-10     2025-12-08
# 3  220961   SEHAM MOHAMMED KHAMEES ALHASSAN    1969-06-03     2025-12-10
# 4  220533     ABDULAZIZ ADNAN SALEH ALHADAD    1978-09-30     2025-12-21
#
#   visit_type visit_status    booking_type clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 1        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 2        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 3        NEW      STARTED  NORMAL BOOKING  Anesthesia
# 4        NEW      STARTED  NORMAL BOOKING  Anesthesia
#
#                                      mrp liver_r_d liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 1  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 2  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
# 4  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID       NaN          NaN
#
#   kidney_recipient kidney_donor
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Anesthesia                                     840
# Clinical Nutrition                             556
# Adult Post Renal Transplant                    500
# TRANSPLANT SURGERY                             458
# Adult Post Kidney Transplant Virtual Clinic    264
# Adult Pre Renal Transplant                     133
# ADULT POST LIVER TRANSPLANT                    131
# Social Work                                    110
# Pediatric Post Renal Transplant                102
# Adult Pre Liver Transplant                      97
# Pediatric Liver Transplant                      66
# Transplant Dressing (procedure)                 54
# Psychology                                      47
# Adult Post Liver Transplant Virtual             42
# Adult Pre Renal Transplant Virtual Clinic       37
# Pre anesthesia liver transplant                 15
# Pediatric Pre Renal Transplant                  11
# Adult Pre Liver Transplant Virtual               5
# Transplant Cystoscopy Clinic                     3
# Name: count, dtype: int64

# %%
# Remove visits based on clinic + transplant status (ONLY)

# Remove row if ALL of the following are true:

# 1-clinic_name is Anesthesia OR Clinical Nutrition
# 2- liver_r_d is NaN
# 3-kidney_recipient is NaN
# 4-kidney_donor is NaN

mask = (
    df["clinic_name"].isin(["Anesthesia", "Clinical Nutrition"])
    & df["liver_r_d"].isna()
    & df["kidney_recipient"].isna()
    & df["kidney_donor"].isna()
)

df = df[~mask]

# %%
df[
    df["clinic_name"].isin(["Anesthesia", "Clinical Nutrition"])
][["liver_r_d", "kidney_recipient", "kidney_donor"]].isna().all(axis=1).sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#        mrn                              patengname pat_birthdate  \
# 7   174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9    77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12  104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13  101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17    6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
#
#    visit_datetime visit_type visit_status    booking_type  \
# 7      2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9      2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12     2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17     2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
#
#                     clinic_name                                     mrp  \
# 7   Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
#
#     liver_r_d        liver_status kidney_recipient kidney_donor
# 7         NaN                 NaN       Post LD Tx          NaN
# 9         NaN                 NaN       Post DD Tx          NaN
# 12  Recipient  Hepatology patient       Post DD Tx          NaN
# 13        NaN                 NaN       Post LD Tx          NaN
# 17        NaN                 NaN       Post LD Tx          NaN

# %%
df[df[["liver_r_d", "kidney_recipient", "kidney_donor"]].isna().all(axis=1)]
# Out:
#          mrn                          patengname pat_birthdate visit_datetime  \
# 530    13459        SHAIKHAH MOHAMMED A ALSAMHAN    1940-08-04     2025-12-15
# 1166  221813   MOHAMMAD MOQBIL ABDULLAH ALQARAWI    1959-01-10     2025-12-28
# 1169  218567      REEM ABDULHAKIM HAMAD ALKHALDI    2010-07-14     2025-12-02
# 2335    8909  BANEEN ABDULLAH MOHAMMED ALSAIHATI    1986-05-17     2025-12-29
# 2744  200160       AHMED MOHAMED ALY AHMED ZIDAN    1981-07-25     2025-12-31
# 2756    6097            REHAB AHMED GABER ABDALL    1978-06-10     2025-12-28
# 3018  220426          SALMAN OMAR JAFAR ALOTAIBI    1986-09-14     2025-12-09
# 3041  200362                      NISY   MATHEWS    1998-08-15     2025-12-16
# 3170  210421                      Devika   Reghu    1996-05-04     2025-12-29
#
#        visit_type visit_status    booking_type                 clinic_name  \
# 530           NEW      STARTED  NORMAL BOOKING  Adult Pre Liver Transplant
# 1166          NEW      STARTED  NORMAL BOOKING  Adult Pre Liver Transplant
# 1169      Walk-In      STARTED         WALK-IN  Pediatric Liver Transplant
# 2335    FOLLOW UP      STARTED  NORMAL BOOKING          TRANSPLANT SURGERY
# 2744  CHART CHECK      STARTED         WALK-IN          TRANSPLANT SURGERY
# 2756  CHART CHECK      STARTED         WALK-IN          TRANSPLANT SURGERY
# 3018      Walk-In      STARTED         WALK-IN          TRANSPLANT SURGERY
# 3041      Walk-In      STARTED         WALK-IN  Adult Pre Renal Transplant
# 3170      Walk-In      STARTED         WALK-IN          TRANSPLANT SURGERY
#
#                                       mrp liver_r_d liver_status  \
# 530   Eyad Mohammad Osman Elhassan Gadour       NaN          NaN
# 1166           HADI MOHAMMED SHOEI KURIRY       NaN          NaN
# 1169      Razan Monther Abdulmajied Bader       NaN          NaN
# 2335            MAHMOUD ALI MAHMOUD OBEID       NaN          NaN
# 2744        AHMED MOHAMED ALY AHMED ZIDAN       NaN          NaN
# 2756        AHMED MOHAMED ALY AHMED ZIDAN       NaN          NaN
# 3018         Mohammed Saad Ali AL-Qahtani       NaN          NaN
# 3041          KHALID AHMEDH BELEED AKKARI       NaN          NaN
# 3170            MAHMOUD ALI MAHMOUD OBEID       NaN          NaN
#
#      kidney_recipient kidney_donor
# 530               NaN          NaN
# 1166              NaN          NaN
# 1169              NaN          NaN
# 2335              NaN          NaN
# 2744              NaN          NaN
# 2756              NaN          NaN
# 3018              NaN          NaN
# 3041              NaN          NaN
# 3170              NaN          NaN

# %%
# Add need_review flag
df["need_review"] = "no"
review_mask = (
    df[["liver_r_d", "kidney_recipient", "kidney_donor"]]
    .isna()
    .all(axis=1)
)

df.loc[review_mask, "need_review"] = "yes"

# %%
df['liver_r_d'].value_counts()
# Out:
# liver_r_d
# Recipient    547
# Donor        125
# Name: count, dtype: int64

# %%
# Create and fill r_d (LOCKED LOGIC)

# We look at three columns:
#liver_r_d, kidney_recipient, kidney_donor
# A) If only one of the three is non-NaN:
# Only liver_r_d filled → r_d = "Liver " + liver_r_d
# Only kidney_recipient filled → r_d = kidney_recipient
# Only kidney_donor filled → r_d = kidney_donor
# B) If liver_r_d is non-NaN AND (either kidney_recipient OR kidney_donor is non-NaN):
# Use clinic_name keyword:
# If clinic_name contains renal or kidney → r_d becomes the non-NaN kidney value (recipient preferred, else donor)
# If clinic_name contains liver → r_d = "Liver " + liver_r_d

# Vectorized version
mask_liver_only = df['liver_r_d'].notna() & df['kidney_recipient'].isna() & df['kidney_donor'].isna()
mask_k_recip_only = df['kidney_recipient'].notna() & df['liver_r_d'].isna() & df['kidney_donor'].isna()
mask_k_donor_only = df['kidney_donor'].notna() & df['liver_r_d'].isna() & df['kidney_recipient'].isna()

df['r_d'] = np.select(
    [
        mask_liver_only,
        mask_k_recip_only,
        mask_k_donor_only,
    ],
    [
        "Liver " + df['liver_r_d'].astype(str),
        df['kidney_recipient'],
        df['kidney_donor']
    ],
    default=np.nan
)

# Now handle mixed cases (where liver + at least one kidney is present)
mixed_mask = (
    df['liver_r_d'].notna() &
    (df['kidney_recipient'].notna() | df['kidney_donor'].notna()) &
    (df['r_d'].isna())  # still null after previous step
)

clinic_lower = df['clinic_name'].fillna('').str.lower()

renal_clinic = clinic_lower.str.contains('renal|kidney')
liver_clinic = clinic_lower.str.contains('liver')

df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'r_d'] = \
    df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'kidney_recipient'].fillna(
        df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'kidney_donor']
    )

df.loc[mixed_mask & liver_clinic & ~renal_clinic, 'r_d'] = \
    "Liver " + df.loc[mixed_mask & liver_clinic & ~renal_clinic, 'liver_r_d'].astype(str)

# %%
df.head()
# Out:
#        mrn                              patengname pat_birthdate  \
# 7   174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9    77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12  104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13  101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17    6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
#
#    visit_datetime visit_type visit_status    booking_type  \
# 7      2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9      2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12     2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17     2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
#
#                     clinic_name                                     mrp  \
# 7   Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                   Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
#
#     liver_r_d        liver_status kidney_recipient kidney_donor need_review  \
# 7         NaN                 NaN       Post LD Tx          NaN          no
# 9         NaN                 NaN       Post DD Tx          NaN          no
# 12  Recipient  Hepatology patient       Post DD Tx          NaN          no
# 13        NaN                 NaN       Post LD Tx          NaN          no
# 17        NaN                 NaN       Post LD Tx          NaN          no
#
#            r_d
# 7   Post LD Tx
# 9   Post DD Tx
# 12         NaN
# 13  Post LD Tx
# 17  Post LD Tx

# %%
df['liver_status'].value_counts()
# Out:
# liver_status
# Post Tx                        366
# Hepatology patient             111
# Pre Tx on workups               82
# New patient                     47
# Pre Tx ready for transplant     24
# OPD Hepatology patient          16
# Pre Tx on DDWL                  16
# Pre Tx Ready for transplant      6
# Hepatitis C patient              2
# Pre Tx on hold                   2
# Name: count, dtype: int64

# %%
# ambiguous_mask = (
#     df['liver_r_d'].notna() &
#     (df['kidney_recipient'].notna() | df['kidney_donor'].notna()) &
#     df['r_d'].isna()
# )

# len(df.loc[ambiguous_mask])

# come to this later at the end to see how many should be assigned as need review
df.head(30)
# Out:
#         mrn                              patengname pat_birthdate  \
# 7    174153                  AYSH ABDO HAMAD HADIDI    1955-02-23
# 9     77521            AMAL SULAIMAN OUDAH ALHAWITI    1986-09-28
# 12   104431                     SAIF RAJA H ALHAJRI    1976-06-28
# 13   101282            NOUF SAUD MOHAMMED ALDAWSARI    1982-11-29
# 17     6364  MOHAMMED BEN ALI BIN SULAIMAN AL JAFAR    1982-08-20
# 18    66898         AMNA AHMED ABDULGAFOR AL SHEIKH    1984-01-04
# 19   208799                   FARZANAH SAEED A  ALI    1963-07-01
# 20   220797                 BASHAYER FAWAZ  ALSAEGR    1992-04-17
# 21   220503  ALHASSAN ABDULRAHIM ABDULLAH ALZAHRANI    1999-08-20
# 22   220468                    SAAD SALEM M ALMAHRI    1986-03-17
# 23   220993      IBRAHIM ABDULKARIM IBRAHIM ALHABIB    1993-09-13
# 27   176279               RADHI NASER HASAN ALHODAR    1946-05-31
# 56    69581            AHMED MOHAMMED QASEM ALHARBI    1991-09-12
# 102  201292            ALI IBRAHIM MOBARAK ABU ABSI    1968-09-23
# 121   91287         NURAH ABDULMONEM AHMED ALFADHLI    2009-04-05
# 122   77466        ALBATUL HASSAN MUSALLAM ALBATHER    2011-11-13
# 125  220299          LANA NASSER MOHAMMED ALMUTAIRI    2025-06-20
# 126  220296                    AYAH ALI AHMED ASIRI    2023-06-26
# 127  217873            ELYAS ZUHDI ABDALLAH ELAYYAN    2024-11-04
# 129  194221             MISK MOHAMMED RADHI ALANAZI    2022-08-02
# 130  142741              AHMED JABER JUHRAN ALMALKI    2017-05-19
# 131  206092          IBRAHIM MOHAMMED IBRAHIM HAMDI    2022-11-22
# 134  201371           AMIRAH AHMED SAEED ALSHAHRANI    2024-04-24
# 135  201315    ABDULRAHMAN HUSSAIN ALI AL BOKHUDHER    2023-03-20
# 136  196993          ABDULLAH ALI MUDAYNI ALOTHAYQI    2023-01-11
# 139  190214           KAYAN MOHAMMED ALI ALDARWEESH    2022-09-27
# 141  188843             HOOR MOHAMMED TAHER ALBASRI    2023-04-06
# 142  187523           TARAF ABDULLAH HUSSAIN ALSABI    2016-06-06
# 143   54041             REFAH HAMAD SALEH ALDOSSARI    1975-07-28
# 148   97290        ANAS MUKHLED DHAIFALLAH ALSULAMI    2009-08-02
#
#     visit_datetime visit_type visit_status    booking_type  \
# 7       2025-12-23  FOLLOW UP      STARTED  NORMAL BOOKING
# 9       2025-12-17        NEW      STARTED  NORMAL BOOKING
# 12      2025-12-10        NEW      STARTED  NORMAL BOOKING
# 13      2025-12-14        NEW      STARTED  NORMAL BOOKING
# 17      2025-12-21  FOLLOW UP      STARTED  NORMAL BOOKING
# 18      2025-12-10  FOLLOW UP      ARRIVED  NORMAL BOOKING
# 19      2025-12-15  FOLLOW UP      STARTED  NORMAL BOOKING
# 20      2025-12-10    Walk-In      STARTED         WALK-IN
# 21      2025-12-10    Walk-In      STARTED         WALK-IN
# 22      2025-12-10    Walk-In      STARTED         WALK-IN
# 23      2025-12-10    Walk-In      STARTED         WALK-IN
# 27      2025-12-01         VV      STARTED  NORMAL BOOKING
# 56      2025-12-07        NEW      STARTED  NORMAL BOOKING
# 102     2025-12-02         VV      STARTED  NORMAL BOOKING
# 121     2025-12-24        NEW      STARTED  NORMAL BOOKING
# 122     2025-12-31         VV      STARTED  NORMAL BOOKING
# 125     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 126     2025-12-03         VV      STARTED  NORMAL BOOKING
# 127     2025-12-17        NEW      STARTED  NORMAL BOOKING
# 129     2025-12-31        NEW      STARTED  NORMAL BOOKING
# 130     2025-12-18        NEW      STARTED  NORMAL BOOKING
# 131     2025-12-24         VV      STARTED  NORMAL BOOKING
# 134     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 135     2025-12-07        NEW      STARTED  NORMAL BOOKING
# 136     2025-12-28        NEW      STARTED  NORMAL BOOKING
# 139     2025-12-03         VV      STARTED  NORMAL BOOKING
# 141     2025-12-24        NEW      STARTED  NORMAL BOOKING
# 142     2025-12-14        NEW      STARTED  NORMAL BOOKING
# 143     2025-12-29        NEW      STARTED  NORMAL BOOKING
# 148     2025-12-28         VV      STARTED  NORMAL BOOKING
#
#                      clinic_name                                     mrp  \
# 7    Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 9                     Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 12                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 13                    Anesthesia   MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 17            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 18            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 19            TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 20            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 21            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 22            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 23            TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 27            Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 56            Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 102           Clinical Nutrition          Ebtisam Hassan Husain Al-Ghawi
# 121           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 122           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 125           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 126           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 127           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 129           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 130           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 131           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 134           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 135           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 136           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 139           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 141           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 142           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
# 143           Clinical Nutrition             Fatimah Abdullah  AlIbrahim
# 148           Clinical Nutrition             Marwah Abdullah  Al-Mubarak
#
#      liver_r_d                 liver_status  \
# 7          NaN                          NaN
# 9          NaN                          NaN
# 12   Recipient           Hepatology patient
# 13         NaN                          NaN
# 17         NaN                          NaN
# 18         NaN                          NaN
# 19         NaN                          NaN
# 20       Donor  Pre Tx ready for transplant
# 21       Donor                      Post Tx
# 22       Donor                      Post Tx
# 23       Donor  Pre Tx ready for transplant
# 27         NaN                          NaN
# 56         NaN                          NaN
# 102        NaN                          NaN
# 121        NaN                          NaN
# 122        NaN                          NaN
# 125  Recipient                  New patient
# 126        NaN                          NaN
# 127  Recipient                      Post Tx
# 129  Recipient                      Post Tx
# 130        NaN                          NaN
# 131        NaN                          NaN
# 134  Recipient                      Post Tx
# 135        NaN                          NaN
# 136  Recipient                      Post Tx
# 139  Recipient                      Post Tx
# 141  Recipient           Hepatology patient
# 142        NaN                          NaN
# 143  Recipient           Hepatology patient
# 148        NaN                          NaN
#
#                          kidney_recipient kidney_donor need_review  \
# 7                              Post LD Tx          NaN          no
# 9                              Post DD Tx          NaN          no
# 12                             Post DD Tx          NaN          no
# 13                             Post LD Tx          NaN          no
# 17                             Post LD Tx          NaN          no
# 18                             Post LD Tx          NaN          no
# 19                             Post LD Tx          NaN          no
# 20                                    NaN          NaN          no
# 21                                    NaN          NaN          no
# 22                                    NaN          NaN          no
# 23                                    NaN          NaN          no
# 27                     Nephrology patient          NaN          no
# 56                             Post LD Tx          NaN          no
# 102                    Nephrology patient          NaN          no
# 121                            Post DD Tx          NaN          no
# 122  Pre Tx Discussed with pending issues          NaN          no
# 125                                   NaN          NaN          no
# 126                     Pre Tx on workups          NaN          no
# 127                                   NaN          NaN          no
# 129                    Nephrology patient          NaN          no
# 130                            Post LD Tx          NaN          no
# 131                     Pre Tx on workups          NaN          no
# 134                                   NaN          NaN          no
# 135                            Post LD Tx          NaN          no
# 136                                   NaN          NaN          no
# 139                                   NaN          NaN          no
# 141                                   NaN          NaN          no
# 142                            Post LD Tx          NaN          no
# 143                                   NaN          NaN          no
# 148                            Post LD Tx          NaN          no
#
#                                       r_d
# 7                              Post LD Tx
# 9                              Post DD Tx
# 12                                    NaN
# 13                             Post LD Tx
# 17                             Post LD Tx
# 18                             Post LD Tx
# 19                             Post LD Tx
# 20                            Liver Donor
# 21                            Liver Donor
# 22                            Liver Donor
# 23                            Liver Donor
# 27                     Nephrology patient
# 56                             Post LD Tx
# 102                    Nephrology patient
# 121                            Post DD Tx
# 122  Pre Tx Discussed with pending issues
# 125                       Liver Recipient
# 126                     Pre Tx on workups
# 127                       Liver Recipient
# 129                                   NaN
# 130                            Post LD Tx
# 131                     Pre Tx on workups
# 134                       Liver Recipient
# 135                            Post LD Tx
# 136                       Liver Recipient
# 139                       Liver Recipient
# 141                       Liver Recipient
# 142                            Post LD Tx
# 143                       Liver Recipient
# 148                            Post LD Tx

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        911
# Liver Recipient                                   450
# Pre Tx on workups                                 266
# Post living donor nephrectomy                     158
# Liver Donor                                       122
# Post DD Tx                                         98
# Waiting for first appointment                      50
# Listed on DDWL                                     40
# Pre Tx Ready for committee                         33
# Pre Tx Discussed & ready for donor nephrectomy     30
# Nephrology patient                                 21
# Initial visit done, No LD, suspended for DDWL      20
# Pre Tx Discussed & Ready for LD Tx                 18
# Listed on DDWL & Ready for LD Tx                   13
# Pre Tx Discussed with pending issues                9
# Pre Tx on hold                                      9
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df["patient_type"] = None
df["transplant_date"] = None
df["days"] = None

# %%
df.head(1)
# Out:
#       mrn              patengname pat_birthdate visit_datetime visit_type  \
# 7  174153  AYSH ABDO HAMAD HADIDI    1955-02-23     2025-12-23  FOLLOW UP
#
#   visit_status    booking_type                  clinic_name  \
# 7      STARTED  NORMAL BOOKING  Adult Post Renal Transplant
#
#                                       mrp liver_r_d liver_status  \
# 7  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI       NaN          NaN
#
#   kidney_recipient kidney_donor need_review         r_d patient_type  \
# 7       Post LD Tx          NaN          no  Post LD Tx         None
#
#   transplant_date  days
# 7            None  None

# %%
df['patient_type'] = df['liver_status'].combine_first(
    df['kidney_recipient']
).combine_first(
    df['kidney_donor']
)

# %%
# if patient_type is NA i think need_revuew = yes

# %%
# Create lookup dictionaries: MRN → Surgery Date
# Using the actual column names from your files

liver_dict = (
    liver_df[['r_mrn', 'surgery_date']]
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['surgery_date']
    .to_dict()
)

recip_dict = (
    kidney_rec_df[['r_mrn', 'surgery_date']]           # ← using kidney_rec_df (your naming)
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['surgery_date']
    .to_dict()
)

donor_dict = (
    kidney_donor_df[['d_mrn', 'surgery_date_d']]
    .dropna(subset=['d_mrn'])
    .set_index('d_mrn')['surgery_date_d']
    .to_dict()
)

# Populate transplant_date with this priority order:
# 1. Liver
# 2. Kidney Recipient
# 3. Kidney Donor
df['transplant_date'] = (
    df['mrn'].map(liver_dict)                  # Liver first
    .combine_first(df['mrn'].map(recip_dict))       # then Recipient
    .combine_first(df['mrn'].map(donor_dict))       # then Donor
)

# Optional: Flag rows that still have no transplant date
# (uncomment when you're ready to implement review flagging)
# df.loc[df['transplant_date'].isna(), 'need_review'] = 'yes'

print("transplant_date column updated.")
print(f"Number of rows with transplant_date filled: {df['transplant_date'].notna().sum()}")
# Out:
# transplant_date column updated.
# Number of rows with transplant_date filled: 1577

# %%
df[df['transplant_date'].isna()][50:100]
# Out:
#          mrn                                   patengname pat_birthdate  \
# 652   221596                   MASHAIL IBRAHIM I ALQATARI    1993-03-16
# 695     3497                 HUWAYDA AHMED MOHAMMED FLATA    1973-04-14
# 697   220938  ABDELRAHMAN ALAAULDEEN AHMED SAYED MOHAMMED    2014-06-16
# 698   115829                ZAHRA MOHAMMED AHMED ALWABARI    2016-05-09
# 714   168247                 SEDRA FARAJ MOHAMMED ALANAZI    2021-01-26
# 774   165482               IBRAHIM FAHAD IBRAHIM AL BAHAR    2021-06-16
# 859   193437                MARIAM MOHAMMED EID ALRASHIDI    1999-08-16
# 861   209234              FUWZIA ABDULLAH HUSAIN ALSHABIB    1957-01-31
# 877   215541                         ALAA AHMED M ALARFAJ    1971-08-21
# 881    30976            MOHAMMED SAEED MOHAMMED ALZAHRANI    1963-11-17
# 911   217140               MOHAMMED ABDULLAH MRHON ALMHAL    1977-08-31
# 938    52504                     ABBER FAHAD H AL DOSSARY    1993-06-27
# 994   130254                 GHINA OMAR MOHAMMED ALHASANI    2018-08-02
# 1014  221422                MESHARI FARUQ AKASHA MOHAMMED    1988-12-07
# 1089  221747                      AREEJ SAEED M ALALAIWAT    1991-04-21
# 1090  221757                 NAWAL MOHAMMED AHMED ALBAHAR    1968-09-23
# 1091  221758              KHATIMAH MUTIB MOHAMMED ALMALKI    1965-10-25
# 1095  221574                        AHMAD ZAKI K ALQASSAB    1995-03-06
# 1096  221423                        OAMAR FAHD A ALZHRANI    1997-01-22
# 1100  221311                    ALAALLAH YAHYA ALI HAKAMI    1969-09-12
# 1101   82873              MOHAMMED BARAK AYEDH AL MOTEARY    1986-01-18
# 1116  202066                  ZAKI KADEM SALEH   ALQASSAB    1962-04-25
# 1119  191895                   AISHAH MOUSA GRARAH QARARH    1966-08-13
# 1120  147654                ALI MAKKI ABDULLAH AL MAHROOS    1971-03-31
# 1126  116636           KHALID BIN MOHAMMED BINALI SAHHARI    1980-04-12
# 1128  199765            NORAH EIDHAH BIN MOHAMMED ALMALKI    1988-02-02
# 1131  221650           AZZA ABDULRAHMAN MOHAMMED ALASMARI    1984-11-19
# 1137  221598               OSAMAH MAHDI MOHAMMED ALDHAHAB    2002-01-01
# 1142  221845                HAMAD MOHAMMED HAMAD AL MARRI    1981-05-22
# 1145  221651        MOHAMMED ABDULFATAH HASSAN AL MUBARAK    1990-05-25
# 1151  221847                 MODHI MOHAMMED ALI ALNAFISAH    1965-10-25
# 1152    2187                 SAAD ZIYAD ABDULLAH ALSWIDAN    1986-04-29
# 1166  221813            MOHAMMAD MOQBIL ABDULLAH ALQARAWI    1959-01-10
# 1169  218567               REEM ABDULHAKIM HAMAD ALKHALDI    2010-07-14
# 1174  211518                     ZAINAB HABEEB A ALMUBARK    1988-06-16
# 1176  113147             ASRAR MOHAMMED IBRAHIM ALTUWAYMI    1998-01-26
# 1177  207937              ABDALLAH NASER ABDULLAH ALABBAS    1989-11-04
# 1178  220675           SALIHAH SAEED ABDULRAHMAN ALGHAMDI    1959-01-10
# 1187  221941                  AHMED ALI ABDULLAH ALDAHNIN    1990-12-13
# 1188  220566                MOHAMMED NASSER SALEM ALMARRI    1996-11-24
# 1189  221023                     MAHA YOUSIF ALI AL OMRAN    1977-07-20
# 1193  220965                  ALI ABDULLAH SALEH ALRASHED    1999-08-13
# 1194  211629             MASOUMAH ABDULLAH TAHER BIN ABDI    1970-09-01
# 1198  114320                   RABAB HASAN HUSAIN ALAQOOL    1959-01-11
# 1199  220939                ELAF SHEHAB SADEQ ABDULRAHMAN    2018-12-10
# 1202  220938  ABDELRAHMAN ALAAULDEEN AHMED SAYED MOHAMMED    2014-06-16
# 1204  121816                KHOLOUD SALEH EISAF ALKATHERI    1993-06-14
# 1207  163486              ABEER ABDULRAHEM MOHAMMED HELAL    1978-07-29
# 1208  212991               MAQBULAH MOHAMMED ALI ALSHAHRI    1955-02-23
# 1209  152685                 NADIR Sarrah MUAITH AL QARNI    2009-03-24
#
#      visit_datetime   visit_type visit_status    booking_type  \
# 652      2025-12-31          NEW      STARTED  NORMAL BOOKING
# 695      2025-12-01          NEW      STARTED  NORMAL BOOKING
# 697      2025-12-03      Walk-In      STARTED         WALK-IN
# 698      2025-12-01          NEW      STARTED  NORMAL BOOKING
# 714      2025-12-15          NEW      STARTED  NORMAL BOOKING
# 774      2025-12-24          NEW      STARTED  NORMAL BOOKING
# 859      2025-12-15          NEW      STARTED  NORMAL BOOKING
# 861      2025-12-15          NEW      STARTED  NORMAL BOOKING
# 877      2025-12-28          NEW      STARTED  NORMAL BOOKING
# 881      2025-12-28          NEW      STARTED  NORMAL BOOKING
# 911      2025-12-21    FOLLOW UP      STARTED  NORMAL BOOKING
# 938      2025-12-01          NEW      STARTED  NORMAL BOOKING
# 994      2025-12-01          NEW      STARTED  NORMAL BOOKING
# 1014     2025-12-18          NEW      STARTED  NORMAL BOOKING
# 1089     2025-12-31  V Follow UP      STARTED  NORMAL BOOKING
# 1090     2025-12-31  V Follow UP      STARTED  NORMAL BOOKING
# 1091     2025-12-31  V Follow UP      STARTED  NORMAL BOOKING
# 1095     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 1096     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 1100     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 1101     2025-12-31  V Follow UP      STARTED  NORMAL BOOKING
# 1116     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 1119     2025-12-29  V Follow UP      ARRIVED  NORMAL BOOKING
# 1120     2025-12-31  V Follow UP      STARTED  NORMAL BOOKING
# 1126     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 1128     2025-12-29          NEW      STARTED  NORMAL BOOKING
# 1131     2025-12-30  V Follow UP      STARTED  NORMAL BOOKING
# 1137     2025-12-30  V Follow UP      STARTED  NORMAL BOOKING
# 1142     2025-12-31  V Follow UP      STARTED  NORMAL BOOKING
# 1145     2025-12-30  V Follow UP      STARTED  NORMAL BOOKING
# 1151     2025-12-31  V Follow UP      STARTED  NORMAL BOOKING
# 1152     2025-12-31  V Follow UP      STARTED  NORMAL BOOKING
# 1166     2025-12-28          NEW      STARTED  NORMAL BOOKING
# 1169     2025-12-02      Walk-In      STARTED         WALK-IN
# 1174     2025-12-24  CHART CHECK      STARTED         WALK-IN
# 1176     2025-12-02  V Follow UP      STARTED  NORMAL BOOKING
# 1177     2025-12-24  CHART CHECK      STARTED         WALK-IN
# 1178     2025-12-07          NEW      STARTED  NORMAL BOOKING
# 1187     2025-12-29  V Follow UP      STARTED  NORMAL BOOKING
# 1188     2025-12-10          NEW      STARTED  NORMAL BOOKING
# 1189     2025-12-09  V Follow UP      STARTED  NORMAL BOOKING
# 1193     2025-12-02          NEW      ARRIVED  NORMAL BOOKING
# 1194     2025-12-29    FOLLOW UP      STARTED  NORMAL BOOKING
# 1198     2025-12-31       Kidney      STARTED  NORMAL BOOKING
# 1199     2025-12-03          NEW      STARTED  NORMAL BOOKING
# 1202     2025-12-03          NEW      STARTED  NORMAL BOOKING
# 1204     2025-12-25          NEW      STARTED  NORMAL BOOKING
# 1207     2025-12-25          NEW      STARTED  NORMAL BOOKING
# 1208     2025-12-23      Walk-In      STARTED         WALK-IN
# 1209     2025-12-24    FOLLOW UP      ARRIVED  NORMAL BOOKING
#
#                                     clinic_name  \
# 652                  Adult Pre Liver Transplant
# 695                                  Anesthesia
# 697                                  Anesthesia
# 698                                  Anesthesia
# 714                          Clinical Nutrition
# 774                          Clinical Nutrition
# 859                          Clinical Nutrition
# 861                          Clinical Nutrition
# 877                          Clinical Nutrition
# 881                          Clinical Nutrition
# 911                  Adult Pre Liver Transplant
# 938                                  Anesthesia
# 994                                  Anesthesia
# 1014                         TRANSPLANT SURGERY
# 1089  Adult Pre Renal Transplant Virtual Clinic
# 1090  Adult Pre Renal Transplant Virtual Clinic
# 1091  Adult Pre Renal Transplant Virtual Clinic
# 1095                 Adult Pre Renal Transplant
# 1096                 Adult Pre Renal Transplant
# 1100                 Adult Pre Renal Transplant
# 1101  Adult Pre Renal Transplant Virtual Clinic
# 1116                 Adult Pre Renal Transplant
# 1119  Adult Pre Renal Transplant Virtual Clinic
# 1120  Adult Pre Renal Transplant Virtual Clinic
# 1126                 Adult Pre Renal Transplant
# 1128                 Adult Pre Renal Transplant
# 1131  Adult Pre Renal Transplant Virtual Clinic
# 1137  Adult Pre Renal Transplant Virtual Clinic
# 1142  Adult Pre Renal Transplant Virtual Clinic
# 1145  Adult Pre Renal Transplant Virtual Clinic
# 1151  Adult Pre Renal Transplant Virtual Clinic
# 1152  Adult Pre Renal Transplant Virtual Clinic
# 1166                 Adult Pre Liver Transplant
# 1169                 Pediatric Liver Transplant
# 1174                         TRANSPLANT SURGERY
# 1176  Adult Pre Renal Transplant Virtual Clinic
# 1177                         TRANSPLANT SURGERY
# 1178                 Adult Pre Liver Transplant
# 1187  Adult Pre Renal Transplant Virtual Clinic
# 1188                 Adult Pre Liver Transplant
# 1189  Adult Pre Renal Transplant Virtual Clinic
# 1193                         TRANSPLANT SURGERY
# 1194                 Adult Pre Liver Transplant
# 1198                         TRANSPLANT SURGERY
# 1199                 Pediatric Liver Transplant
# 1202                 Pediatric Liver Transplant
# 1204                                 Anesthesia
# 1207                                 Anesthesia
# 1208                                 Anesthesia
# 1209             Pediatric Pre Renal Transplant
#
#                                          mrp  liver_r_d  \
# 652               HADI MOHAMMED SHOEI KURIRY  Recipient
# 695    MOHAMED ESSAMELDIN HASSAN ABDELMEGUID  Recipient
# 697    MOHAMED ESSAMELDIN HASSAN ABDELMEGUID  Recipient
# 698    MOHAMED ESSAMELDIN HASSAN ABDELMEGUID        NaN
# 714                Fatimah Mansoor  Al Faraj        NaN
# 774              Marwah Abdullah  Al-Mubarak  Recipient
# 859              Fatimah Abdullah  AlIbrahim  Recipient
# 861              Fatimah Abdullah  AlIbrahim  Recipient
# 877              Fatimah Abdullah  AlIbrahim  Recipient
# 881              Fatimah Abdullah  AlIbrahim  Recipient
# 911               HADI MOHAMMED SHOEI KURIRY  Recipient
# 938    MOHAMED ESSAMELDIN HASSAN ABDELMEGUID  Recipient
# 994    MOHAMED ESSAMELDIN HASSAN ABDELMEGUID  Recipient
# 1014               MAHMOUD ALI MAHMOUD OBEID      Donor
# 1089             NAGEEB ASHOOR SALEM MUSAIAD        NaN
# 1090             NAGEEB ASHOOR SALEM MUSAIAD        NaN
# 1091             NAGEEB ASHOOR SALEM MUSAIAD        NaN
# 1095      ABDULNASER MOHAMMED HAMOUD ALABADI        NaN
# 1096      ABDULNASER MOHAMMED HAMOUD ALABADI        NaN
# 1100      ABDULNASER MOHAMMED HAMOUD ALABADI        NaN
# 1101             NAGEEB ASHOOR SALEM MUSAIAD        NaN
# 1116  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN
# 1119  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN
# 1120             NAGEEB ASHOOR SALEM MUSAIAD        NaN
# 1126      ABDULNASER MOHAMMED HAMOUD ALABADI        NaN
# 1128  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN
# 1131             KHALID AHMEDH BELEED AKKARI        NaN
# 1137             KHALID AHMEDH BELEED AKKARI        NaN
# 1142             NAGEEB ASHOOR SALEM MUSAIAD        NaN
# 1145             KHALID AHMEDH BELEED AKKARI        NaN
# 1151             NAGEEB ASHOOR SALEM MUSAIAD        NaN
# 1152             NAGEEB ASHOOR SALEM MUSAIAD        NaN
# 1166              HADI MOHAMMED SHOEI KURIRY        NaN
# 1169         Razan Monther Abdulmajied Bader        NaN
# 1174            Mohammed Saad Ali AL-Qahtani        NaN
# 1176      ABDULNASER MOHAMMED HAMOUD ALABADI        NaN
# 1177            Mohammed Saad Ali AL-Qahtani        NaN
# 1178              HADI MOHAMMED SHOEI KURIRY  Recipient
# 1187      ABDULNASER MOHAMMED HAMOUD ALABADI        NaN
# 1188              HADI MOHAMMED SHOEI KURIRY  Recipient
# 1189      ABDULNASER MOHAMMED HAMOUD ALABADI        NaN
# 1193           AHMED MOHAMED ALY AHMED ZIDAN      Donor
# 1194     Eyad Mohammad Osman Elhassan Gadour  Recipient
# 1198            Mohammed Saad Ali AL-Qahtani        NaN
# 1199           IBRAHIM ELHADI IBRAHIM HASSAN  Recipient
# 1202           IBRAHIM ELHADI IBRAHIM HASSAN  Recipient
# 1204                   ASHRAF ALI MOUSSA ALI        NaN
# 1207                   ASHRAF ALI MOUSSA ALI        NaN
# 1208                   ASHRAF ALI MOUSSA ALI        NaN
# 1209          ABDULAZIZ AHMED SALEM BA MHRAZ        NaN
#
#                 liver_status                               kidney_recipient  \
# 652              New patient                                            NaN
# 695   OPD Hepatology patient                                            NaN
# 697              New patient                                            NaN
# 698                      NaN                             Nephrology patient
# 714                      NaN                             Nephrology patient
# 774              New patient                                            NaN
# 859       Hepatology patient                                            NaN
# 861              New patient                  Waiting for first appointment
# 877        Pre Tx on workups                                            NaN
# 881   OPD Hepatology patient                                            NaN
# 911       Hepatology patient                                            NaN
# 938       Hepatology patient                                            NaN
# 994       Hepatology patient                                            NaN
# 1014       Pre Tx on workups                                            NaN
# 1089                     NaN  Initial visit done, No LD, suspended for DDWL
# 1090                     NaN  Initial visit done, No LD, suspended for DDWL
# 1091                     NaN                  Waiting for first appointment
# 1095                     NaN                                            NaN
# 1096                     NaN                                            NaN
# 1100                     NaN                  Waiting for first appointment
# 1101                     NaN  Initial visit done, No LD, suspended for DDWL
# 1116                     NaN                  Waiting for first appointment
# 1119                     NaN                  Waiting for first appointment
# 1120                     NaN  Initial visit done, No LD, suspended for DDWL
# 1126                     NaN                                 Listed on DDWL
# 1128                     NaN  Initial visit done, No LD, suspended for DDWL
# 1131                     NaN                                            NaN
# 1137                     NaN                                            NaN
# 1142                     NaN  Initial visit done, No LD, suspended for DDWL
# 1145                     NaN                                            NaN
# 1151                     NaN  Initial visit done, No LD, suspended for DDWL
# 1152                     NaN  Initial visit done, No LD, suspended for DDWL
# 1166                     NaN                                            NaN
# 1169                     NaN                                            NaN
# 1174                     NaN                                            NaN
# 1176                     NaN  Initial visit done, No LD, suspended for DDWL
# 1177                     NaN                                            NaN
# 1178             New patient                                            NaN
# 1187                     NaN  Initial visit done, No LD, suspended for DDWL
# 1188             New patient                                            NaN
# 1189                     NaN                                            NaN
# 1193       Pre Tx on workups                                            NaN
# 1194             New patient                                            NaN
# 1198                     NaN                              Pre Tx on workups
# 1199       Pre Tx on workups                                            NaN
# 1202             New patient                                            NaN
# 1204                     NaN                                            NaN
# 1207                     NaN             Pre Tx Discussed & Ready for LD Tx
# 1208                     NaN           Pre Tx Discussed with pending issues
# 1209                     NaN                                 Listed on DDWL
#
#                                         kidney_donor need_review  \
# 652                                              NaN          no
# 695                                              NaN          no
# 697                                              NaN          no
# 698                                              NaN          no
# 714                                              NaN          no
# 774                                              NaN          no
# 859                                              NaN          no
# 861                                              NaN          no
# 877                                              NaN          no
# 881                                              NaN          no
# 911                                              NaN          no
# 938                                              NaN          no
# 994                                              NaN          no
# 1014                                             NaN          no
# 1089                                             NaN          no
# 1090                                             NaN          no
# 1091                                             NaN          no
# 1095                   Waiting for first appointment          no
# 1096                               Pre Tx on workups          no
# 1100                                             NaN          no
# 1101                                             NaN          no
# 1116                                             NaN          no
# 1119                                             NaN          no
# 1120                                             NaN          no
# 1126                                             NaN          no
# 1128                                             NaN          no
# 1131                               Pre Tx on workups          no
# 1137                               Pre Tx on workups          no
# 1142                                             NaN          no
# 1145                               Pre Tx on workups          no
# 1151                                             NaN          no
# 1152                                             NaN          no
# 1166                                             NaN         yes
# 1169                                             NaN         yes
# 1174  Pre Tx Discussed & ready for donor nephrectomy          no
# 1176                                             NaN          no
# 1177  Pre Tx Discussed & ready for donor nephrectomy          no
# 1178                                             NaN          no
# 1187                                             NaN          no
# 1188                                             NaN          no
# 1189                               Pre Tx on workups          no
# 1193                                             NaN          no
# 1194                                             NaN          no
# 1198                                             NaN          no
# 1199                                             NaN          no
# 1202                                             NaN          no
# 1204  Pre Tx Discussed & ready for donor nephrectomy          no
# 1207                                             NaN          no
# 1208                                             NaN          no
# 1209                                             NaN          no
#
#                                                  r_d  \
# 652                                  Liver Recipient
# 695                                  Liver Recipient
# 697                                  Liver Recipient
# 698                               Nephrology patient
# 714                               Nephrology patient
# 774                                  Liver Recipient
# 859                                  Liver Recipient
# 861                                              NaN
# 877                                  Liver Recipient
# 881                                  Liver Recipient
# 911                                  Liver Recipient
# 938                                  Liver Recipient
# 994                                  Liver Recipient
# 1014                                     Liver Donor
# 1089   Initial visit done, No LD, suspended for DDWL
# 1090   Initial visit done, No LD, suspended for DDWL
# 1091                   Waiting for first appointment
# 1095                   Waiting for first appointment
# 1096                               Pre Tx on workups
# 1100                   Waiting for first appointment
# 1101   Initial visit done, No LD, suspended for DDWL
# 1116                   Waiting for first appointment
# 1119                   Waiting for first appointment
# 1120   Initial visit done, No LD, suspended for DDWL
# 1126                                  Listed on DDWL
# 1128   Initial visit done, No LD, suspended for DDWL
# 1131                               Pre Tx on workups
# 1137                               Pre Tx on workups
# 1142   Initial visit done, No LD, suspended for DDWL
# 1145                               Pre Tx on workups
# 1151   Initial visit done, No LD, suspended for DDWL
# 1152   Initial visit done, No LD, suspended for DDWL
# 1166                                             NaN
# 1169                                             NaN
# 1174  Pre Tx Discussed & ready for donor nephrectomy
# 1176   Initial visit done, No LD, suspended for DDWL
# 1177  Pre Tx Discussed & ready for donor nephrectomy
# 1178                                 Liver Recipient
# 1187   Initial visit done, No LD, suspended for DDWL
# 1188                                 Liver Recipient
# 1189                               Pre Tx on workups
# 1193                                     Liver Donor
# 1194                                 Liver Recipient
# 1198                               Pre Tx on workups
# 1199                                 Liver Recipient
# 1202                                 Liver Recipient
# 1204  Pre Tx Discussed & ready for donor nephrectomy
# 1207              Pre Tx Discussed & Ready for LD Tx
# 1208            Pre Tx Discussed with pending issues
# 1209                                  Listed on DDWL
#
#                                         patient_type transplant_date  days
# 652                                      New patient             NaT  None
# 695                           OPD Hepatology patient             NaT  None
# 697                                      New patient             NaT  None
# 698                               Nephrology patient             NaT  None
# 714                               Nephrology patient             NaT  None
# 774                                      New patient             NaT  None
# 859                               Hepatology patient             NaT  None
# 861                                      New patient             NaT  None
# 877                                Pre Tx on workups             NaT  None
# 881                           OPD Hepatology patient             NaT  None
# 911                               Hepatology patient             NaT  None
# 938                               Hepatology patient             NaT  None
# 994                               Hepatology patient             NaT  None
# 1014                               Pre Tx on workups             NaT  None
# 1089   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1090   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1091                   Waiting for first appointment             NaT  None
# 1095                   Waiting for first appointment             NaT  None
# 1096                               Pre Tx on workups             NaT  None
# 1100                   Waiting for first appointment             NaT  None
# 1101   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1116                   Waiting for first appointment             NaT  None
# 1119                   Waiting for first appointment             NaT  None
# 1120   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1126                                  Listed on DDWL             NaT  None
# 1128   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1131                               Pre Tx on workups             NaT  None
# 1137                               Pre Tx on workups             NaT  None
# 1142   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1145                               Pre Tx on workups             NaT  None
# 1151   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1152   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1166                                             NaN             NaT  None
# 1169                                             NaN             NaT  None
# 1174  Pre Tx Discussed & ready for donor nephrectomy             NaT  None
# 1176   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1177  Pre Tx Discussed & ready for donor nephrectomy             NaT  None
# 1178                                     New patient             NaT  None
# 1187   Initial visit done, No LD, suspended for DDWL             NaT  None
# 1188                                     New patient             NaT  None
# 1189                               Pre Tx on workups             NaT  None
# 1193                               Pre Tx on workups             NaT  None
# 1194                                     New patient             NaT  None
# 1198                               Pre Tx on workups             NaT  None
# 1199                               Pre Tx on workups             NaT  None
# 1202                                     New patient             NaT  None
# 1204  Pre Tx Discussed & ready for donor nephrectomy             NaT  None
# 1207              Pre Tx Discussed & Ready for LD Tx             NaT  None
# 1208            Pre Tx Discussed with pending issues             NaT  None
# 1209                                  Listed on DDWL             NaT  None

# %%
# fill patient_type: if visit_date - transplant_date is minus, zero or the transplant_date is NaN -> pre
# if the visit_date - transplant_date. patient_type -> post

# Ensure both columns are datetime (safe, coercive)
visit_dt = pd.to_datetime(df["visit_datetime"], errors="coerce")
tx_dt = pd.to_datetime(df["transplant_date"], errors="coerce")

# Calculate day difference
df["days"] = (visit_dt - tx_dt).dt.days

# Overwrite patient_type based on rules
df.loc[tx_dt.isna(), "patient_type"] = "pre"
df.loc[tx_dt.notna() & (df["days"] <= 0), "patient_type"] = "pre"
df.loc[tx_dt.notna() & (df["days"] > 0), "patient_type"] = "post"
