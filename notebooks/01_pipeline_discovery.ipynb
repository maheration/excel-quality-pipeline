# %% [markdown]
# # Excel Quality Pipeline – Discovery Notebook
#
# ## Objective
# Build a reproducible data pipeline that produces a single cleaned
# quality dataset from multiple Excel inputs.
#
# This notebook is for exploration and validation only.
# Final logic will be migrated into the `src/` module.

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.3.3'

# %%
# ===== Monthly Run Config =====
OPD_FILE = "../data/raw/feb/PATIENT OPD VISITS-2026_2_1_10_24.xlsx"
LIVER_FILE = "../data/raw/feb/Liver Registry - 1 Feb.xlsx"
KIDNEY_RECIP_FILE = "../data/raw/feb/Kidney Recipient - 1 Feb.xlsx"
KIDNEY_DONOR_FILE = "../data/raw/feb/Kidney Donor - 1 Feb.xlsx"
MOTC_FILE = "../data/raw/feb/MOTC OPD visits - from 2018-2021.xlsx"

OUTPUT_FILE = "../data/output/cleaned_opd_visits.xlsx"
# =============================

# %%
df = pd.read_excel(OPD_FILE)
df.shape
# Out:
# (3810, 18)

# %%
header = df.columns.tolist()

# %%
print(header)
# Out:
# ['MRN', 'PatEngName', 'pat_birthdate', 'regtime', 'VISIT_DATETIME', 'ARRIVETIME', 'STARTTIME', 'VISIT_TYPE', 'PORTAL STATUS', 'VISIT STATUS', 'BOOKING_TYPE', 'clinic_key', 'CLINIC_NAME', 'MRP', 'JOB TITLE', 'SPECIALTY', 'Added_by', 'addtime']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3810 entries, 0 to 3809
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MRN             3810 non-null   int64
#  1   PatEngName      3749 non-null   object
#  2   pat_birthdate   3749 non-null   datetime64[ns]
#  3   regtime         3749 non-null   datetime64[ns]
#  4   VISIT_DATETIME  3810 non-null   object
#  5   ARRIVETIME      3087 non-null   datetime64[ns]
#  6   STARTTIME       2990 non-null   datetime64[ns]
#  7   VISIT_TYPE      3810 non-null   object
#  8   PORTAL STATUS   3749 non-null   object
#  9   VISIT STATUS    3749 non-null   object
#  10  BOOKING_TYPE    3749 non-null   object
#  11  clinic_key      3749 non-null   float64
#  12  CLINIC_NAME     3810 non-null   object
#  13  MRP             3810 non-null   object
#  14  JOB TITLE       3749 non-null   object
#  15  SPECIALTY       3749 non-null   object
#  16  Added_by        3749 non-null   object
#  17  addtime         3749 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), float64(1), int64(1), object(11)
# memory usage: 535.9+ KB

# %%
# Drop uneeded col
cols_to_drop = [
    "regtime",
    "ARRIVETIME",
    "STARTTIME",
    "PORTAL STATUS",
    "clinic_key",
    "JOB TITLE",
    "SPECIALTY",
    "Added_by",
    "addtime",
]

df = df.drop(columns=cols_to_drop)

# %%
df.columns
# Out:
# Index(['MRN', 'PatEngName', 'pat_birthdate', 'VISIT_DATETIME', 'VISIT_TYPE',
#        'VISIT STATUS', 'BOOKING_TYPE', 'CLINIC_NAME', 'MRP'],
#       dtype='object')

# %%
# Normalize column names
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)
df.columns
# Out:
# Index(['mrn', 'patengname', 'pat_birthdate', 'visit_datetime', 'visit_type',
#        'visit_status', 'booking_type', 'clinic_name', 'mrp'],
#       dtype='object')

# %%
df['visit_datetime'].dtype
# Out:
# dtype('O')

# %%
# change col visit_datetime to datetime DD/MM/YYYY

df["visit_datetime"] = pd.to_datetime(
    df["visit_datetime"],
    errors="coerce"
).dt.date

# %%
df["visit_datetime"].dtype
type(df.loc[0, "visit_datetime"])
# Out:
# datetime.date

# %%
# Adding the new col

new_cols = [
    "liver_r_d",
    "liver_status",
    "kidney_recipient",
    "kidney_donor",
]

for col in new_cols:
    df[col] = None

df.columns
# Out:
# Index(['mrn', 'patengname', 'pat_birthdate', 'visit_datetime', 'visit_type',
#        'visit_status', 'booking_type', 'clinic_name', 'mrp', 'liver_r_d',
#        'liver_status', 'kidney_recipient', 'kidney_donor'],
#       dtype='object')

# %%
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  220920       WARDA MOHAMMED ALI AL HAMAD    1977-09-30     2026-01-12
# 1  187647  ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2  218085          Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 3  220888   NAWAF ABDULLAH EISSA ALSHAMMARI    2019-11-12     2026-01-04
# 4  147118      SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
#
#   visit_type visit_status    booking_type                      clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING                       Anesthesia
# 1  FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2        NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 3        NEW      STARTED  NORMAL BOOKING                       Anesthesia
# 4  FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
#
#                                      mrp liver_r_d liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 1      Mohammed Abdulmoatani  Almaghrabi      None         None
# 2     ABDULNASER MOHAMMED HAMOUD ALABADI      None         None
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID      None         None
# 4         ABDULAZIZ AHMED SALEM BA MHRAZ      None         None
#
#   kidney_recipient kidney_donor
# 0             None         None
# 1             None         None
# 2             None         None
# 3             None         None
# 4             None         None

# %%
df['visit_status'].value_counts()
# Out:
# visit_status
# STARTED    2990
# NO SHOW     662
# ARRIVED      97
# Name: count, dtype: int64

# %%
# Remove NO SHOW visit_status

df = df[df["visit_status"] != "NO SHOW"]

# %%
df['visit_status'].value_counts()
# Out:
# visit_status
# STARTED    2990
# ARRIVED      97
# Name: count, dtype: int64

# %%
# Fill liver columns using Liver Registry (ONLY)
# For each MRN in df:
# Look it up in Liver Registry
# If found:
###### Rec_Don → liver_r_d
###### Current Status1 → liver_status
# If not found:
##### leave as NaN

liver_df = pd.read_excel(LIVER_FILE)
liver_df.columns = (liver_df.columns.str.strip().str.lower().str.replace(" ", "_"))

# %%
liver_df.columns.tolist()
# Out:
# ['r_mrn',
#  'id_number',
#  'patient_name',
#  'mobile1_0',
#  'payment_0',
#  'rec_don',
#  'nationality',
#  'city_of_residence',
#  'specify_other',
#  'age_group',
#  'age',
#  'blood_group',
#  'gender',
#  'date_open_file_0',
#  'current_status1',
#  'patient_type_1',
#  'initial_tx_assessment_date',
#  'workup_start_date',
#  'workup_completed_date',
#  'date_added_to_waiting_list',
#  'surgery_date',
#  'tx_type',
#  'transplant_place',
#  'comment_0',
#  'closefile_r',
#  'closefiledate_r',
#  'closefilereason_r',
#  'assigned_consultant_0',
#  'assigned_surgeon_r',
#  'primary_disease']

# %%
df = df.merge(
    liver_df[["r_mrn", "rec_don", "current_status1"]],
    left_on="mrn",
    right_on="r_mrn",
    how="left"
)

# %%
df["liver_r_d"] = df["rec_don"]
df["liver_status"] = df["current_status1"]
df.tail()
# Out:
#          mrn patengname pat_birthdate visit_datetime visit_type visit_status  \
# 3143  222221        NaN           NaT     2026-01-11        new          NaN
# 3144  177889        NaN           NaT     2026-01-12        new          NaN
# 3145  222472        NaN           NaT     2026-01-19        new          NaN
# 3146  191339        NaN           NaT     2026-01-19        new          NaN
# 3147  222858        NaN           NaT     2026-01-25        new          NaN
#
#      booking_type clinic_name             mrp  liver_r_d       liver_status  \
# 3143          NaN  Psychology  Feda Al Ghamdi        NaN                NaN
# 3144          NaN  Psychology  Feda Al Ghamdi  Recipient        New patient
# 3145          NaN  Psychology  Feda Al Ghamdi      Donor  Pre Tx on workups
# 3146          NaN  Psychology  Feda Al Ghamdi        NaN                NaN
# 3147          NaN  Psychology  Feda Al Ghamdi      Donor  Pre Tx on workups
#
#      kidney_recipient kidney_donor   r_mrn    rec_don    current_status1
# 3143             None         None     NaN        NaN                NaN
# 3144             None         None  177889  Recipient        New patient
# 3145             None         None  222472      Donor  Pre Tx on workups
# 3146             None         None     NaN        NaN                NaN
# 3147             None         None  222858      Donor  Pre Tx on workups

# %%
df = df.drop(columns=["r_mrn", "rec_don", "current_status1"])

# %%
df[df["liver_r_d"].notna()]
# Out:
#          mrn                          patengname pat_birthdate visit_datetime  \
# 4     147118        SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 88    112285          ALI MOHAMMED ALI ALSHARDAN    2017-04-13     2026-01-18
# 90    137912           SAAD HAMAD HASSAN SAHHARI    2018-12-05     2026-01-14
# 93    120160            NAJD TALAL HABIB ALANAZI    2017-05-24     2026-01-14
# 95    119981  HASHIM ABDULRAHEEM NASSER AL HAMAD    2017-12-02     2026-01-14
# ...      ...                                 ...           ...            ...
# 3139  127093                                 NaN           NaT     2026-01-05
# 3140  210060                                 NaN           NaT     2026-01-06
# 3144  177889                                 NaN           NaT     2026-01-12
# 3145  222472                                 NaN           NaT     2026-01-19
# 3147  222858                                 NaN           NaT     2026-01-25
#
#      visit_type visit_status    booking_type                      clinic_name  \
# 4     FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 88          NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 90          NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 93           VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 95          NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# ...         ...          ...             ...                              ...
# 3139  Follow up          NaN             NaN                       Psychology
# 3140        new          NaN             NaN                       Psychology
# 3144        new          NaN             NaN                       Psychology
# 3145        new          NaN             NaN                       Psychology
# 3147        new          NaN             NaN                       Psychology
#
#                                  mrp  liver_r_d        liver_status  \
# 4     ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 88       Marwah Abdullah  Al-Mubarak  Recipient             Post Tx
# 90       Marwah Abdullah  Al-Mubarak  Recipient  Hepatology patient
# 93       Marwah Abdullah  Al-Mubarak  Recipient  Hepatology patient
# 95       Marwah Abdullah  Al-Mubarak  Recipient             Post Tx
# ...                              ...        ...                 ...
# 3139                   Alia Al Enazi  Recipient      Pre Tx on DDWL
# 3140                   Alia Al Enazi  Recipient  Hepatology patient
# 3144                  Feda Al Ghamdi  Recipient         New patient
# 3145                  Feda Al Ghamdi      Donor   Pre Tx on workups
# 3147                  Feda Al Ghamdi      Donor   Pre Tx on workups
#
#      kidney_recipient kidney_donor
# 4                None         None
# 88               None         None
# 90               None         None
# 93               None         None
# 95               None         None
# ...               ...          ...
# 3139             None         None
# 3140             None         None
# 3144             None         None
# 3145             None         None
# 3147             None         None
#
# [540 rows x 13 columns]

# %%
# Fill kidney_recipient using Kidney Recipient registry (ONLY)
# For each mrn in the main df:
# Look it up in Kidney Recipient - 1 JAN.xlsx

# If found:
###### copy Current Status1 → kidney_recipient
# If not found:
###### leave as NaN

kidney_rec_df = pd.read_excel(KIDNEY_RECIP_FILE)
kidney_rec_df.columns = (kidney_rec_df.columns.str.strip().str.lower().str.replace(" ", "_"))

# %%
df = df.merge(
    kidney_rec_df[["r_mrn", "current_status1"]],
    left_on="mrn",
    right_on="r_mrn",
    how="left"
)
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  220920       WARDA MOHAMMED ALI AL HAMAD    1977-09-30     2026-01-12
# 1  187647  ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2  218085          Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 3  220888   NAWAF ABDULLAH EISSA ALSHAMMARI    2019-11-12     2026-01-04
# 4  147118      SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
#
#   visit_type visit_status    booking_type                      clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING                       Anesthesia
# 1  FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2        NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 3        NEW      STARTED  NORMAL BOOKING                       Anesthesia
# 4  FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
#
#                                      mrp  liver_r_d        liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID        NaN                 NaN
# 1      Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2     ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID        NaN                 NaN
# 4         ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
#
#   kidney_recipient kidney_donor     r_mrn current_status1
# 0             None         None       NaN             NaN
# 1             None         None  187647.0      Post LD Tx
# 2             None         None       NaN             NaN
# 3             None         None       NaN             NaN
# 4             None         None  147118.0      Post DD Tx

# %%
df["kidney_recipient"] = df["current_status1"]
df = df.drop(columns=["r_mrn", "current_status1"])

# %%
df.tail()
# Out:
#          mrn patengname pat_birthdate visit_datetime visit_type visit_status  \
# 3143  222221        NaN           NaT     2026-01-11        new          NaN
# 3144  177889        NaN           NaT     2026-01-12        new          NaN
# 3145  222472        NaN           NaT     2026-01-19        new          NaN
# 3146  191339        NaN           NaT     2026-01-19        new          NaN
# 3147  222858        NaN           NaT     2026-01-25        new          NaN
#
#      booking_type clinic_name             mrp  liver_r_d       liver_status  \
# 3143          NaN  Psychology  Feda Al Ghamdi        NaN                NaN
# 3144          NaN  Psychology  Feda Al Ghamdi  Recipient        New patient
# 3145          NaN  Psychology  Feda Al Ghamdi      Donor  Pre Tx on workups
# 3146          NaN  Psychology  Feda Al Ghamdi        NaN                NaN
# 3147          NaN  Psychology  Feda Al Ghamdi      Donor  Pre Tx on workups
#
#      kidney_recipient kidney_donor
# 3143              NaN         None
# 3144   Pre Tx on hold         None
# 3145              NaN         None
# 3146              NaN         None
# 3147              NaN         None

# %%
# Fill kidney_donor
# For each mrn in the main df:
# Match it to d_mrn in Kidney Donor - 1 JAN.xlsx
# Copy current_status1_d → kidney_donor
# If no match → leave NaN

kidney_donor_df = pd.read_excel(KIDNEY_DONOR_FILE)

kidney_donor_df.columns = (
    kidney_donor_df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
)

df = df.merge(
    kidney_donor_df[["d_mrn", "current_status1_d"]],
    left_on="mrn",
    right_on="d_mrn",
    how="left"
)

df["kidney_donor"] = df["current_status1_d"]

df = df.drop(columns=["d_mrn", "current_status1_d"])

# %%
df.head()
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 0  220920       WARDA MOHAMMED ALI AL HAMAD    1977-09-30     2026-01-12
# 1  187647  ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2  218085          Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 3  220888   NAWAF ABDULLAH EISSA ALSHAMMARI    2019-11-12     2026-01-04
# 4  147118      SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
#
#   visit_type visit_status    booking_type                      clinic_name  \
# 0        NEW      STARTED  NORMAL BOOKING                       Anesthesia
# 1  FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2        NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 3        NEW      STARTED  NORMAL BOOKING                       Anesthesia
# 4  FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
#
#                                      mrp  liver_r_d        liver_status  \
# 0  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID        NaN                 NaN
# 1      Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2     ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 3  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID        NaN                 NaN
# 4         ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
#
#   kidney_recipient                   kidney_donor
# 0              NaN                            NaN
# 1       Post LD Tx                            NaN
# 2              NaN  Post living donor nephrectomy
# 3              NaN                            NaN
# 4       Post DD Tx                            NaN

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Anesthesia                                         760
# Clinical Nutrition                                 602
# Adult Post Renal Transplant                        469
# TRANSPLANT SURGERY                                 410
# Adult Post Kidney Transplant Virtual Clinic        228
# ADULT POST LIVER TRANSPLANT                        128
# Adult Pre Renal Transplant                          96
# Adult Pre Liver Transplant                          88
# Pediatric Post Renal Transplant                     85
# Pediatric Liver Transplant                          72
# Social Work                                         46
# Adult Post Liver Transplant Virtual                 40
# Transplant Dressing (procedure)                     38
# Pediatric Post Kidney Transplant Virtual Clinic     21
# Adult Pre Renal Transplant Virtual Clinic           19
# Psychology                                          15
# Pediatric Pre Renal Transplant                      11
# Adult Pre Liver Transplant Virtual                  10
# Transplant Cystoscopy Clinic                         6
# Pre anesthesia liver transplant                      4
# Name: count, dtype: int64

# %%
# Remove visits based on clinic + transplant status (ONLY)

# Remove row if ALL of the following are true:

# 1-clinic_name is Anesthesia OR Clinical Nutrition
# 2- liver_r_d is NaN
# 3-kidney_recipient is NaN
# 4-kidney_donor is NaN

mask = (
    df["clinic_name"].isin(["Anesthesia", "Clinical Nutrition"])
    & df["liver_r_d"].isna()
    & df["kidney_recipient"].isna()
    & df["kidney_donor"].isna()
)

df = df[~mask]

# %%
df[
    df["clinic_name"].isin(["Anesthesia", "Clinical Nutrition"])
][["liver_r_d", "kidney_recipient", "kidney_donor"]].isna().all(axis=1).sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#        mrn                         patengname pat_birthdate visit_datetime  \
# 1   187647   ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2   218085           Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4   147118       SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6   210109  YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28  176279          RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
#
#    visit_type visit_status    booking_type                      clinic_name  \
# 1   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2         NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6   FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                        mrp  liver_r_d        liver_status  \
# 1        Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2       ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 4           ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 6   SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN                 NaN
# 28          Ebtisam Hassan Husain Al-Ghawi        NaN                 NaN
#
#       kidney_recipient                   kidney_donor
# 1           Post LD Tx                            NaN
# 2                  NaN  Post living donor nephrectomy
# 4           Post DD Tx                            NaN
# 6           Post LD Tx                            NaN
# 28  Nephrology patient                            NaN

# %%
df[df[["liver_r_d", "kidney_recipient", "kidney_donor"]].isna().all(axis=1)]
# Out:
#          mrn                              patengname pat_birthdate  \
# 1228  213897             RAZAN SAEED JAMAN ALZAHRANI    1999-08-19
# 1351  223022     BADER ABDULMOHSEN MOHAMMED ALMUTIRI    1966-10-15
# 2123  209901                           Jiji   THOMAS    1991-05-05
# 2167  208567           GHAITH GHALI DAKHEL ALJAMEELI    2017-12-20
# 2273   13459            SHAIKHAH MOHAMMED A ALSAMHAN    1940-08-04
# 2293   69960            AZIZAH MOHAMMED A ALSHAHRANI    1979-11-26
# 2595  186450              SAUD EID RASHED AL RASHIDI    2019-10-21
# 2643  211782         HALIMA IBRAHIM SALEH ALMAJDOUIE    1948-05-10
# 2699    8909      BANEEN ABDULLAH MOHAMMED ALSAIHATI    1986-05-17
# 2800    4592            MUNEERAH ALI HAMAD ALSAFRANI    1956-02-12
# 2889    8909      BANEEN ABDULLAH MOHAMMED ALSAIHATI    1986-05-17
# 2892    8909      BANEEN ABDULLAH MOHAMMED ALSAIHATI    1986-05-17
# 2898  201277               ALI NEMAH ALI   AL KHUZAM    1960-12-19
# 2903   95399  KHOLOD ABD EL KARIM DAKHIL AL HSSANIAN    1970-11-04
# 2905    9754     MAREEM ABD EL AZIZ ABDALLA AL AMERY    1963-01-19
# 2908   93153      MOHAMMED ABDALLA TURKEY ALSHAHRANI    1967-10-04
# 2910  220818      MOHAMMED ALSHAWI MOHAMMED ALARJANI    1963-11-18
# 3138  222403                                     NaN           NaT
#
#      visit_datetime visit_type visit_status    booking_type  \
# 1228     2026-01-14    Walk-In      ARRIVED         WALK-IN
# 1351     2026-01-28        NEW      STARTED  NORMAL BOOKING
# 2123     2026-01-13     Kidney      STARTED  NORMAL BOOKING
# 2167     2026-01-18  FOLLOW UP      STARTED  NORMAL BOOKING
# 2273     2026-01-19  FOLLOW UP      STARTED  NORMAL BOOKING
# 2293     2026-01-20      Liver      STARTED  NORMAL BOOKING
# 2595     2026-01-14  FOLLOW UP      STARTED  NORMAL BOOKING
# 2643     2026-01-29    Walk-In      ARRIVED         WALK-IN
# 2699     2026-01-19        NEW      STARTED  NORMAL BOOKING
# 2800     2026-01-29    Walk-In      ARRIVED         WALK-IN
# 2889     2026-01-12  FOLLOW UP      STARTED  NORMAL BOOKING
# 2892     2026-01-05  FOLLOW UP      STARTED  NORMAL BOOKING
# 2898     2026-01-04    Walk-In      ARRIVED         WALK-IN
# 2903     2026-01-04    Walk-In      ARRIVED         WALK-IN
# 2905     2026-01-04    Walk-In      ARRIVED         WALK-IN
# 2908     2026-01-04    Walk-In      ARRIVED         WALK-IN
# 2910     2026-01-04    Walk-In      ARRIVED         WALK-IN
# 3138     2026-01-05        new          NaN             NaN
#
#                       clinic_name                                     mrp  \
# 1228  Adult Post Renal Transplant        MAHER MOHAMMED RAFAT ALDEMERDASH
# 1351   Adult Pre Liver Transplant              HADI MOHAMMED SHOEI KURIRY
# 2123           TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 2167   Pediatric Liver Transplant         Razan Monther Abdulmajied Bader
# 2273   Adult Pre Liver Transplant     Eyad Mohammad Osman Elhassan Gadour
# 2293           TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 2595   Pediatric Liver Transplant           IBRAHIM ELHADI IBRAHIM HASSAN
# 2643           TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 2699           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 2800  Adult Post Renal Transplant  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI
# 2889           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 2892           TRANSPLANT SURGERY               MAHMOUD ALI MAHMOUD OBEID
# 2898           TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 2903           TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 2905           TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 2908           TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 2910           TRANSPLANT SURGERY            Mohammed Saad Ali AL-Qahtani
# 3138                   Psychology                           Alia Al Enazi
#
#      liver_r_d liver_status kidney_recipient kidney_donor
# 1228       NaN          NaN              NaN          NaN
# 1351       NaN          NaN              NaN          NaN
# 2123       NaN          NaN              NaN          NaN
# 2167       NaN          NaN              NaN          NaN
# 2273       NaN          NaN              NaN          NaN
# 2293       NaN          NaN              NaN          NaN
# 2595       NaN          NaN              NaN          NaN
# 2643       NaN          NaN              NaN          NaN
# 2699       NaN          NaN              NaN          NaN
# 2800       NaN          NaN              NaN          NaN
# 2889       NaN          NaN              NaN          NaN
# 2892       NaN          NaN              NaN          NaN
# 2898       NaN          NaN              NaN          NaN
# 2903       NaN          NaN              NaN          NaN
# 2905       NaN          NaN              NaN          NaN
# 2908       NaN          NaN              NaN          NaN
# 2910       NaN          NaN              NaN          NaN
# 3138       NaN          NaN              NaN          NaN

# %%
# Add need_review flag
df["need_review"] = "no"
review_mask = (
    df[["liver_r_d", "kidney_recipient", "kidney_donor"]]
    .isna()
    .all(axis=1)
)

df.loc[review_mask, "need_review"] = "yes"

# %%
df['liver_r_d'].value_counts()
# Out:
# liver_r_d
# Recipient    490
# Donor         50
# Name: count, dtype: int64

# %%
# Create and fill r_d (LOCKED LOGIC)

# We look at three columns:
#liver_r_d, kidney_recipient, kidney_donor
# A) If only one of the three is non-NaN:
# Only liver_r_d filled → r_d = "Liver " + liver_r_d
# Only kidney_recipient filled → r_d = kidney_recipient
# Only kidney_donor filled → r_d = kidney_donor
# B) If liver_r_d is non-NaN AND (either kidney_recipient OR kidney_donor is non-NaN):
# Use clinic_name keyword:
# If clinic_name contains renal or kidney → r_d becomes the non-NaN kidney value (recipient preferred, else donor)
# If clinic_name contains liver → r_d = "Liver " + liver_r_d

# Vectorized version
mask_liver_only = df['liver_r_d'].notna() & df['kidney_recipient'].isna() & df['kidney_donor'].isna()
mask_k_recip_only = df['kidney_recipient'].notna() & df['liver_r_d'].isna() & df['kidney_donor'].isna()
mask_k_donor_only = df['kidney_donor'].notna() & df['liver_r_d'].isna() & df['kidney_recipient'].isna()

df['r_d'] = np.select(
    [
        mask_liver_only,
        mask_k_recip_only,
        mask_k_donor_only,
    ],
    [
        "Liver " + df['liver_r_d'].astype(str),
        df['kidney_recipient'],
        df['kidney_donor']
    ],
    default=np.nan
)

# Now handle mixed cases (where liver + at least one kidney is present)
mixed_mask = (
    df['liver_r_d'].notna() &
    (df['kidney_recipient'].notna() | df['kidney_donor'].notna()) &
    (df['r_d'].isna())  # still null after previous step
)

clinic_lower = df['clinic_name'].fillna('').str.lower()

renal_clinic = clinic_lower.str.contains('renal|kidney')
liver_clinic = clinic_lower.str.contains('liver')

df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'r_d'] = \
    df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'kidney_recipient'].fillna(
        df.loc[mixed_mask & renal_clinic & ~liver_clinic, 'kidney_donor']
    )

df.loc[mixed_mask & liver_clinic & ~renal_clinic, 'r_d'] = \
    "Liver " + df.loc[mixed_mask & liver_clinic & ~renal_clinic, 'liver_r_d'].astype(str)

# %%
df.head()
# Out:
#        mrn                         patengname pat_birthdate visit_datetime  \
# 1   187647   ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2   218085           Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4   147118       SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6   210109  YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28  176279          RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
#
#    visit_type visit_status    booking_type                      clinic_name  \
# 1   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2         NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6   FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                        mrp  liver_r_d        liver_status  \
# 1        Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2       ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 4           ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 6   SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN                 NaN
# 28          Ebtisam Hassan Husain Al-Ghawi        NaN                 NaN
#
#       kidney_recipient                   kidney_donor need_review  \
# 1           Post LD Tx                            NaN          no
# 2                  NaN  Post living donor nephrectomy          no
# 4           Post DD Tx                            NaN          no
# 6           Post LD Tx                            NaN          no
# 28  Nephrology patient                            NaN          no
#
#                               r_d
# 1                      Post LD Tx
# 2   Post living donor nephrectomy
# 4                      Post DD Tx
# 6                      Post LD Tx
# 28             Nephrology patient

# %%
df['liver_status'].value_counts()
# Out:
# liver_status
# Post Tx                        318
# Hepatology patient              91
# New patient                     37
# Pre Tx on workups               37
# Pre Tx on DDWL                  26
# OPD Hepatology patient          17
# Pre Tx ready for transplant      6
# Pre Tx Ready for transplant      4
# Hepatitis C patient              3
# Pre Tx on hold                   1
# Name: count, dtype: int64

# %%
# ambiguous_mask = (
#     df['liver_r_d'].notna() &
#     (df['kidney_recipient'].notna() | df['kidney_donor'].notna()) &
#     df['r_d'].isna()
# )

# len(df.loc[ambiguous_mask])

# come to this later at the end to see how many should be assigned as need review
df.head(30)
# Out:
#         mrn                           patengname pat_birthdate visit_datetime  \
# 1    187647     ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2    218085             Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4    147118         SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6    210109    YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28   176279            RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
# 61   201290             AYAT ALI ABDULLAH  ASQIT    1994-02-21     2026-01-04
# 68   218481             AMAL ALI HUSAIN AL ABBAS    1973-11-21     2026-01-28
# 79   192067      WAEL SALEH BIN ALI ALMUNTASHIRI    2011-07-25     2026-01-28
# 83   128975             RAWAN MOSSA AHMAD ALESSA    2014-03-04     2026-01-11
# 85   185562  RAED IBRAHIM ABDELMOHSEN ALABDULALI    2013-07-16     2026-01-28
# 88   112285           ALI MOHAMMED ALI ALSHARDAN    2017-04-13     2026-01-18
# 90   137912            SAAD HAMAD HASSAN SAHHARI    2018-12-05     2026-01-14
# 92   142741           AHMED JABER JUHRAN ALMALKI    2017-05-19     2026-01-14
# 93   120160             NAJD TALAL HABIB ALANAZI    2017-05-24     2026-01-14
# 95   119981   HASHIM ABDULRAHEEM NASSER AL HAMAD    2017-12-02     2026-01-14
# 96   119849             SAAD SULTAN SAUD ALHARBI    2018-01-14     2026-01-14
# 105  167787         HOUR NASSER MOHAMMED ALHAJRI    2019-10-25     2026-01-21
# 106  163543           MAYS HASSAN ABDULLAH ASIRI    2020-07-09     2026-01-25
# 108  211964            HAYA DERA SAEED ALQAHTANI    2019-03-15     2026-01-14
# 111   91287      NURAH ABDULMONEM AHMED ALFADHLI    2009-04-05     2026-01-21
# 112  220939        ELAF SHEHAB SADEQ ABDULRAHMAN    2018-12-10     2026-01-28
# 119  188453           BADER HAMAD HASSAN SAHHARI    2023-05-04     2026-01-14
# 120  190214        KAYAN MOHAMMED ALI ALDARWEESH    2022-09-27     2026-01-21
# 121  195966    FATIMAH HASSAN MOHAMMED AL ASMAKH    2023-10-29     2026-01-14
# 127  204028           MOHAMMED HASAN MAHDI AHMAD    2024-04-29     2026-01-28
# 129  214438             KHALID ALI AYIDH ALFARSI    2023-07-05     2026-01-21
# 132  189085            AWS MOHAMMAD ALI ALSHEHRI    2020-03-17     2026-01-21
# 133  218986           GORE MAZEN MOHSEN ALRABEEI    2024-08-11     2026-01-21
# 134  218986           GORE MAZEN MOHSEN ALRABEEI    2024-08-11     2026-01-14
# 138  107405      NAYANWA HASSAN AHMED ALSULAIMAN    2016-06-24     2026-01-15
#
#     visit_type visit_status    booking_type                      clinic_name  \
# 1    FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2          NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4    FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6    FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28         NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 61         NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 68          VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 79         NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 83         NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 85          VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 88         NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 90         NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 92         NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 93          VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 95         NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 96          VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 105         VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 106         VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 108         VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 111  FOLLOW UP      STARTED  NORMAL BOOKING               Clinical Nutrition
# 112        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 119        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 120        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 121         VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 127        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 129        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 132         VV      STARTED  NORMAL BOOKING               Clinical Nutrition
# 133  FOLLOW UP      STARTED  NORMAL BOOKING               Clinical Nutrition
# 134        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
# 138        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                         mrp  liver_r_d  \
# 1         Mohammed Abdulmoatani  Almaghrabi        NaN
# 2        ABDULNASER MOHAMMED HAMOUD ALABADI        NaN
# 4            ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient
# 6    SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN
# 28           Ebtisam Hassan Husain Al-Ghawi        NaN
# 61              FAIY JALAWI AMER AL MUTAIRI        NaN
# 68           Ebtisam Hassan Husain Al-Ghawi        NaN
# 79              Marwah Abdullah  Al-Mubarak        NaN
# 83              Marwah Abdullah  Al-Mubarak        NaN
# 85              Marwah Abdullah  Al-Mubarak        NaN
# 88              Marwah Abdullah  Al-Mubarak  Recipient
# 90              Marwah Abdullah  Al-Mubarak  Recipient
# 92              Marwah Abdullah  Al-Mubarak        NaN
# 93              Marwah Abdullah  Al-Mubarak  Recipient
# 95              Marwah Abdullah  Al-Mubarak  Recipient
# 96              Marwah Abdullah  Al-Mubarak        NaN
# 105             Marwah Abdullah  Al-Mubarak        NaN
# 106             Marwah Abdullah  Al-Mubarak  Recipient
# 108             Marwah Abdullah  Al-Mubarak  Recipient
# 111             Marwah Abdullah  Al-Mubarak        NaN
# 112             Marwah Abdullah  Al-Mubarak  Recipient
# 119             Marwah Abdullah  Al-Mubarak  Recipient
# 120             Marwah Abdullah  Al-Mubarak  Recipient
# 121             Marwah Abdullah  Al-Mubarak  Recipient
# 127             Marwah Abdullah  Al-Mubarak  Recipient
# 129             Marwah Abdullah  Al-Mubarak  Recipient
# 132             Marwah Abdullah  Al-Mubarak  Recipient
# 133             Marwah Abdullah  Al-Mubarak  Recipient
# 134             Marwah Abdullah  Al-Mubarak  Recipient
# 138             Marwah Abdullah  Al-Mubarak  Recipient
#
#                liver_status    kidney_recipient  \
# 1                       NaN          Post LD Tx
# 2                       NaN                 NaN
# 4        Hepatology patient          Post DD Tx
# 6                       NaN          Post LD Tx
# 28                      NaN  Nephrology patient
# 61                      NaN          Post LD Tx
# 68                      NaN  Nephrology patient
# 79                      NaN          Post LD Tx
# 83                      NaN  Nephrology patient
# 85                      NaN          Post LD Tx
# 88                  Post Tx                 NaN
# 90       Hepatology patient                 NaN
# 92                      NaN          Post LD Tx
# 93       Hepatology patient                 NaN
# 95                  Post Tx                 NaN
# 96                      NaN      Listed on DDWL
# 105                     NaN          Post LD Tx
# 106             New patient                 NaN
# 108  OPD Hepatology patient                 NaN
# 111                     NaN          Post DD Tx
# 112       Pre Tx on workups                 NaN
# 119             New patient                 NaN
# 120                 Post Tx                 NaN
# 121                 Post Tx                 NaN
# 127                 Post Tx                 NaN
# 129      Hepatology patient                 NaN
# 132                 Post Tx                 NaN
# 133                 Post Tx                 NaN
# 134                 Post Tx                 NaN
# 138                 Post Tx                 NaN
#
#                       kidney_donor need_review                            r_d
# 1                              NaN          no                     Post LD Tx
# 2    Post living donor nephrectomy          no  Post living donor nephrectomy
# 4                              NaN          no                     Post DD Tx
# 6                              NaN          no                     Post LD Tx
# 28                             NaN          no             Nephrology patient
# 61                             NaN          no                     Post LD Tx
# 68                             NaN          no             Nephrology patient
# 79                             NaN          no                     Post LD Tx
# 83                             NaN          no             Nephrology patient
# 85                             NaN          no                     Post LD Tx
# 88                             NaN          no                Liver Recipient
# 90                             NaN          no                Liver Recipient
# 92                             NaN          no                     Post LD Tx
# 93                             NaN          no                Liver Recipient
# 95                             NaN          no                Liver Recipient
# 96                             NaN          no                 Listed on DDWL
# 105                            NaN          no                     Post LD Tx
# 106                            NaN          no                Liver Recipient
# 108                            NaN          no                Liver Recipient
# 111                            NaN          no                     Post DD Tx
# 112                            NaN          no                Liver Recipient
# 119                            NaN          no                Liver Recipient
# 120                            NaN          no                Liver Recipient
# 121                            NaN          no                Liver Recipient
# 127                            NaN          no                Liver Recipient
# 129                            NaN          no                Liver Recipient
# 132                            NaN          no                Liver Recipient
# 133                            NaN          no                Liver Recipient
# 134                            NaN          no                Liver Recipient
# 138                            NaN          no                Liver Recipient

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        855
# Liver Recipient                                   413
# Pre Tx on workups                                 190
# Post living donor nephrectomy                     140
# Post DD Tx                                         85
# Liver Donor                                        48
# Pre Tx Ready for committee                         38
# Pre Tx Discussed & Ready for LD Tx                 26
# Pre Tx Discussed & ready for donor nephrectomy     23
# Waiting for first appointment                      23
# Nephrology patient                                 20
# Listed on DDWL                                     20
# Pre Tx on hold                                     14
# Initial visit done, No LD, suspended for DDWL       9
# Pre Tx Discussed with pending issues                7
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df["patient_type"] = None
df["transplant_date"] = None
df["days"] = None

# %%
df.head(1)
# Out:
#       mrn                        patengname pat_birthdate visit_datetime  \
# 1  187647  ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
#
#   visit_type visit_status    booking_type                      clinic_name  \
# 1  FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
#
#                                  mrp liver_r_d liver_status kidney_recipient  \
# 1  Mohammed Abdulmoatani  Almaghrabi       NaN          NaN       Post LD Tx
#
#   kidney_donor need_review         r_d patient_type transplant_date  days
# 1          NaN          no  Post LD Tx         None            None  None

# %%
df['patient_type'] = df['liver_status'].combine_first(
    df['kidney_recipient']
).combine_first(
    df['kidney_donor']
)

# %%
# if patient_type is NA i think need_revuew = yes

# %%
# Create lookup dictionaries: MRN → Surgery Date
# Using the actual column names from your files

liver_dict = (
    liver_df[['r_mrn', 'surgery_date']]
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['surgery_date']
    .to_dict()
)

recip_dict = (
    kidney_rec_df[['r_mrn', 'surgery_date']]           # ← using kidney_rec_df (your naming)
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['surgery_date']
    .to_dict()
)

donor_dict = (
    kidney_donor_df[['d_mrn', 'surgery_date_d']]
    .dropna(subset=['d_mrn'])
    .set_index('d_mrn')['surgery_date_d']
    .to_dict()
)

# Populate transplant_date with this priority order:
# 1. Liver
# 2. Kidney Recipient
# 3. Kidney Donor
df['transplant_date'] = (
    df['mrn'].map(liver_dict)                  # Liver first
    .combine_first(df['mrn'].map(recip_dict))       # then Recipient
    .combine_first(df['mrn'].map(donor_dict))       # then Donor
)

# Optional: Flag rows that still have no transplant date
# (uncomment when you're ready to implement review flagging)
# df.loc[df['transplant_date'].isna(), 'need_review'] = 'yes'

print("transplant_date column updated.")
print(f"Number of rows with transplant_date filled: {df['transplant_date'].notna().sum()}")
# Out:
# transplant_date column updated.
# Number of rows with transplant_date filled: 1422

# %%
# fill patient_type: if visit_date - transplant_date is minus, zero or the transplant_date is NaN -> pre
# if the visit_date - transplant_date. patient_type -> post

# Ensure both columns are datetime (safe, coercive)
visit_dt = pd.to_datetime(df["visit_datetime"], errors="coerce")
tx_dt = pd.to_datetime(df["transplant_date"], errors="coerce")

# Calculate day difference
df["days"] = (visit_dt - tx_dt).dt.days

# Overwrite patient_type based on rules
df.loc[tx_dt.isna(), "patient_type"] = "pre"
df.loc[tx_dt.notna() & (df["days"] <= 0), "patient_type"] = "pre"
df.loc[tx_dt.notna() & (df["days"] > 0), "patient_type"] = "post"

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        855
# Liver Recipient                                   413
# Pre Tx on workups                                 190
# Post living donor nephrectomy                     140
# Post DD Tx                                         85
# Liver Donor                                        48
# Pre Tx Ready for committee                         38
# Pre Tx Discussed & Ready for LD Tx                 26
# Pre Tx Discussed & ready for donor nephrectomy     23
# Waiting for first appointment                      23
# Nephrology patient                                 20
# Listed on DDWL                                     20
# Pre Tx on hold                                     14
# Initial visit done, No LD, suspended for DDWL       9
# Pre Tx Discussed with pending issues                7
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df[df['r_d'] == 'Nephrology patient']
# Out:
#          mrn                             patengname pat_birthdate  \
# 28    176279              RADHI NASER HASAN ALHODAR    1946-05-31
# 68    218481               AMAL ALI HUSAIN AL ABBAS    1973-11-21
# 83    128975               RAWAN MOSSA AHMAD ALESSA    2014-03-04
# 323    42618           RANA ABDULAZIZ SAAD AL HAWAS    1972-06-20
# 401   201585                      SUJA   KAITHAVANA    1973-05-23
# 453   176618  RAHMAH ABDULRAZAQ ABDULHADI AL HAMMAD    1984-09-10
# 548    69833      KHADIJAH IBRAHIM HASSAN AL QATTAN    1954-03-06
# 720   198355                  NAWAL ALI A ALGHANNAM    1963-11-17
# 725   140801       FAWZYAH ANBAR MOBARAK ALABDULLAH    1956-02-12
# 732    19202         MUSTAFA NASSER HUSSAIN ALJAFAR    1967-10-04
# 743   141679            FATIMAH ALI MOUSA ALZAHRANI    1951-04-07
# 1304  198738               NADYAH SAEED M ALQAHTANI    1977-12-26
# 1628  209913         YOUSEF AHMED YOUSEF ALKHALIFAH    2011-01-08
# 1700  141679            FATIMAH ALI MOUSA ALZAHRANI    1951-04-07
# 2267  203835             SUBAHA ARAR MATEER ALANAZI    1983-03-30
# 2566  169152          FAHAD MUBARAK DHNYEN  ALSBEAI    1958-01-20
# 2947  166991               ALI MOHAMMED ALI ALREBAH    1972-03-24
# 2972  113716        SALMAN SULTAN ABDULATIF ALANAZI    2009-12-27
# 2990  220348         NORAH ABDULLAH BIN AHMED HAMDI    1985-01-13
# 3073  202663     SHARIFAH MOHAMMED IBRAHIM ALHASHMI    1948-05-10
#
#      visit_datetime visit_type visit_status    booking_type  \
# 28       2026-01-04        NEW      STARTED  NORMAL BOOKING
# 68       2026-01-28         VV      STARTED  NORMAL BOOKING
# 83       2026-01-11        NEW      STARTED  NORMAL BOOKING
# 323      2026-01-05        NEW      STARTED  NORMAL BOOKING
# 401      2026-01-19        NEW      STARTED  NORMAL BOOKING
# 453      2026-01-12        NEW      STARTED  NORMAL BOOKING
# 548      2026-01-25        NEW      STARTED  NORMAL BOOKING
# 720      2026-01-14        NEW      STARTED  NORMAL BOOKING
# 725      2026-01-19        NEW      STARTED  NORMAL BOOKING
# 732      2026-01-05        NEW      STARTED  NORMAL BOOKING
# 743      2026-01-18  FOLLOW UP      STARTED  NORMAL BOOKING
# 1304     2026-01-04        NEW      STARTED  NORMAL BOOKING
# 1628     2026-01-28        NEW      STARTED  NORMAL BOOKING
# 1700     2026-01-20  FOLLOW UP      STARTED  NORMAL BOOKING
# 2267     2026-01-11        NEW      STARTED  NORMAL BOOKING
# 2566     2026-01-05        NEW      STARTED  NORMAL BOOKING
# 2947     2026-01-14        NEW      STARTED  NORMAL BOOKING
# 2972     2026-01-01        NEW      STARTED  NORMAL BOOKING
# 2990     2026-01-07        NEW      STARTED  NORMAL BOOKING
# 3073     2026-01-12        NEW      STARTED  NORMAL BOOKING
#
#                          clinic_name                                    mrp  \
# 28                Clinical Nutrition         Ebtisam Hassan Husain Al-Ghawi
# 68                Clinical Nutrition         Ebtisam Hassan Husain Al-Ghawi
# 83                Clinical Nutrition            Marwah Abdullah  Al-Mubarak
# 323               Clinical Nutrition               Entisar Malik M. AL-Hany
# 401                       Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 453               Clinical Nutrition           Fatima Abdullah Ali Al-Sinan
# 548                       Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 720               Clinical Nutrition            Fatimah Abdullah  AlIbrahim
# 725               Clinical Nutrition            Fatimah Abdullah  AlIbrahim
# 732               Clinical Nutrition            Fatimah Abdullah  AlIbrahim
# 743               Clinical Nutrition            Fatimah Abdullah  AlIbrahim
# 1304                      Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 1628  Pediatric Pre Renal Transplant         ABDULAZIZ AHMED SALEM BA MHRAZ
# 1700              Clinical Nutrition           RAWAN OLAYAN OBAIAD ALOLAYAN
# 2267                      Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 2566                      Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 2947                      Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 2972                      Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 2990                      Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
# 3073                      Anesthesia  MOHAMED ESSAMELDIN HASSAN ABDELMEGUID
#
#      liver_r_d liver_status    kidney_recipient kidney_donor need_review  \
# 28         NaN          NaN  Nephrology patient          NaN          no
# 68         NaN          NaN  Nephrology patient          NaN          no
# 83         NaN          NaN  Nephrology patient          NaN          no
# 323        NaN          NaN  Nephrology patient          NaN          no
# 401        NaN          NaN  Nephrology patient          NaN          no
# 453        NaN          NaN  Nephrology patient          NaN          no
# 548        NaN          NaN  Nephrology patient          NaN          no
# 720        NaN          NaN  Nephrology patient          NaN          no
# 725        NaN          NaN  Nephrology patient          NaN          no
# 732        NaN          NaN  Nephrology patient          NaN          no
# 743        NaN          NaN  Nephrology patient          NaN          no
# 1304       NaN          NaN  Nephrology patient          NaN          no
# 1628       NaN          NaN  Nephrology patient          NaN          no
# 1700       NaN          NaN  Nephrology patient          NaN          no
# 2267       NaN          NaN  Nephrology patient          NaN          no
# 2566       NaN          NaN  Nephrology patient          NaN          no
# 2947       NaN          NaN  Nephrology patient          NaN          no
# 2972       NaN          NaN  Nephrology patient          NaN          no
# 2990       NaN          NaN  Nephrology patient          NaN          no
# 3073       NaN          NaN  Nephrology patient          NaN          no
#
#                      r_d patient_type transplant_date  days
# 28    Nephrology patient          pre             NaT   NaN
# 68    Nephrology patient          pre             NaT   NaN
# 83    Nephrology patient          pre             NaT   NaN
# 323   Nephrology patient          pre             NaT   NaN
# 401   Nephrology patient          pre             NaT   NaN
# 453   Nephrology patient          pre             NaT   NaN
# 548   Nephrology patient          pre             NaT   NaN
# 720   Nephrology patient          pre             NaT   NaN
# 725   Nephrology patient          pre             NaT   NaN
# 732   Nephrology patient          pre             NaT   NaN
# 743   Nephrology patient          pre             NaT   NaN
# 1304  Nephrology patient          pre             NaT   NaN
# 1628  Nephrology patient          pre             NaT   NaN
# 1700  Nephrology patient          pre             NaT   NaN
# 2267  Nephrology patient          pre             NaT   NaN
# 2566  Nephrology patient          pre             NaT   NaN
# 2947  Nephrology patient          pre             NaT   NaN
# 2972  Nephrology patient          pre             NaT   NaN
# 2990  Nephrology patient          pre             NaT   NaN
# 3073  Nephrology patient          pre             NaT   NaN

# %%
df['liver_status'].value_counts()
# Out:
# liver_status
# Post Tx                        318
# Hepatology patient              91
# New patient                     37
# Pre Tx on workups               37
# Pre Tx on DDWL                  26
# OPD Hepatology patient          17
# Pre Tx ready for transplant      6
# Pre Tx Ready for transplant      4
# Hepatitis C patient              3
# Pre Tx on hold                   1
# Name: count, dtype: int64

# %%
df['patient_type'].value_counts()
# Out:
# patient_type
# post    1350
# pre      614
# Name: count, dtype: int64

# %%
# Final patient_type classification logic
#
# This step overwrites patient_type (which initially contains only "pre" / "post")
# and assigns a final clinical category using transplant context and liver status.
#
# Priority order (top to bottom – first match wins):
#
# 1) Hepatology override:
#    If liver_status contains any of:
#       - "hepatology"
#       - "hepatitis"
#       - "new patients"
#    → patient_type = "Hepatology"
#
# 2) Liver transplant context:
#    If r_d contains "liver":
#       - patient_type == "post" → "Post-Liver Tx"
#       - patient_type == "pre"  → "Pre-Liver Tx"
#
# 3) Nephrology (non-transplant):
#    If r_d contains "nephrology":
#       → patient_type = "Nephrology"
#
# 4) Kidney transplant context:
#    If r_d is present AND does NOT contain "liver" or "nephrology":
#       - patient_type == "post" → "Post-Kidney Tx"
#       - patient_type == "pre"  → "Pre-Kidney Tx"
#
# 5) Final fallback:
#    Any remaining rows → "Pre-Kidney Tx"
#
# Notes:
# - Matching is case-insensitive
# - Rules are mutually exclusive and applied in strict priority order
# - This mirrors the quality department’s manual classification logic



import numpy as np


# Prepare case-insensitive conditions
r_d_lower = df['r_d'].fillna('').str.lower()
liver_status_lower = df['liver_status'].fillna('').str.lower()

# ── Priority conditions (applied top → bottom) ───────────────────────────────

# Priority 1: Hepatology override (absolute)
is_hepatology = liver_status_lower.str.contains('hepatology|hepatitis|new patients', na=False)

# Priority 2: Liver transplant context
is_liver_context = r_d_lower.str.contains('liver', na=False)
is_post = df['patient_type'] == 'post'
is_pre  = df['patient_type'] == 'pre'

# Priority 3: Nephrology (non-transplant)
is_nephrology = r_d_lower.str.contains('nephrology', na=False)

# Priority 4: Kidney transplant context
# (has r_d value, but not liver & not nephrology)
is_kidney_context = (
    df['r_d'].notna() &
    ~is_liver_context &
    ~is_nephrology
)

# ── Apply rules in strict priority order using np.select ─────────────────────

conditions = [
    is_hepatology,                                      # 1. Hepatology override
    is_liver_context & is_post,                         # 2. Post-Liver Tx
    is_liver_context & is_pre,                          # 2. Pre-Liver Tx
    is_nephrology,                                      # 3. Nephrology
    is_kidney_context & is_post,                        # 4. Post-Kidney Tx
    is_kidney_context & is_pre,                         # 4. Pre-Kidney Tx
]

choices = [
    "Hepatology",
    "Post-Liver Tx",
    "Pre-Liver Tx",
    "Nephrology",
    "Post-Kidney Tx",
    "Pre-Kidney Tx",
]

df['patient_type'] = np.select(conditions, choices, default="Pre-Kidney Tx")

# %%
df['patient_type'].value_counts()
# Out:
# patient_type
# Post-Kidney Tx    994
# Pre-Kidney Tx     444
# Post-Liver Tx     308
# Hepatology        111
# Pre-Liver Tx       87
# Nephrology         20
# Name: count, dtype: int64

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Adult Post Renal Transplant                        469
# TRANSPLANT SURGERY                                 410
# Adult Post Kidney Transplant Virtual Clinic        228
# ADULT POST LIVER TRANSPLANT                        128
# Anesthesia                                         102
# Adult Pre Renal Transplant                          96
# Adult Pre Liver Transplant                          88
# Pediatric Post Renal Transplant                     85
# Clinical Nutrition                                  76
# Pediatric Liver Transplant                          72
# Social Work                                         46
# Adult Post Liver Transplant Virtual                 40
# Transplant Dressing (procedure)                     38
# Pediatric Post Kidney Transplant Virtual Clinic     21
# Adult Pre Renal Transplant Virtual Clinic           19
# Psychology                                          15
# Pediatric Pre Renal Transplant                      11
# Adult Pre Liver Transplant Virtual                  10
# Transplant Cystoscopy Clinic                         6
# Pre anesthesia liver transplant                      4
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                         patengname pat_birthdate visit_datetime  \
# 1   187647   ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2   218085           Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4   147118       SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6   210109  YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28  176279          RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
#
#    visit_type visit_status    booking_type                      clinic_name  \
# 1   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2         NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6   FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                        mrp  liver_r_d        liver_status  \
# 1        Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2       ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 4           ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 6   SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN                 NaN
# 28          Ebtisam Hassan Husain Al-Ghawi        NaN                 NaN
#
#       kidney_recipient                   kidney_donor need_review  \
# 1           Post LD Tx                            NaN          no
# 2                  NaN  Post living donor nephrectomy          no
# 4           Post DD Tx                            NaN          no
# 6           Post LD Tx                            NaN          no
# 28  Nephrology patient                            NaN          no
#
#                               r_d    patient_type transplant_date   days
# 1                      Post LD Tx  Post-Kidney Tx      2024-01-23  714.0
# 2   Post living donor nephrectomy  Post-Kidney Tx      2025-12-02   42.0
# 4                      Post DD Tx      Hepatology      2024-01-22  734.0
# 6                      Post LD Tx  Post-Kidney Tx      2025-09-15  127.0
# 28             Nephrology patient      Nephrology             NaT    NaN

# %%
# Create lookup dictionaries: MRN → Age Group

liver_age_dict = (
    liver_df[['r_mrn', 'age_group']]
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['age_group']
    .to_dict()
)

recip_age_dict = (
    kidney_rec_df[['r_mrn', 'age_group']]
    .dropna(subset=['r_mrn'])
    .set_index('r_mrn')['age_group']
    .to_dict()
)

donor_age_dict = (
    kidney_donor_df[['d_mrn', 'age_group_d']]
    .dropna(subset=['d_mrn'])
    .set_index('d_mrn')['age_group_d']
    .to_dict()
)

# Populate age_group with priority: Liver → Recipient → Donor
df['age_group'] = (
    df['mrn'].map(liver_age_dict)                # 1. Liver first
    .combine_first(df['mrn'].map(recip_age_dict))     # 2. Kidney Recipient
    .combine_first(df['mrn'].map(donor_age_dict))     # 3. Kidney Donor
)

# %%
df['age_group'].value_counts()
# Out:
# age_group
# Adult        1686
# Pediatric     260
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                         patengname pat_birthdate visit_datetime  \
# 1   187647   ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2   218085           Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4   147118       SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6   210109  YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28  176279          RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
#
#    visit_type visit_status    booking_type                      clinic_name  \
# 1   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2         NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6   FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                        mrp  liver_r_d        liver_status  \
# 1        Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2       ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 4           ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 6   SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN                 NaN
# 28          Ebtisam Hassan Husain Al-Ghawi        NaN                 NaN
#
#       kidney_recipient                   kidney_donor need_review  \
# 1           Post LD Tx                            NaN          no
# 2                  NaN  Post living donor nephrectomy          no
# 4           Post DD Tx                            NaN          no
# 6           Post LD Tx                            NaN          no
# 28  Nephrology patient                            NaN          no
#
#                               r_d    patient_type transplant_date   days  \
# 1                      Post LD Tx  Post-Kidney Tx      2024-01-23  714.0
# 2   Post living donor nephrectomy  Post-Kidney Tx      2025-12-02   42.0
# 4                      Post DD Tx      Hepatology      2024-01-22  734.0
# 6                      Post LD Tx  Post-Kidney Tx      2025-09-15  127.0
# 28             Nephrology patient      Nephrology             NaT    NaN
#
#     age_group
# 1   Pediatric
# 2       Adult
# 4   Pediatric
# 6       Adult
# 28      Adult

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Adult Post Renal Transplant                        469
# TRANSPLANT SURGERY                                 410
# Adult Post Kidney Transplant Virtual Clinic        228
# ADULT POST LIVER TRANSPLANT                        128
# Anesthesia                                         102
# Adult Pre Renal Transplant                          96
# Adult Pre Liver Transplant                          88
# Pediatric Post Renal Transplant                     85
# Clinical Nutrition                                  76
# Pediatric Liver Transplant                          72
# Social Work                                         46
# Adult Post Liver Transplant Virtual                 40
# Transplant Dressing (procedure)                     38
# Pediatric Post Kidney Transplant Virtual Clinic     21
# Adult Pre Renal Transplant Virtual Clinic           19
# Psychology                                          15
# Pediatric Pre Renal Transplant                      11
# Adult Pre Liver Transplant Virtual                  10
# Transplant Cystoscopy Clinic                         6
# Pre anesthesia liver transplant                      4
# Name: count, dtype: int64

# %%
df['patient_type'].value_counts()
# Out:
# patient_type
# Post-Kidney Tx    994
# Pre-Kidney Tx     444
# Post-Liver Tx     308
# Hepatology        111
# Pre-Liver Tx       87
# Nephrology         20
# Name: count, dtype: int64

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        855
# Liver Recipient                                   413
# Pre Tx on workups                                 190
# Post living donor nephrectomy                     140
# Post DD Tx                                         85
# Liver Donor                                        48
# Pre Tx Ready for committee                         38
# Pre Tx Discussed & Ready for LD Tx                 26
# Pre Tx Discussed & ready for donor nephrectomy     23
# Waiting for first appointment                      23
# Nephrology patient                                 20
# Listed on DDWL                                     20
# Pre Tx on hold                                     14
# Initial visit done, No LD, suspended for DDWL       9
# Pre Tx Discussed with pending issues                7
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                         patengname pat_birthdate visit_datetime  \
# 1   187647   ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2   218085           Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4   147118       SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6   210109  YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28  176279          RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
#
#    visit_type visit_status    booking_type                      clinic_name  \
# 1   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2         NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6   FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                        mrp  liver_r_d        liver_status  \
# 1        Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2       ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 4           ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 6   SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN                 NaN
# 28          Ebtisam Hassan Husain Al-Ghawi        NaN                 NaN
#
#       kidney_recipient                   kidney_donor need_review  \
# 1           Post LD Tx                            NaN          no
# 2                  NaN  Post living donor nephrectomy          no
# 4           Post DD Tx                            NaN          no
# 6           Post LD Tx                            NaN          no
# 28  Nephrology patient                            NaN          no
#
#                               r_d    patient_type transplant_date   days  \
# 1                      Post LD Tx  Post-Kidney Tx      2024-01-23  714.0
# 2   Post living donor nephrectomy  Post-Kidney Tx      2025-12-02   42.0
# 4                      Post DD Tx      Hepatology      2024-01-22  734.0
# 6                      Post LD Tx  Post-Kidney Tx      2025-09-15  127.0
# 28             Nephrology patient      Nephrology             NaT    NaN
#
#     age_group
# 1   Pediatric
# 2       Adult
# 4   Pediatric
# 6       Adult
# 28      Adult

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Post LD Tx                                        855
# Liver Recipient                                   413
# Pre Tx on workups                                 190
# Post living donor nephrectomy                     140
# Post DD Tx                                         85
# Liver Donor                                        48
# Pre Tx Ready for committee                         38
# Pre Tx Discussed & Ready for LD Tx                 26
# Pre Tx Discussed & ready for donor nephrectomy     23
# Waiting for first appointment                      23
# Nephrology patient                                 20
# Listed on DDWL                                     20
# Pre Tx on hold                                     14
# Initial visit done, No LD, suspended for DDWL       9
# Pre Tx Discussed with pending issues                7
# Listed on DDWL - Inactive                           3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                         patengname pat_birthdate visit_datetime  \
# 1   187647   ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2   218085           Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4   147118       SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6   210109  YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28  176279          RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
#
#    visit_type visit_status    booking_type                      clinic_name  \
# 1   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2         NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6   FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                        mrp  liver_r_d        liver_status  \
# 1        Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2       ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 4           ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 6   SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN                 NaN
# 28          Ebtisam Hassan Husain Al-Ghawi        NaN                 NaN
#
#       kidney_recipient                   kidney_donor need_review  \
# 1           Post LD Tx                            NaN          no
# 2                  NaN  Post living donor nephrectomy          no
# 4           Post DD Tx                            NaN          no
# 6           Post LD Tx                            NaN          no
# 28  Nephrology patient                            NaN          no
#
#                               r_d    patient_type transplant_date   days  \
# 1                      Post LD Tx  Post-Kidney Tx      2024-01-23  714.0
# 2   Post living donor nephrectomy  Post-Kidney Tx      2025-12-02   42.0
# 4                      Post DD Tx      Hepatology      2024-01-22  734.0
# 6                      Post LD Tx  Post-Kidney Tx      2025-09-15  127.0
# 28             Nephrology patient      Nephrology             NaT    NaN
#
#     age_group
# 1   Pediatric
# 2       Adult
# 4   Pediatric
# 6       Adult
# 28      Adult

# %%
df[df['patient_type'] == 'Hepatology'][30:50]
# Out:
#          mrn                           patengname pat_birthdate  \
# 1287  220675   SALIHAH SAEED ABDULRAHMAN ALGHAMDI    1959-01-10
# 1288  160545            Jana  EID FAHAAD  ALHAJRI    2008-07-05
# 1294  217189         SALAF DOKHI SALEM ALSHAMMARI    1977-07-21
# 1312  200089  HASIRAH MOHAMMED SUDDIQ SAYED QAYSI    1992-09-08
# 1316    1470     KHALED SAEED BIN AWADH ALQAHTANI    1986-04-26
# 1342  196718            MESHAL FAHAD SARI ALHAJRI    2007-02-04
# 1343  119922           KHALID AHMED ATIAH ALREESH    1978-06-06
# 1344  118047           RAAD MAJED GHALLAB ALHARBI    2017-06-30
# 1350  151311           AWATIF AHMED  ALI ALMUBARK    1963-11-17
# 1354   76667                 LATEEFAH R F ALANEZI    1985-03-11
# 1355  220183     SALEM HEJJI ABDULWAHAB AL SHAQAQ    2003-05-11
# 1360  118195              Saqer Ali Salman Yatimi    1989-12-15
# 1421   84940     ABDULLAH IBRAHIM HUSSAIN ALSHAIB    1967-06-09
# 1494  163355    Abdulrahman MASSAAD SAAED ALJHANI    2011-03-06
# 1497  217189         SALAF DOKHI SALEM ALSHAMMARI    1977-07-21
# 1524  103350          NORAH MAHDI MOHAMMED ALYAMI    1964-11-05
# 1577  138918              Marwa ALAA     Al Mazni    1988-06-16
# 1609  122652           RAWAN AHMED NASSAR ALATAWI    2007-04-03
# 1617   58470             HUSSAM ALI HADI ALRASHDI    1988-04-24
# 1635  206433       ORJUWAN YOUSEF AHMED  ALSHALAN    2011-06-22
#
#      visit_datetime   visit_type visit_status    booking_type  \
# 1287     2026-01-18  V Follow UP      STARTED  NORMAL BOOKING
# 1288     2026-01-11    FOLLOW UP      STARTED  NORMAL BOOKING
# 1294     2026-01-19  CHART CHECK      STARTED         WALK-IN
# 1312     2026-01-20  V Follow UP      ARRIVED  NORMAL BOOKING
# 1316     2026-01-27    FOLLOW UP      STARTED  NORMAL BOOKING
# 1342     2026-01-27    FOLLOW UP      STARTED  NORMAL BOOKING
# 1343     2026-01-27    FOLLOW UP      STARTED  NORMAL BOOKING
# 1344     2026-01-08    FOLLOW UP      STARTED  NORMAL BOOKING
# 1350     2026-01-25    FOLLOW UP      STARTED  NORMAL BOOKING
# 1354     2026-01-11    FOLLOW UP      STARTED  NORMAL BOOKING
# 1355     2026-01-27  V Follow UP      STARTED  NORMAL BOOKING
# 1360     2026-01-13    FOLLOW UP      STARTED  NORMAL BOOKING
# 1421     2026-01-05          NEW      STARTED  NORMAL BOOKING
# 1494     2026-01-22    FOLLOW UP      STARTED  NORMAL BOOKING
# 1497     2026-01-18    FOLLOW UP      STARTED  NORMAL BOOKING
# 1524     2026-01-29    FOLLOW UP      STARTED  NORMAL BOOKING
# 1577     2026-01-07          NEW      STARTED  NORMAL BOOKING
# 1609     2026-01-12          NEW      STARTED  NORMAL BOOKING
# 1617     2026-01-28    FOLLOW UP      STARTED  NORMAL BOOKING
# 1635     2026-01-25          NEW      STARTED  NORMAL BOOKING
#
#                                     clinic_name  \
# 1287         Adult Pre Liver Transplant Virtual
# 1288                 Adult Pre Liver Transplant
# 1294                 Adult Pre Renal Transplant
# 1312         Adult Pre Liver Transplant Virtual
# 1316                 Adult Pre Liver Transplant
# 1342                 Adult Pre Liver Transplant
# 1343                 Adult Pre Liver Transplant
# 1344            Pediatric Post Renal Transplant
# 1350                 Adult Pre Liver Transplant
# 1354                 Adult Pre Liver Transplant
# 1355  Adult Pre Renal Transplant Virtual Clinic
# 1360                 Adult Pre Liver Transplant
# 1421                 Adult Pre Renal Transplant
# 1494            Pediatric Post Renal Transplant
# 1497                         TRANSPLANT SURGERY
# 1524                         TRANSPLANT SURGERY
# 1577                 Adult Pre Liver Transplant
# 1609                Adult Post Renal Transplant
# 1617                Adult Post Renal Transplant
# 1635                 Pediatric Liver Transplant
#
#                                          mrp  liver_r_d  \
# 1287              HADI MOHAMMED SHOEI KURIRY  Recipient
# 1288              HADI MOHAMMED SHOEI KURIRY  Recipient
# 1294  SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI  Recipient
# 1312                 NOORA HASSAN B AL FARAJ  Recipient
# 1316                 NOORA HASSAN B AL FARAJ  Recipient
# 1342                 NOORA HASSAN B AL FARAJ  Recipient
# 1343                 NOORA HASSAN B AL FARAJ  Recipient
# 1344       Mohammed Abdulmoatani  Almaghrabi  Recipient
# 1350              HADI MOHAMMED SHOEI KURIRY  Recipient
# 1354              HADI MOHAMMED SHOEI KURIRY  Recipient
# 1355             KHALID AHMEDH BELEED AKKARI  Recipient
# 1360                 NOORA HASSAN B AL FARAJ  Recipient
# 1421      ABDULNASER MOHAMMED HAMOUD ALABADI  Recipient
# 1494       Mohammed Abdulmoatani  Almaghrabi  Recipient
# 1497            Mohammed Saad Ali AL-Qahtani  Recipient
# 1524               MAHMOUD ALI MAHMOUD OBEID  Recipient
# 1577              HADI MOHAMMED SHOEI KURIRY  Recipient
# 1609             NAGEEB ASHOOR SALEM MUSAIAD  Recipient
# 1617                    FAHAD EID M ALOTAIBE  Recipient
# 1635         Razan Monther Abdulmajied Bader  Recipient
#
#                 liver_status kidney_recipient                   kidney_donor  \
# 1287      Hepatology patient              NaN                            NaN
# 1288      Hepatology patient              NaN                            NaN
# 1294      Hepatology patient       Post LD Tx                            NaN
# 1312      Hepatology patient              NaN                            NaN
# 1316      Hepatology patient              NaN                            NaN
# 1342      Hepatology patient              NaN                            NaN
# 1343  OPD Hepatology patient              NaN                            NaN
# 1344      Hepatology patient       Post LD Tx                            NaN
# 1350  OPD Hepatology patient              NaN                            NaN
# 1354      Hepatology patient              NaN                            NaN
# 1355  OPD Hepatology patient              NaN     Pre Tx Ready for committee
# 1360      Hepatology patient              NaN                            NaN
# 1421     Hepatitis C patient   Listed on DDWL                            NaN
# 1494      Hepatology patient       Post LD Tx                            NaN
# 1497      Hepatology patient       Post LD Tx                            NaN
# 1524      Hepatology patient       Post LD Tx                            NaN
# 1577      Hepatology patient              NaN                            NaN
# 1609      Hepatology patient       Post LD Tx                            NaN
# 1617      Hepatology patient              NaN  Post living donor nephrectomy
# 1635      Hepatology patient              NaN                            NaN
#
#      need_review                            r_d patient_type transplant_date  \
# 1287          no                Liver Recipient   Hepatology             NaT
# 1288          no                Liver Recipient   Hepatology             NaT
# 1294          no                     Post LD Tx   Hepatology      2026-01-20
# 1312          no                Liver Recipient   Hepatology             NaT
# 1316          no                Liver Recipient   Hepatology             NaT
# 1342          no                Liver Recipient   Hepatology             NaT
# 1343          no                Liver Recipient   Hepatology             NaT
# 1344          no                     Post LD Tx   Hepatology      2019-12-11
# 1350          no                Liver Recipient   Hepatology             NaT
# 1354          no                Liver Recipient   Hepatology             NaT
# 1355          no     Pre Tx Ready for committee   Hepatology             NaT
# 1360          no                Liver Recipient   Hepatology             NaT
# 1421          no                 Listed on DDWL   Hepatology             NaT
# 1494          no                     Post LD Tx   Hepatology      2021-12-29
# 1497          no                            NaN   Hepatology      2026-01-20
# 1524          no                            NaN   Hepatology      2025-12-21
# 1577          no                Liver Recipient   Hepatology             NaT
# 1609          no                     Post LD Tx   Hepatology      2025-11-25
# 1617          no  Post living donor nephrectomy   Hepatology      2011-10-30
# 1635          no                Liver Recipient   Hepatology             NaT
#
#         days  age_group
# 1287     NaN      Adult
# 1288     NaN      Adult
# 1294    -1.0      Adult
# 1312     NaN      Adult
# 1316     NaN      Adult
# 1342     NaN      Adult
# 1343     NaN      Adult
# 1344  2220.0  Pediatric
# 1350     NaN      Adult
# 1354     NaN      Adult
# 1355     NaN      Adult
# 1360     NaN      Adult
# 1421     NaN      Adult
# 1494  1485.0  Pediatric
# 1497    -2.0      Adult
# 1524    39.0      Adult
# 1577     NaN      Adult
# 1609    48.0  Pediatric
# 1617  5204.0      Adult
# 1635     NaN  Pediatric

# %%
# Final logic for correcting / filling r_d column
# Rules applied in this strict top-to-bottom priority order:

# 1. If patient_type == "Hepatology"
#    → r_d = "Liver Recipient"

# 2. If patient_type == "Nephrology"
#    → r_d = "Kidney Recipient"

# 3. If patient_type in ["Post-Liver Tx", "Pre-Liver Tx"]
#    → keep the current r_d value as-is 
#      (it should already be either "Liver Recipient" or "Liver Donor")

# 4. If patient_type in ["Post-Kidney Tx", "Pre-Kidney Tx"]
#    → Decision order:
#      - If kidney_recipient is NOT NULL → r_d = "Kidney Recipient"
#      - Else if kidney_donor is NOT NULL   → r_d = "Kidney Donor"
#      - Else (both kidney_recipient AND kidney_donor are NULL)
#        → keep current r_d value unchanged
#        → AND set need_review = "yes" (change from default "no")

# All other cases: keep current r_d (though in practice should be covered above)

# Notes:
# - Liver cases trust existing r_d (already cleaned correctly)
# - Kidney cases prefer recipient status when available
# - Only flag for manual review when there's true ambiguity 
#   (no clear kidney role in source registry columns)


# 1. Hepatology & Nephrology overrides
hepatology_mask = df['patient_type'] == "Hepatology"
nephrology_mask = df['patient_type'] == "Nephrology"

df.loc[hepatology_mask, 'r_d'] = "Liver Recipient"
df.loc[nephrology_mask, 'r_d'] = "Kidney Recipient"

# 2. Liver cases - keep current r_d (no change needed)

# 3. Kidney transplant cases (Post & Pre)
kidney_tx_mask = df['patient_type'].isin(["Post-Kidney Tx", "Pre-Kidney Tx"])

# Sub-conditions for kidney cases
has_recipient = df['kidney_recipient'].notna()
has_donor     = df['kidney_donor'].notna()

# Apply preference: Recipient > Donor > keep current
df.loc[kidney_tx_mask & has_recipient, 'r_d'] = "Kidney Recipient"
df.loc[kidney_tx_mask & ~has_recipient & has_donor, 'r_d'] = "Kidney Donor"

# 4. Ambiguous kidney cases → flag for review
ambiguous_kidney = (
    kidney_tx_mask & 
    ~has_recipient & 
    ~has_donor
)

df.loc[ambiguous_kidney, 'need_review'] = "yes"

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Adult Post Renal Transplant                        469
# TRANSPLANT SURGERY                                 410
# Adult Post Kidney Transplant Virtual Clinic        228
# ADULT POST LIVER TRANSPLANT                        128
# Anesthesia                                         102
# Adult Pre Renal Transplant                          96
# Adult Pre Liver Transplant                          88
# Pediatric Post Renal Transplant                     85
# Clinical Nutrition                                  76
# Pediatric Liver Transplant                          72
# Social Work                                         46
# Adult Post Liver Transplant Virtual                 40
# Transplant Dressing (procedure)                     38
# Pediatric Post Kidney Transplant Virtual Clinic     21
# Adult Pre Renal Transplant Virtual Clinic           19
# Psychology                                          15
# Pediatric Pre Renal Transplant                      11
# Adult Pre Liver Transplant Virtual                  10
# Transplant Cystoscopy Clinic                         6
# Pre anesthesia liver transplant                      4
# Name: count, dtype: int64

# %%
df['r_d'].value_counts()
# Out:
# r_d
# Kidney Recipient    1128
# Liver Recipient      458
# Kidney Donor         312
# Liver Donor           48
# Name: count, dtype: int64

# %%
# Logic for creating the new 'clinic' column
# Rules are applied in order - first matching condition wins (top-to-bottom priority)

# All string matching is:
# - case-insensitive
# - partial contains (anywhere in the clinic_name string)

# 1. If clinic_name contains "renal" or "kidney"
#    → clinic = "Kidney Tx"

# 2. Else if clinic_name contains any of:
#    - "pediatric liver transplant"
#    - "adult pre liver transplant"
#    - "adult post liver transplant"
#    → clinic = "liver Tx"

# 3. Else if clinic_name contains "anesthesia"
#    → Check r_d (case-insensitive contains):
#      - if r_d contains "kidney" → clinic = "Anesthesia-Kidney"
#      - if r_d contains "liver"  → clinic = "Anesthesia-Liver"
#      - if neither → clinic remains NaN

# 4. Else if clinic_name contains "transplant urology" or "transplant cystoscopy clinic"
#    → clinic = "Urology"

# 5. Else if clinic_name contains "clinical nutrition"
#    → clinic = "Nutrition"

# 6. Else if clinic_name contains "transplant dressing (procedure)"
#    → clinic = "Surgery-Dressing"

# 7. Else if clinic_name contains "transplant surgery"
#    → Check r_d (case-insensitive contains):
#      - if r_d contains "kidney" → clinic = "Surgery-Kidney"
#      - else → clinic = "Surgery-Liver"

# 8. Else if clinic_name contains "psychology"
#    → clinic = "Psychology"

# 9. Else if clinic_name contains "social work"
#    → clinic = "Social Work"

# 10. Fallback (no match above)
#     → clinic remains NaN



# Make sure clinic_name is string and handle NaN
df['clinic_name'] = df['clinic_name'].astype(str).fillna('')

# Prepare lowercase versions for matching
clinic_lower = df['clinic_name'].str.lower()
rd_lower     = df['r_d'].fillna('').str.lower()

# Initialize the new column
df['clinic'] = pd.NA

# 1. Kidney Tx (renal or kidney)
mask_kidney = clinic_lower.str.contains('renal|kidney', na=False)
df.loc[mask_kidney, 'clinic'] = 'Kidney Tx'

# 2. Liver Tx (specific phrases)
mask_liver_specific = clinic_lower.str.contains(
    'pediatric liver transplant|adult pre liver transplant|adult post liver transplant',
    na=False
)
df.loc[mask_liver_specific & df['clinic'].isna(), 'clinic'] = 'liver Tx'

# 3. Anesthesia cases
mask_anesthesia = clinic_lower.str.contains('anesthesia', na=False)
df.loc[mask_anesthesia & df['clinic'].isna(), 'clinic'] = pd.NA  # default

df.loc[
    mask_anesthesia & df['clinic'].isna() & rd_lower.str.contains('kidney'),
    'clinic'
] = 'Anesthesia-Kidney'

df.loc[
    mask_anesthesia & df['clinic'].isna() & rd_lower.str.contains('liver'),
    'clinic'
] = 'Anesthesia-Liver'

# 4. Urology
mask_urology = clinic_lower.str.contains('transplant urology|transplant cystoscopy clinic', na=False)
df.loc[mask_urology & df['clinic'].isna(), 'clinic'] = 'Urology'

# 5. Nutrition
mask_nutrition = clinic_lower.str.contains('clinical nutrition', na=False)
df.loc[mask_nutrition & df['clinic'].isna(), 'clinic'] = 'Nutrition'

# 6. Surgery Dressing
mask_dressing = clinic_lower.str.contains(
    'transplant dressing (procedure)', 
    regex=False, 
    na=False
)
df.loc[mask_dressing & df['clinic'].isna(), 'clinic'] = 'Surgery-Dressing'

# 7. Transplant Surgery
mask_surgery = clinic_lower.str.contains('transplant surgery', na=False)
df.loc[mask_surgery & df['clinic'].isna(), 'clinic'] = 'Surgery-Liver'  # default for surgery

df.loc[
    mask_surgery & df['clinic'].isna() & rd_lower.str.contains('kidney'),
    'clinic'
] = 'Surgery-Kidney'

# 8. Psychology
mask_psych = clinic_lower.str.contains('psychology', na=False)
df.loc[mask_psych & df['clinic'].isna(), 'clinic'] = 'Psychology'

# 9. Social Work
mask_social = clinic_lower.str.contains('social work', na=False)
df.loc[mask_social & df['clinic'].isna(), 'clinic'] = 'Social Work'

# %%
df['clinic'].value_counts()
# Out:
# clinic
# Kidney Tx            929
# Surgery-Liver        410
# liver Tx             338
# Anesthesia-Kidney     82
# Nutrition             76
# Social Work           46
# Surgery-Dressing      38
# Anesthesia-Liver      24
# Psychology            15
# Urology                6
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                         patengname pat_birthdate visit_datetime  \
# 1   187647   ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2   218085           Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4   147118       SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6   210109  YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28  176279          RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
#
#    visit_type visit_status    booking_type                      clinic_name  \
# 1   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2         NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6   FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                        mrp  liver_r_d        liver_status  \
# 1        Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2       ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 4           ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 6   SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN                 NaN
# 28          Ebtisam Hassan Husain Al-Ghawi        NaN                 NaN
#
#       kidney_recipient                   kidney_donor need_review  \
# 1           Post LD Tx                            NaN          no
# 2                  NaN  Post living donor nephrectomy          no
# 4           Post DD Tx                            NaN          no
# 6           Post LD Tx                            NaN          no
# 28  Nephrology patient                            NaN          no
#
#                  r_d    patient_type transplant_date   days  age_group  \
# 1   Kidney Recipient  Post-Kidney Tx      2024-01-23  714.0  Pediatric
# 2       Kidney Donor  Post-Kidney Tx      2025-12-02   42.0      Adult
# 4    Liver Recipient      Hepatology      2024-01-22  734.0  Pediatric
# 6   Kidney Recipient  Post-Kidney Tx      2025-09-15  127.0      Adult
# 28  Kidney Recipient      Nephrology             NaT    NaN      Adult
#
#        clinic
# 1   Kidney Tx
# 2   Kidney Tx
# 4   Kidney Tx
# 6   Kidney Tx
# 28  Nutrition

# %%
df['visit_type'].value_counts()
# Out:
# visit_type
# FOLLOW UP            782
# NEW                  482
# V Follow UP          299
# Walk-In              129
# Kidney               126
# CHART CHECK           77
# Liver                 39
# new                   14
# VV                    12
# Medication Refill      3
# Follow up              1
# Name: count, dtype: int64

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Adult Post Renal Transplant                        469
# TRANSPLANT SURGERY                                 410
# Adult Post Kidney Transplant Virtual Clinic        228
# ADULT POST LIVER TRANSPLANT                        128
# Anesthesia                                         102
# Adult Pre Renal Transplant                          96
# Adult Pre Liver Transplant                          88
# Pediatric Post Renal Transplant                     85
# Clinical Nutrition                                  76
# Pediatric Liver Transplant                          72
# Social Work                                         46
# Adult Post Liver Transplant Virtual                 40
# Transplant Dressing (procedure)                     38
# Pediatric Post Kidney Transplant Virtual Clinic     21
# Adult Pre Renal Transplant Virtual Clinic           19
# Psychology                                          15
# Pediatric Pre Renal Transplant                      11
# Adult Pre Liver Transplant Virtual                  10
# Transplant Cystoscopy Clinic                         6
# Pre anesthesia liver transplant                      4
# Name: count, dtype: int64

# %%
ref = pd.read_excel(MOTC_FILE)
ref.columns
ref.head(1)

########################
# Out:
#         Date    MRN                      Name    Age   patient Type    clinic  \
# 0 2018-01-07  89742  Fatima Ahmed Al-swaidani  Adult  Post-Liver tx  Liver Tx
#
#   Visit Type     R/D Adult Kidney post type Adult Kidney Tx out & donors  \
# 0         FU  Liver                       -                            -
#
#   Pediatric Kidney Tx. Type  Consultant Covered the clinic "Actual Coverage"  \
# 0                        NaN                                Mohammed Mawaldi
#
#   Medica - Plus Clinic Name Consultant name from Medica + Assistant Coverage  \
# 0       Adult Post Liver Tx                           NaN                NaN
#
#   In MCC Unnamed: 16 Unnamed: 17 From papers
# 0    NaN         NaN         NaN         NaN

# %%
# =============================================================================
# COMPLETE OPD VISIT_TYPE CLEANING PIPELINE – FULL LOGIC EXPLAINED
# =============================================================================
#
# BUSINESS PROBLEM:
#   Our main dataframe (df) has a column 'visit_type' with messy/inconsistent values:
#   Examples: "Follow up", "New", "follow-up", "Kidney", "Liver", "Walk-In", "CHART CHECK", "VV", etc.
#   Goal: After cleaning, this column MUST contain ONLY these 4 allowed values:
#       → 'FOLLOW UP', 'NEW', 'V FOLLOW UP', 'VV'
#
# REFERENCE DATA:
#   We have an Excel file: "MOTC OPD visits - from 2018-2021.xlsx"
#   It contains historical visits with columns: 'MRN' and 'clinic'
#   We use it to decide whether a patient is known (FOLLOW UP) or new (NEW)
#
# STEP-BY-STEP LOGIC OF THE ENTIRE PIPELINE:
#
# 1. STANDARDIZE OBVIOUS CASES (simple fixes)
#    → Convert variations like "follow up", "Follow-up", "followup", "new" → canonical forms
#    → Make everything UPPERCASE and strip extra spaces
#    → Goal: Fix most clean cases without needing the reference file
#
# 2. IDENTIFY MESSY ROWS THAT STILL NEED HELP
#    → Create a mask: rows where visit_type is NOT in {'FOLLOW UP', 'NEW', 'V FOLLOW UP', 'VV'}
#    → These are the rows we couldn't automatically classify in step 1 (e.g. "Kidney", "Walk-In")
#
# 3. PREPARE REFERENCE DATA FOR FAST LOOKUPS
#    → Standardize 'clinic' and 'MRN' in the reference file (uppercase + strip)
#    → Create a set of known (clinic, MRN) pairs that have visited before
#
# 4. RECLASSIFY THE MESSY ROWS USING THE REFERENCE FILE (VECTORIZED – FAST!)
#    → For each messy row:
#        - Take its standardized clinic + MRN
#        - Check if this exact (clinic, MRN) pair exists in the historical reference data
#            → If YES → patient is known → set visit_type = 'FOLLOW UP'
#            → If NO  → patient is new   → set visit_type = 'NEW'
#    → We use pandas merge + np.where → very fast even for large datasets
#
# 5. FINAL SAFETY CHECK & SELECTIVE MANUAL REVIEW FLAGGING
#    → After all cleaning is done, check again:
#        - Print the final distribution of visit_type
#        - Look for ANY rows that still have invalid values (not in the 4 allowed ones)
#    → If there ARE still bad rows (should be rare!):
#        - Print a WARNING + show the unexpected values
#        - Flag ONLY these problematic rows for manual human review:
#            → Set need_review = 'yes' (column already exists and defaults to 'no')
#    → If everything is clean → print SUCCESS
#    → Important: We do NOT flag the 372 rows we successfully reclassified — only flag rows
#      that are STILL wrong after all automated logic
#
# WHY THIS APPROACH IS GREAT:
#   - Fast & scalable (vectorized merge instead of slow row-by-row loops)
#   - Auditable: we can trace every decision
#   - Safe: human review only for truly uncertain/problematic cases
#   - Future-proof: handles casing, spaces, missing values gracefully
#


# ── Inputs ────────────────────────────────────────────────────────
# REF_PATH = "../data/raw/MOTC OPD visits - from 2018-2021.xlsx"
ALLOWED_VISIT_TYPES = {"FOLLOW UP", "NEW", "V FOLLOW UP", "VV"}

# ── 1. Load reference ─────────────────────────────────────────────
ref = pd.read_excel(MOTC_FILE)

# ── 2. Standardize everything ─────────────────────────────────────
# visit_type
df["visit_type"] = df["visit_type"].astype(str).str.strip()
df.loc[
    df["visit_type"].str.lower().isin(["follow up", "follow-up", "followup"]),
    "visit_type"
] = "FOLLOW UP"
df.loc[df["visit_type"].str.lower() == "new", "visit_type"] = "NEW"
df["visit_type"] = df["visit_type"].str.upper().str.strip()

# clinic & mrn (helper columns)
df["clinic_std"] = df["clinic"].astype(str).str.strip().str.upper()
ref["clinic_std"] = ref["clinic"].astype(str).str.strip().str.upper()

df["mrn_std"] = df["mrn"].astype(str).str.strip()
ref["mrn_std"] = ref["MRN"].astype(str).str.strip()

# ── 3. Identify rows to fix ───────────────────────────────────────
needs_reclass = ~df["visit_type"].isin(ALLOWED_VISIT_TYPES)
print(f"Rows needing reclassification: {needs_reclass.sum():,}")

# ── 4. Vectorized reclassification (best way!) ────────────────────
ref_pairs = ref[["clinic_std", "mrn_std"]].drop_duplicates()

tmp = df.loc[needs_reclass, ["clinic_std", "mrn_std"]].merge(
    ref_pairs.assign(seen_in_ref=True),
    on=["clinic_std", "mrn_std"],
    how="left"
)

df.loc[needs_reclass, "visit_type"] = np.where(
    tmp["seen_in_ref"].notna(),   # ← .notna() returns True/False directly
    "FOLLOW UP",
    "NEW"
)

# ── 5. Cleanup ────────────────────────────────────────────────────
df.drop(columns=["clinic_std", "mrn_std"], inplace=True)

# ── Final safety check & flagging for review ───────────────────────
print("\nFinal visit_type distribution:")
print(df["visit_type"].value_counts(dropna=False))

# Find rows with unexpected (invalid) visit_type values
unexpected_mask = ~df["visit_type"].isin(ALLOWED_VISIT_TYPES)

# Get the actual unexpected values (for printing)
unexpected_values = df.loc[unexpected_mask, "visit_type"].unique()

if len(unexpected_values) > 0:
    print("\nWARNING — unexpected values still exist:", unexpected_values)
    print(f"Number of rows with unexpected values: {unexpected_mask.sum():,}")
    
    # Flag ONLY these problematic rows for manual review
    df.loc[unexpected_mask, 'need_review'] = 'yes'
    
    # Optional: also save what the bad value was
    if 'original_visit_type' not in df.columns:
        df['original_visit_type'] = df['visit_type'].copy()  # only if you didn't save it earlier
else:
    print("\nSUCCESS: All visit_types are now allowed! No rows need review.")
# Out:
# Rows needing reclassification: 374
#
# Final visit_type distribution:
# visit_type
# FOLLOW UP      923
# NEW            730
# V FOLLOW UP    299
# VV              12
# Name: count, dtype: int64
#
# SUCCESS: All visit_types are now allowed! No rows need review.

# %%
df['clinic'].value_counts()
# Out:
# clinic
# Kidney Tx            929
# Surgery-Liver        410
# liver Tx             338
# Anesthesia-Kidney     82
# Nutrition             76
# Social Work           46
# Surgery-Dressing      38
# Anesthesia-Liver      24
# Psychology            15
# Urology                6
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        mrn                         patengname pat_birthdate visit_datetime  \
# 1   187647   ALREEM AHMED  ABDULKAREEM KHALAF    2016-08-31     2026-01-06
# 2   218085           Sultan Ali Saleh Alnahdi    1990-07-01     2026-01-13
# 4   147118       SAAD ABDULLAH ALI ALBUAINAIN    2008-12-31     2026-01-25
# 6   210109  YASAMIYAN HAMAD MOHAMMED ALRAWILI    2008-05-02     2026-01-20
# 28  176279          RADHI NASER HASAN ALHODAR    1946-05-31     2026-01-04
#
#    visit_type visit_status    booking_type                      clinic_name  \
# 1   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 2         NEW      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 4   FOLLOW UP      STARTED  NORMAL BOOKING  Pediatric Post Renal Transplant
# 6   FOLLOW UP      STARTED  NORMAL BOOKING      Adult Post Renal Transplant
# 28        NEW      STARTED  NORMAL BOOKING               Clinical Nutrition
#
#                                        mrp  liver_r_d        liver_status  \
# 1        Mohammed Abdulmoatani  Almaghrabi        NaN                 NaN
# 2       ABDULNASER MOHAMMED HAMOUD ALABADI        NaN                 NaN
# 4           ABDULAZIZ AHMED SALEM BA MHRAZ  Recipient  Hepatology patient
# 6   SUMAYAH ABDULAZIZ MOHAMMED ASKANDARANI        NaN                 NaN
# 28          Ebtisam Hassan Husain Al-Ghawi        NaN                 NaN
#
#       kidney_recipient                   kidney_donor need_review  \
# 1           Post LD Tx                            NaN          no
# 2                  NaN  Post living donor nephrectomy          no
# 4           Post DD Tx                            NaN          no
# 6           Post LD Tx                            NaN          no
# 28  Nephrology patient                            NaN          no
#
#                  r_d    patient_type transplant_date   days  age_group  \
# 1   Kidney Recipient  Post-Kidney Tx      2024-01-23  714.0  Pediatric
# 2       Kidney Donor  Post-Kidney Tx      2025-12-02   42.0      Adult
# 4    Liver Recipient      Hepatology      2024-01-22  734.0  Pediatric
# 6   Kidney Recipient  Post-Kidney Tx      2025-09-15  127.0      Adult
# 28  Kidney Recipient      Nephrology             NaT    NaN      Adult
#
#        clinic
# 1   Kidney Tx
# 2   Kidney Tx
# 4   Kidney Tx
# 6   Kidney Tx
# 28  Nutrition

# %%
# =============================================================================
# FINAL STEP: FIX INCORRECT MULTIPLE "NEW" VISITS PER (MRN, CLINIC)
# =============================================================================
#
# BUSINESS RULE:
#   - Each patient (mrn) can have AT MOST ONE 'NEW' visit per clinic
#   - The 'NEW' must be the EARLIEST visit (by visit_datetime)
#   - All subsequent visits in the same clinic MUST be 'FOLLOW UP'
#
# We ONLY fix groups where:
#   - Multiple visits exist (group size > 1)
#   - AND ALL visits are currently labeled 'NEW'
#
# Groups we leave untouched:
#   - Single visit
#   - Already contain at least one 'FOLLOW UP', 'V FOLLOW UP' or 'VV'
#
# Important: We do NOT flag any rows for review in this step.
#            The need_review column remains unchanged.
#
# =============================================================================


# 1. Ensure visit_datetime is proper datetime
df['visit_datetime'] = pd.to_datetime(df['visit_datetime'], errors='coerce')

# 2. Sort chronologically within each (mrn, clinic) using stable sort
df = df.sort_values(
    ['mrn', 'clinic', 'visit_datetime'],
    kind='mergesort'                  # stable sort for reproducibility
).reset_index(drop=True)

# 3. Helper columns (all vectorized)
df['is_first_visit'] = df.groupby(['mrn', 'clinic']).cumcount() == 0
df['group_size'] = df.groupby(['mrn', 'clinic'])['visit_type'].transform('size')

# Safe & clear "all NEW" check
df['all_new'] = (
    df.groupby(['mrn', 'clinic'])['visit_type'].transform('nunique') == 1
) & df['visit_type'].eq('NEW')

# 4. Mask: rows we will change to 'FOLLOW UP'
mask_to_change = (
    (df['group_size'] > 1) &
    df['all_new'] &
    ~df['is_first_visit']
)

# 5. Store examples BEFORE mutation (shows original 'NEW' values)
changed_examples = df.loc[mask_to_change].copy()

# 6. Apply the correction
df.loc[mask_to_change, 'visit_type'] = 'FOLLOW UP'

# 7. Clean up helper columns
df = df.drop(columns=['is_first_visit', 'group_size', 'all_new'])

# %%
df.head()
# Out:
#     mrn                        patengname pat_birthdate visit_datetime  \
# 0    99    IBRAHIM AHMED YOUSEF  ALAHSAIE    1956-02-13     2026-01-25
# 1   733    HUDA ABDULLAH AHMED  ALDARORAH    1968-09-23     2026-01-11
# 2   733    HUDA ABDULLAH AHMED  ALDARORAH    1968-09-23     2026-01-18
# 3  1470  KHALED SAEED BIN AWADH ALQAHTANI    1986-04-26     2026-01-06
# 4  1470  KHALED SAEED BIN AWADH ALQAHTANI    1986-04-26     2026-01-27
#
#     visit_type visit_status    booking_type  \
# 0    FOLLOW UP      STARTED  NORMAL BOOKING
# 1  V FOLLOW UP      STARTED  NORMAL BOOKING
# 2  V FOLLOW UP      STARTED  NORMAL BOOKING
# 3          NEW      STARTED  NORMAL BOOKING
# 4    FOLLOW UP      STARTED  NORMAL BOOKING
#
#                            clinic_name                         mrp  liver_r_d  \
# 0          ADULT POST LIVER TRANSPLANT  HADI MOHAMMED SHOEI KURIRY  Recipient
# 1  Adult Post Liver Transplant Virtual  HADI MOHAMMED SHOEI KURIRY  Recipient
# 2  Adult Post Liver Transplant Virtual  HADI MOHAMMED SHOEI KURIRY  Recipient
# 3                           Anesthesia       ASHRAF ALI MOUSSA ALI  Recipient
# 4           Adult Pre Liver Transplant     NOORA HASSAN B AL FARAJ  Recipient
#
#          liver_status    kidney_recipient kidney_donor need_review  \
# 0             Post Tx  Nephrology patient          NaN          no
# 1             Post Tx                 NaN          NaN          no
# 2             Post Tx                 NaN          NaN          no
# 3  Hepatology patient                 NaN          NaN          no
# 4  Hepatology patient                 NaN          NaN          no
#
#                r_d   patient_type transplant_date    days age_group  \
# 0  Liver Recipient  Post-Liver Tx      2007-05-31  6814.0     Adult
# 1  Liver Recipient  Post-Liver Tx      2018-10-28  2632.0     Adult
# 2  Liver Recipient  Post-Liver Tx      2018-10-28  2639.0     Adult
# 3  Liver Recipient     Hepatology             NaT     NaN     Adult
# 4  Liver Recipient     Hepatology             NaT     NaN     Adult
#
#              clinic
# 0          liver Tx
# 1          liver Tx
# 2          liver Tx
# 3  Anesthesia-Liver
# 4          liver Tx

# %%
df.columns
# Out:
# Index(['mrn', 'patengname', 'pat_birthdate', 'visit_datetime', 'visit_type',
#        'visit_status', 'booking_type', 'clinic_name', 'mrp', 'liver_r_d',
#        'liver_status', 'kidney_recipient', 'kidney_donor', 'need_review',
#        'r_d', 'patient_type', 'transplant_date', 'days', 'age_group',
#        'clinic'],
#       dtype='object')

# %%
df['clinic_name'].value_counts()
# Out:
# clinic_name
# Adult Post Renal Transplant                        469
# TRANSPLANT SURGERY                                 410
# Adult Post Kidney Transplant Virtual Clinic        228
# ADULT POST LIVER TRANSPLANT                        128
# Anesthesia                                         102
# Adult Pre Renal Transplant                          96
# Adult Pre Liver Transplant                          88
# Pediatric Post Renal Transplant                     85
# Clinical Nutrition                                  76
# Pediatric Liver Transplant                          72
# Social Work                                         46
# Adult Post Liver Transplant Virtual                 40
# Transplant Dressing (procedure)                     38
# Pediatric Post Kidney Transplant Virtual Clinic     21
# Adult Pre Renal Transplant Virtual Clinic           19
# Psychology                                          15
# Pediatric Pre Renal Transplant                      11
# Adult Pre Liver Transplant Virtual                  10
# Transplant Cystoscopy Clinic                         6
# Pre anesthesia liver transplant                      4
# Name: count, dtype: int64

# %%
import os
from datetime import datetime


# -----------------------------
# 1) Build the final export_df
# -----------------------------
export_df = df.rename(columns={
    "visit_datetime": "date",
    "patengname": "name",
    "age_group": "age",
    "patient_type": "patient type",
    "visit_type": "visit type",
    "r_d": "r/d",
    "clinic_name": "Medica - Plus Clinic Name",
    "mrp": "Consultant name from Medica +",
})

final_cols = [
    "date",
    "mrn",
    "name",
    "age",
    "patient type",
    "clinic",
    "visit type",
    "r/d",
    "Medica - Plus Clinic Name",
    "Consultant name from Medica +",
    "need_review",
]
export_df = export_df[final_cols].copy()

# -----------------------------
# 2) Date format: DATE ONLY
#    (Excel will show it as a date)
# -----------------------------
export_df["date"] = pd.to_datetime(export_df["date"], errors="coerce").dt.date

# -----------------------------
# 3) Export to data/output as Excel
# -----------------------------

output_dir = "../data/output"
os.makedirs(output_dir, exist_ok=True)


year_month = datetime.now().strftime("%Y_%m")
output_path = os.path.join(
    output_dir,
    f"cleaned_opd_visits_{year_month}.xlsx"
)

export_df.to_excel(output_path, index=False)

print(f"✅ Exported: {output_path}")
# Out:
# ✅ Exported: ../data/output/cleaned_opd_visits_2026_02.xlsx
